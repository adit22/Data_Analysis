# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\18\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_may=data.iloc[92:123,:]
data_may.head()
# Out:
#        Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 92  01 May              2396            37262              962
# 93  02 May              2564            39826              831
# 94  03 May              2952            42778              911
# 95  04 May              3656            46434             1082
# 96  05 May              2971            49405             1295
#
#     Total Recovered  Daily Deceased  Total Deceased
# 92            10021              77            1231
# 93            10852              92            1323
# 94            11763             140            1463
# 95            12845             103            1566
# 96            14140             128            1694

# %%
len(data_may)
# Out:
# 31

# %%
data_may.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
count1=0
for i in list(data_may.columns):
    for j in range(92,123):
        if(data_may[i][j]=="NaN" or data_may[i][j]=="" or data_may[i][j]==" " or data_may[i][j]=="?"):
            count1=count1+1
if(count1):
    print("yes")

# %%
count2=0
for j in range(92,123):
    if(data_may["Date"][j]=="####"):
        count2=count2+1
if(count2):
    print("yes")

# %%
#data_may.to_csv("coviddata_may.csv")

# %%
datamy=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\monthly_case_series\coviddata_may.csv")
datamy.head()
# Out:
#      Date  Daily Confirmed  Total Confirmed  Daily Recovered  Total Recovered  \
# 0  01-May             2396            37262              962            10021
# 1  02-May             2564            39826              831            10852
# 2  03-May             2952            42778              911            11763
# 3  04-May             3656            46434             1082            12845
# 4  05-May             2971            49405             1295            14140
#
#    Daily Deceased  Total Deceased
# 0              77            1231
# 1              92            1323
# 2             140            1463
# 3             103            1566
# 4             128            1694

# %%
date=datamy["Date"]
date=list(date)

# %%
for i in range(len(date)):
    date[i]=date[i].strip("-May")

# %%
for i in range(len(date)):
    date[i]="2020-05-"+date[i]

# %%
datamy["Date"]=date

# %%
datamy['Date'] = datamy['Date'].astype('datetime64[ns]') 
datamy.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0            10021              77            1231
# 1            10852              92            1323
# 2            11763             140            1463
# 3            12845             103            1566
# 4            14140             128            1694

# %%
datamy.plot(x="Date",y="Daily Confirmed")

# %%
datamy.plot(x="Date",y="Total Confirmed")

# %%
datamy.plot(x="Date",y="Daily Recovered")

# %%
datamy.plot(x="Date",y="Total Recovered")

# %%
datamy.plot(x="Date",y="Daily Deceased")

# %%
datamy.plot(x="Date",y="Total Deceased")

# %%
datamay=datamy.copy()
datamay.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0            10021              77            1231
# 1            10852              92            1323
# 2            11763             140            1463
# 3            12845             103            1566
# 4            14140             128            1694

# %%
datamay["Date_tmp"]=pd.Series(list(range(1,32)),index=list(range(0,31)))
datamay.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased  Date_tmp
# 0            10021              77            1231         1
# 1            10852              92            1323         2
# 2            11763             140            1463         3
# 3            12845             103            1566         4
# 4            14140             128            1694         5

# %%
colss=list(data.columns)
colss.pop(0)
for m in colss:
    fig,axs=plt.subplots(2,2)
    count=1
    for i,j,k in zip(range(0,22,7),[[0,0],[0,1],[1,0],[1,1]],["blue","red","orange","green"]):
        a="tab"+":"+k
        count+=1
        if(count==5):
            x=datamay["Date_tmp"][i:i+7+3]
            y=datamay[m][i:i+7+3]
        else:
            
            x=datamay["Date_tmp"][i:i+7]
            y=datamay[m][i:i+7]
        axs[j[0],j[1]].plot(x,y,a)
        axs[0, 0].set_title(m)

# %%
colss=list(data.columns)
colss.pop(0)
for m in colss:
    fig,axs=plt.subplots(2,2)
    
    
    count=1
    for i,j,k in zip(range(0,22,7),[[0,0],[0,1],[1,0],[1,1]],["blue","red","orange","green"]):
        a="tab"+":"+k
        count+=1
        
        if(count==5):
            x=datamay["Date_tmp"][i:i+7+3]
            y=datamay[m][i:i+7+3]
        else:
            
            x=datamay["Date_tmp"][i:i+7]
            y=datamay[m][i:i+7]
        if(count<4):
            axs[j[0],j[1]].set_title(m)
        axs[j[0],j[1]].plot(x,y,a)
        axs[j[0],j[1]].fill_between(x,0,y,color=k)

# %%
colss=list(data.columns)
colss.pop(0)
for m in colss:
    count=1
    for i,j in zip(range(0,15,14),["orange","red"]):
        fig,(axs1,axs2)=plt.subplots(1,2)
        fig.suptitle(m)
        fig.tight_layout(pad=2.0)

        x1=datamay["Date_tmp"][i:i+7]
        y1=datamay[m][i:i+7]
        if(count==2):
            x2=datamay["Date_tmp"][i+7:i+14+3]
            y2=datamay[m][i+7:i+14+3]
        else:
            x2=datamay["Date_tmp"][i+7:i+14]
            y2=datamay[m][i+7:i+14]
        count+=1
        a="tab"+":"+j
        axs1.plot(x1,y1,a)
        axs2.plot(x2,y2,a)

# %%
colss=list(data.columns)
colss.pop(0)
for m in colss:
    count=1
    for i,j in zip(range(0,15,14),["orange","red"]):
        fig,(axs1,axs2)=plt.subplots(1,2)
        fig.suptitle(m)
        fig.tight_layout(pad=2.0)

        x1=datamay["Date_tmp"][i:i+7]
        y1=datamay[m][i:i+7]
        if(count==2):
            x2=datamay["Date_tmp"][i+7:i+14+3]
            y2=datamay[m][i+7:i+14+3]
        else:
            x2=datamay["Date_tmp"][i+7:i+14]
            y2=datamay[m][i+7:i+14]
        count+=1
        a="tab"+":"+j
        axs1.plot(x1,y1,a)
        axs1.fill_between(x1,0,y1,color=j)
        axs2.plot(x2,y2,a)
        axs2.fill_between(x2,0,y2,color=j)

# %%
colss=list(data.columns)
colss.pop(0)
for m,n in zip(colss,["blue","black","orange","green","violet","red"]):
    datamay.plot(x="Date",y=m,color=n)

# %%
colss=list(data.columns)
colss.pop(0)
for m,n in zip(colss,["blue","black","orange","green","violet","red"]):
    datamay.plot(x="Date",y=m,color=n,kind="area")

# %%
datamay_for_scattering=datamay.copy()
datamay_for_scattering.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased  Date_tmp
# 0            10021              77            1231         1
# 1            10852              92            1323         2
# 2            11763             140            1463         3
# 3            12845             103            1566         4
# 4            14140             128            1694         5

# %%
colls=list(datamay_for_scattering.columns)
colls.pop(0)
colls.pop(len(colls)-1)
datamay_for_scattering.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased  Date_tmp
# 0            10021              77            1231         1
# 1            10852              92            1323         2
# 2            11763             140            1463         3
# 3            12845             103            1566         4
# 4            14140             128            1694         5

# %%
colors=["Red","Violet","Orange","Yellow","Green","Black"]
for i,j in zip(colls,colors):
    datamay_for_scattering.plot(x="Date_tmp",y=i,kind="scatter",color=j)

# %%
datamay=datamay.drop(["Date_tmp"], axis=1)
datamay.reset_index(inplace = True, drop = True) 
datamay.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0            10021              77            1231
# 1            10852              92            1323
# 2            11763             140            1463
# 3            12845             103            1566
# 4            14140             128            1694

# %%
datamay_diff=datamay.copy()
datamay_diff.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0            10021              77            1231
# 1            10852              92            1323
# 2            11763             140            1463
# 3            12845             103            1566
# 4            14140             128            1694

# %%
new_cols=["Daily_Confirmed_Diff","Total_Confirmed_Diff","Daily_Recovered_Diff","Total_Recovered_Diff","Daily_Deceased_Diff","Total_Deceased_diff"]
existing_cols=list(datamay_diff.columns)
existing_cols.pop(0)
existing_cols
prv_vals=[1801,34866,630,9059,75,1154]
for i,j,l in zip(new_cols,existing_cols,prv_vals):
    datamay_diff[i]=list(range(len(datamay_diff)))
    datamay_diff[i][0]=datamay_diff[j][0]-l
    for k in range(0,len(datamay_diff)-1):
        datamay_diff[i][k+1]=datamay_diff[j][k+1]-datamay_diff[j][k]
# Out:
# <ipython-input-35-499fc357e549>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datamay_diff[i][0]=datamay_diff[j][0]-l
# <ipython-input-35-499fc357e549>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datamay_diff[i][k+1]=datamay_diff[j][k+1]-datamay_diff[j][k]

# %%
datamay_diff.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Diff  \
# 0            10021              77            1231                   595
# 1            10852              92            1323                   168
# 2            11763             140            1463                   388
# 3            12845             103            1566                   704
# 4            14140             128            1694                  -685
#
#    Total_Confirmed_Diff  Daily_Recovered_Diff  Total_Recovered_Diff  \
# 0                  2396                   332                   962
# ...

# %%
datamay_diff["Total Confirmed"][14]-datamay_diff["Total Confirmed"][13]==datamay_diff["Total_Confirmed_Diff"][14]
# Out:
# True

# %%
datamay_diff.describe()
# Out:
#        Daily Confirmed  Total Confirmed  Daily Recovered  Total Recovered  \
# count        31.000000        31.000000        31.000000        31.000000
# mean       5025.258065     99658.774194      2671.064516     39262.129032
# std        1855.868727     45919.692269      2008.523686     24219.678486
# min        2396.000000     37262.000000       831.000000     10021.000000
# 25%        3577.000000     61277.500000      1444.500000     18594.000000
# 50%        4628.000000     90649.000000      2482.000000     34257.000000
# 75%        6475.000000    134980.500000      3225.500000     56051.500000
# max        8789.000000    190649.000000     11735.000000     91862.000000
#
#        Daily Deceased  Total Deceased  Daily_Confirmed_Diff  \
# count       31.000000       31.000000             31.000000
# mean       137.161290     3039.580645            225.419355
# std         42.790261     1215.692060            583.174804
# ...

# %%
colors=["Blue","Red","Yellow","Green","Orange","Violet"]
for i,j in zip(new_cols,colors):
    datamay_diff.plot(x="Date",y=i,color=j)

# %%
datamay_diff["Date_tmp"]=pd.Series(list(range(1,32)),index=list(range(0,31)))
datamay_diff.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Diff  \
# 0            10021              77            1231                   595
# 1            10852              92            1323                   168
# 2            11763             140            1463                   388
# 3            12845             103            1566                   704
# 4            14140             128            1694                  -685
#
#    Total_Confirmed_Diff  Daily_Recovered_Diff  Total_Recovered_Diff  \
# 0                  2396                   332                   962
# ...

# %%
colss=list(datamay_diff.columns)
for i in range(0,7):
    colss.pop(0)
colss.pop(len(colss)-1)
for m in colss:
    fig,axs=plt.subplots(2,2)
    count=1
    for i,j,k in zip(range(0,22,7),[[0,0],[0,1],[1,0],[1,1]],["blue","red","orange","green"]):
        count+=1
        a="tab"+":"+k
        
        if(count==5):
            x=datamay_diff["Date_tmp"][i:i+7+3]
            y=datamay_diff[m][i:i+7+3]
            

        else:
        
            x=datamay_diff["Date_tmp"][i:i+7]
            y=datamay_diff[m][i:i+7]
        if(count<4):
                axs[j[0],j[1]].set_title(m)
        axs[j[0],j[1]].plot(x,y,a)
        #axs[j[0],j[1]].fill_between(x,0,y,color=k)

# %%
datamay_diff.drop(['Date_tmp'],axis=1)
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  2020-05-01             2396            37262              962
# 1  2020-05-02             2564            39826              831
# 2  2020-05-03             2952            42778              911
# 3  2020-05-04             3656            46434             1082
# 4  2020-05-05             2971            49405             1295
# 5  2020-05-06             3602            53007             1161
# 6  2020-05-07             3344            56351             1475
# 7  2020-05-08             3339            59690             1111
# 8  2020-05-09             3175            62865             1414
# 9  2020-05-10             4311            67176             1669
# 10 2020-05-11             3592            70768             1579
# 11 2020-05-12             3562            74330             1905
# 12 2020-05-13             3726            78056             1963
# ...

# %%
datamay_diff.tail()
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 26 2020-05-27             7246           158104             3434
# 27 2020-05-28             7254           165358             3171
# 28 2020-05-29             8138           173496            11735
# 29 2020-05-30             8364           181860             4303
# 30 2020-05-31             8789           190649             4928
#
#     Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Diff  \
# 26            67725             188            4534                  1339
# 27            70896             176            4710                     8
# 28            82631             269            4979                   884
# 29            86934             205            5184                   226
# 30            91862             222            5406                   425
#
#     Total_Confirmed_Diff  Daily_Recovered_Diff  Total_Recovered_Diff  \
# ...

# %%
#datamay_diff.to_excel("datamay_diff.xlsx")

# %%
kys=["daily_cnf_diff_pos_neg","total_cnf_diff_pos_neg","daily_rcvd_diff_pos_neg","total_rcvd_diff_pos_neg","daily_dcsd_diff_pos_neg","total_dcsd_diff_pos_neg"]
new_cols=["Daily_Confirmed_Diff","Total_Confirmed_Diff","Daily_Recovered_Diff","Total_Recovered_Diff","Daily_Deceased_Diff","Total_Deceased_diff"]
pos_neg_dict={}
pos_neg_len_dict={}
a=[]
b=[]
for i,j in zip(kys,new_cols):
    pos=datamay_diff[datamay_diff[j]>0]
    a.append(pos)
    b.append(len(pos))
    neg=datamay_diff[datamay_diff[j]<0]
    a.append(neg)
    b.append(len(neg))
    zro=datamay_diff[datamay_diff[j]==0]
    a.append(zro)
    b.append(len(zro))
    pos_neg_dict.update({i:a})
    pos_neg_len_dict.update({i:b})
    a=[]
    b=[]

# %%
datamay_ratio_with_precision=datamay.copy()
datamay_ratio_with_precision.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0            10021              77            1231
# 1            10852              92            1323
# 2            11763             140            1463
# 3            12845             103            1566
# 4            14140             128            1694

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(datamay_ratio_with_precision.columns)
existing_cols.pop(0)
existing_cols
prv_vals=[1801,34866,630,9059,75,1154]
for i,j,l in zip(new_cols,existing_cols,prv_vals):
    datamay_ratio_with_precision[i]=list(range(len(datamay_ratio_with_precision)))
    datamay_ratio_with_precision[i][0]=round(datamay_ratio_with_precision[j][0]/l,2)
    tmp=[]
    tmp.append(datamay_ratio_with_precision[i][0])
    for k in range(0,len(datamay_ratio_with_precision)-1):
        tmp.append(round(datamay_ratio_with_precision[j][k+1]/datamay_ratio_with_precision[j][k],2))
    datamay_ratio_with_precision[i]=tmp
datamay_ratio_with_precision.head()
# Out:
# <ipython-input-47-faefe93df690>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datamay_ratio_with_precision[i][0]=round(datamay_ratio_with_precision[j][0]/l,2)
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0            10021              77            1231                   1.00
# 1            10852              92            1323                   1.07
# ...

# %%
round(datamay_ratio_with_precision["Total Confirmed"][4]/datamay_ratio_with_precision["Total Confirmed"][3],2)==datamay_ratio_with_precision["Total_Confirmed_Ratio"][4]
# Out:
# True

# %%
colors=["Blue","Red","Yellow","Green","Orange","Violet"]
for i,j in zip(new_cols,colors):
    datamay_ratio_with_precision.plot(x="Date",y=i,color=j)

# %%
datamay_ratio_with_precision.tail()
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 26 2020-05-27             7246           158104             3434
# 27 2020-05-28             7254           165358             3171
# 28 2020-05-29             8138           173496            11735
# 29 2020-05-30             8364           181860             4303
# 30 2020-05-31             8789           190649             4928
#
#     Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 26            67725             188            4534                   1.23
# 27            70896             176            4710                   1.00
# 28            82631             269            4979                   1.12
# 29            86934             205            5184                   1.03
# 30            91862             222            5406                   1.05
#
#     Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# ...

# %%
datamay_ratio=datamay.copy()
datamay_ratio.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0            10021              77            1231
# 1            10852              92            1323
# 2            11763             140            1463
# 3            12845             103            1566
# 4            14140             128            1694

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(datamay_ratio.columns)
existing_cols.pop(0)
existing_cols
prv_vals=[1801,34866,630,9059,75,1154]
for i,j,l in zip(new_cols,existing_cols,prv_vals):
    datamay_ratio[i]=list(range(len(datamay_ratio)))
    datamay_ratio[i][0]=datamay_ratio[j][0]/l
    tmp=[]
    tmp.append(datamay_ratio[i][0])
    for k in range(0,len(datamay_ratio)-1):
        tmp.append(datamay_ratio[j][k+1]/datamay_ratio[j][k])
    datamay_ratio[i]=tmp
datamay_ratio.head()
# Out:
# <ipython-input-52-c2c578338135>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datamay_ratio[i][0]=datamay_ratio[j][0]/l
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-05-01             2396            37262              962
# 1 2020-05-02             2564            39826              831
# 2 2020-05-03             2952            42778              911
# 3 2020-05-04             3656            46434             1082
# 4 2020-05-05             2971            49405             1295
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0            10021              77            1231               1.000000
# 1            10852              92            1323               1.070117
# ...

# %%
colors=["Blue","Red","Yellow","Green","Orange","Violet"]
for i,j in zip(new_cols,colors):
    datamay_ratio.plot(x="Date",y=i,color=j)

# %%
datamay_ratio["Date_tmp"]=pd.Series(list(range(1,32)),index=list(range(0,31)))
datamay_ratio.tail()
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 26 2020-05-27             7246           158104             3434
# 27 2020-05-28             7254           165358             3171
# 28 2020-05-29             8138           173496            11735
# 29 2020-05-30             8364           181860             4303
# 30 2020-05-31             8789           190649             4928
#
#     Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 26            67725             188            4534               1.226680
# 27            70896             176            4710               1.001104
# 28            82631             269            4979               1.121864
# 29            86934             205            5184               1.027771
# 30            91862             222            5406               1.050813
#
#     Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# ...

# %%
colss=list(datamay_ratio.columns)
for i in range(0,7):
    colss.pop(0)
colss.pop(len(colss)-1)
for m in colss:
    fig,axs=plt.subplots(2,2)
    count=1
    for i,j,k in zip(range(0,22,7),[[0,0],[0,1],[1,0],[1,1]],["blue","red","orange","green"]):
        count+=1
        a="tab"+":"+k
        
        if(count==5):
            x=datamay_ratio["Date_tmp"][i:i+7+3]
            y=datamay_ratio[m][i:i+7+3]
            

        else:
        
            x=datamay_ratio["Date_tmp"][i:i+7]
            y=datamay_ratio[m][i:i+7]
        if(count<4):
                axs[j[0],j[1]].set_title(m)
        axs[j[0],j[1]].plot(x,y,a)
        #axs[j[0],j[1]].fill_between(x,0,y,color=k)

# %%
datamay_ratio.drop(['Date_tmp'],axis=1)
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  2020-05-01             2396            37262              962
# 1  2020-05-02             2564            39826              831
# 2  2020-05-03             2952            42778              911
# 3  2020-05-04             3656            46434             1082
# 4  2020-05-05             2971            49405             1295
# 5  2020-05-06             3602            53007             1161
# 6  2020-05-07             3344            56351             1475
# 7  2020-05-08             3339            59690             1111
# 8  2020-05-09             3175            62865             1414
# 9  2020-05-10             4311            67176             1669
# 10 2020-05-11             3592            70768             1579
# 11 2020-05-12             3562            74330             1905
# 12 2020-05-13             3726            78056             1963
# ...

# %%
#datamay_ratio.to_excel("datamay_ratio.xlsx")

# %%
kys=["daily_cnf_diff_rat10","total_cnf_diff_rat10","daily_rcvd_diff_rat10","total_rcvd_diff_rat10","daily_dcsd_diff_rat10","total_dcsd_diff_rat10"]
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
one_zro_dict={}
one_zro_len_dict={}
a=[]
b=[]
for i,j in zip(kys,new_cols):
    pos=datamay_ratio[datamay_ratio[j]>=1]
    a.append(pos)
    b.append(len(pos))
    neg=datamay_ratio[datamay_ratio[j]<1]
    a.append(neg)
    b.append(len(neg))
    zro=datamay_ratio[datamay_ratio[j]==0]
    a.append(zro)
    b.append(len(zro))
    one_zro_dict.update({i:a})
    one_zro_len_dict.update({i:b})
    a=[]
    b=[]
