# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\8\case_time_series_8.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
#no duplicated data

# %%
data_apr=data[62:]
#data_apr
len(data_apr)
# Out:
# 30

# %%
data_apr[data_apr.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
#no duplicated data

# %%
data_apr.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
count1=0
for i in list(data_apr.columns):
    for j in range(62,92):
        if(data_apr[i][j]=="NaN" or data_apr[i][j]=="" or data_apr[i][j]==" " or data_apr[i][j]=="?"):
            count1=count1+1
if(count1):
    print("yes")

# %%
count2=0
for j in range(62,92):
    if(data_apr["Date"][j]=="####"):
        count2=count2+1
if(count2):
    print("yes")

# %%
#no missing value

# %%
#data_apr.to_csv("coviddata_apr.csv")

# %%
dataap=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\monthly_case_series\coviddata_apr.csv")
dataap.head()
# Out:
#      Date  Daily Confirmed  Total Confirmed  Daily Recovered  Total Recovered  \
# 0  01-Apr              424             2059               19              169
# 1  02-Apr              486             2545               22              191
# 2  03-Apr              560             3105               39              230
# 3  04-Apr              579             3684               56              286
# 4  05-Apr              609             4293               43              329
#
#    Daily Deceased  Total Deceased
# 0               6              53
# 1              16              69
# 2              14              83
# 3              13              96
# 4              22             118

# %%
date=dataap["Date"]
date=list(date)

# %%
for i in range(len(date)):
    date[i]=date[i].strip("-Apr")

# %%
for i in range(len(date)):
    date[i]="2020-04-"+date[i]

# %%
dataap["Date"]=date

# %%
dataap['Date'] = dataap['Date'].astype('datetime64[ns]') 
dataap.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0              169               6              53
# 1              191              16              69
# 2              230              14              83
# 3              286              13              96
# 4              329              22             118

# %%
dataap.plot(x="Date",y="Daily Confirmed")

# %%
dataap.plot(x="Date",y="Total Confirmed")

# %%
dataap.plot(x="Date",y="Daily Recovered")

# %%
dataap.plot(x="Date",y="Total Recovered")

# %%
dataap.plot(x="Date",y="Daily Deceased")

# %%
dataap.plot(x="Date",y="Total Deceased")

# %%
dataapr=dataap.copy()
dataapr.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0              169               6              53
# 1              191              16              69
# 2              230              14              83
# 3              286              13              96
# 4              329              22             118

# %%
dataapr["Date_tmp"]=pd.Series(list(range(1,31)),index=list(range(0,30)))
dataapr.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased  Date_tmp
# 0              169               6              53         1
# 1              191              16              69         2
# 2              230              14              83         3
# 3              286              13              96         4
# 4              329              22             118         5

# %%
colss=list(data.columns)
colss.pop(0)
for m in colss:
    fig,axs=plt.subplots(2,2)
    count=1
    for i,j,k in zip(range(0,22,7),[[0,0],[0,1],[1,0],[1,1]],["blue","red","orange","green"]):
        count+=1
        a="tab"+":"+k
        
        if(count==5):
            x=dataapr["Date_tmp"][i:i+7+2]
            y=dataapr[m][i:i+7+2]
            axs[j[0],j[1]].plot(x,y,a)
            axs[0, 0].set_title(m)
            

        else:
        
            x=dataapr["Date_tmp"][i:i+7]
            y=dataapr[m][i:i+7]
            if(count<4):
                axs[j[0],j[1]].set_title(m)
            axs[j[0],j[1]].plot(x,y,a)

# %%
colss=list(data.columns)
colss.pop(0)
for m in colss:
    fig,axs=plt.subplots(2,2)
    count=1
    for i,j,k in zip(range(0,22,7),[[0,0],[0,1],[1,0],[1,1]],["blue","red","orange","green"]):
        count+=1
        a="tab"+":"+k
        
        if(count==5):
            x=dataapr["Date_tmp"][i:i+7+2]
            y=dataapr[m][i:i+7+2]
            
            

        else:
        
            x=dataapr["Date_tmp"][i:i+7]
            y=dataapr[m][i:i+7]
        if(count<4):
            axs[j[0],j[1]].set_title(m)
        axs[j[0],j[1]].plot(x,y,a)
        axs[j[0],j[1]].fill_between(x,0,y,color=k)

# %%
colss=list(data.columns)
colss.pop(0)
for m in colss:
    count=1
    for i,j in zip(range(0,15,14),["orange","red"]):
        fig,(axs1,axs2)=plt.subplots(1,2)
        fig.suptitle(m)
        fig.tight_layout(pad=2.0)

        x1=dataapr["Date_tmp"][i:i+7]
        y1=dataapr[m][i:i+7]
        if(count==2):
            x2=dataapr["Date_tmp"][i+7:i+14+2]
            y2=dataapr[m][i+7:i+14+2]
        else:
            x2=dataapr["Date_tmp"][i+7:i+14]
            y2=dataapr[m][i+7:i+14]
        count+=1
        a="tab"+":"+j
        axs1.plot(x1,y1,a)
        axs2.plot(x2,y2,a)

# %%
colss=list(data.columns)
colss.pop(0)
for m in colss:
    count=1
    for i,j in zip(range(0,15,14),["orange","red"]):
        fig,(axs1,axs2)=plt.subplots(1,2)
        fig.suptitle(m)
        fig.tight_layout(pad=2.0)

        x1=dataapr["Date_tmp"][i:i+7]
        y1=dataapr[m][i:i+7]
        if(count==2):
            x2=dataapr["Date_tmp"][i+7:i+14+2]
            y2=dataapr[m][i+7:i+14+2]
        else:
            x2=dataapr["Date_tmp"][i+7:i+14]
            y2=dataapr[m][i+7:i+14]
        count+=1
        a="tab"+":"+j
        axs1.plot(x1,y1,a)
        axs1.fill_between(x1,0,y1,color=j)
        axs2.plot(x2,y2,a)
        axs2.fill_between(x2,0,y2,color=j)

# %%
colss=list(data.columns)
colss.pop(0)
for m,n in zip(colss,["blue","black","orange","green","violet","red"]):
    dataapr.plot(x="Date",y=m,color=n)

# %%
colss=list(data.columns)
colss.pop(0)
for m,n in zip(colss,["blue","black","orange","green","violet","red"]):
    dataapr.plot(x="Date",y=m,color=n,kind="area")

# %%
dataapr_for_scattering=dataapr.copy()
dataapr_for_scattering.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased  Date_tmp
# 0              169               6              53         1
# 1              191              16              69         2
# 2              230              14              83         3
# 3              286              13              96         4
# 4              329              22             118         5

# %%
colls=list(dataapr_for_scattering.columns)
colls.pop(0)
colls.pop(len(colls)-1)
dataapr_for_scattering.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased  Date_tmp
# 0              169               6              53         1
# 1              191              16              69         2
# 2              230              14              83         3
# 3              286              13              96         4
# 4              329              22             118         5

# %%
colors=["Red","Violet","Orange","Yellow","Green","Black"]
for i,j in zip(colls,colors):
    dataapr_for_scattering.plot(x="Date_tmp",y=i,kind="scatter",color=j)

# %%
dataapr=dataapr.drop(["Date_tmp"], axis=1)
dataapr.reset_index(inplace = True, drop = True) 
dataapr.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0              169               6              53
# 1              191              16              69
# 2              230              14              83
# 3              286              13              96
# 4              329              22             118

# %%
dataapr_diff=dataapr.copy()
dataapr_diff.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0              169               6              53
# 1              191              16              69
# 2              230              14              83
# 3              286              13              96
# 4              329              22             118

# %%
new_cols=["Daily_Confirmed_Diff","Total_Confirmed_Diff","Daily_Recovered_Diff","Total_Recovered_Diff","Daily_Deceased_Diff","Total_Deceased_diff"]
existing_cols=list(dataapr_diff.columns)
existing_cols.pop(0)
existing_cols
prv_vals=[309,1635,13,150,6,47]
for i,j,l in zip(new_cols,existing_cols,prv_vals):
    dataapr_diff[i]=list(range(len(dataapr_diff)))
    dataapr_diff[i][0]=dataapr_diff[j][0]-l
    for k in range(0,len(dataapr_diff)-1):
        dataapr_diff[i][k+1]=dataapr_diff[j][k+1]-dataapr_diff[j][k]
dataapr_diff.head()
# Out:
# <ipython-input-38-98cc28922af1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataapr_diff[i][0]=dataapr_diff[j][0]-l
# <ipython-input-38-98cc28922af1>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataapr_diff[i][k+1]=dataapr_diff[j][k+1]-dataapr_diff[j][k]
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# ...

# %%
dataapr_diff["Total Confirmed"][24]-dataapr_diff["Total Confirmed"][23]==dataapr_diff["Total_Confirmed_Diff"][24]
# Out:
# True

# %%
dataapr_diff.describe()
# Out:
#        Daily Confirmed  Total Confirmed  Daily Recovered  Total Recovered  \
# count        30.000000        30.000000        30.000000        30.000000
# mean       1107.700000     14975.100000       296.966667      2874.300000
# std         472.721479     10101.546213       235.856982      2789.124497
# min         424.000000      2059.000000        19.000000       169.000000
# 25%         646.250000      6118.250000        80.250000       582.500000
# 50%        1046.000000     12901.500000       222.000000      1638.000000
# 75%        1560.250000     22623.250000       473.500000      4851.500000
# max        1902.000000     34866.000000       703.000000      9059.000000
#
#        Daily Deceased  Total Deceased  Daily_Confirmed_Diff  \
# count       30.000000       30.000000             30.000000
# mean        36.900000      483.300000             49.733333
# std         18.077134      328.006849            228.355430
# ...

# %%
colors=["Blue","Red","Yellow","Green","Orange","Violet"]
for i,j in zip(new_cols,colors):
    dataapr_diff.plot(x="Date",y=i,color=j)

# %%
dataapr_diff["Date_tmp"]=pd.Series(list(range(1,31)),index=list(range(0,30)))
dataapr_diff.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Diff  \
# 0              169               6              53                   115
# 1              191              16              69                    62
# 2              230              14              83                    74
# 3              286              13              96                    19
# 4              329              22             118                    30
#
#    Total_Confirmed_Diff  Daily_Recovered_Diff  Total_Recovered_Diff  \
# 0                   424                     6                    19
# ...

# %%
colss=list(dataapr_diff.columns)
for i in range(0,7):
    colss.pop(0)
colss.pop(len(colss)-1)
for m in colss:
    fig,axs=plt.subplots(2,2)
    count=1
    for i,j,k in zip(range(0,22,7),[[0,0],[0,1],[1,0],[1,1]],["blue","red","orange","green"]):
        count+=1
        a="tab"+":"+k
        
        if(count==5):
            x=dataapr_diff["Date_tmp"][i:i+7+2]
            y=dataapr_diff[m][i:i+7+2]
            

        else:
        
            x=dataapr_diff["Date_tmp"][i:i+7]
            y=dataapr_diff[m][i:i+7]
        if(count<4):
                axs[j[0],j[1]].set_title(m)
        axs[j[0],j[1]].plot(x,y,a)
        #axs[j[0],j[1]].fill_between(x,0,y,color=k)

# %%
dataapr_diff.drop(['Date_tmp'],axis=1)
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  2020-04-01              424             2059               19
# 1  2020-04-02              486             2545               22
# 2  2020-04-03              560             3105               39
# 3  2020-04-04              579             3684               56
# 4  2020-04-05              609             4293               43
# 5  2020-04-06              484             4777               65
# 6  2020-04-07              573             5350               75
# 7  2020-04-08              565             5915               96
# 8  2020-04-09              813             6728               70
# 9  2020-04-10              871             7599              151
# 10 2020-04-11              854             8453              186
# 11 2020-04-12              758             9211              114
# 12 2020-04-13             1243            10454              112
# ...

# %%
dataapr_diff.tail()
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 25 2020-04-26             1607            27890              585
# 26 2020-04-27             1568            29458              580
# 27 2020-04-28             1902            31360              636
# 28 2020-04-29             1705            33065              690
# 29 2020-04-30             1801            34866              630
#
#     Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Diff  \
# 25             6523              56             881                  -228
# 26             7103              58             939                   -39
# 27             7739              69            1008                   334
# 28             8429              71            1079                  -197
# 29             9059              75            1154                    96
#
#     Total_Confirmed_Diff  Daily_Recovered_Diff  Total_Recovered_Diff  \
# ...

# %%
#dataapr_diff.to_excel("dataapr_diff.xlsx")

# %%
kys=["daily_cnf_diff_pos_neg","total_cnf_diff_pos_neg","daily_rcvd_diff_pos_neg","total_rcvd_diff_pos_neg","daily_dcsd_diff_pos_neg","total_dcsd_diff_pos_neg"]
new_cols=["Daily_Confirmed_Diff","Total_Confirmed_Diff","Daily_Recovered_Diff","Total_Recovered_Diff","Daily_Deceased_Diff","Total_Deceased_diff"]
pos_neg_dict={}
pos_neg_len_dict={}
a=[]
b=[]
for i,j in zip(kys,new_cols):
    pos=dataapr_diff[dataapr_diff[j]>0]
    a.append(pos)
    b.append(len(pos))
    neg=dataapr_diff[dataapr_diff[j]<0]
    a.append(neg)
    b.append(len(neg))
    zro=dataapr_diff[dataapr_diff[j]==0]
    a.append(zro)
    b.append(len(zro))
    pos_neg_dict.update({i:a})
    pos_neg_len_dict.update({i:b})
    a=[]
    b=[]

# %%
dataapr_ratio_with_precision=dataapr.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(dataapr_ratio_with_precision.columns)
existing_cols.pop(0)
existing_cols
prv_vals=[309,1635,13,150,6,47]
for i,j,l in zip(new_cols,existing_cols,prv_vals):
    dataapr_ratio_with_precision[i]=list(range(len(dataapr_ratio_with_precision)))
    dataapr_ratio_with_precision[i][0]=round(dataapr_ratio_with_precision[j][0]/l,2)
    tmp=[]
    tmp.append(dataapr_ratio_with_precision[i][0])
    for k in range(0,len(dataapr_ratio_with_precision)-1):
        tmp.append(round(dataapr_ratio_with_precision[j][k+1]/dataapr_ratio_with_precision[j][k],2))
    dataapr_ratio_with_precision[i]=tmp
dataapr_ratio_with_precision.head()
# Out:
# <ipython-input-49-d374ef9abb21>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataapr_ratio_with_precision[i][0]=round(dataapr_ratio_with_precision[j][0]/l,2)
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0              169               6              53                   1.00
# 1              191              16              69                   1.15
# ...

# %%
round(dataapr_ratio_with_precision["Total Confirmed"][4]/dataapr_ratio_with_precision["Total Confirmed"][3],2)==dataapr_ratio_with_precision["Total_Confirmed_Ratio"][4]
# Out:
# True

# %%
colors=["Blue","Red","Yellow","Green","Orange","Violet"]
for i,j in zip(new_cols,colors):
    dataapr_ratio_with_precision.plot(x="Date",y=i,color=j)

# %%
dataapr_ratio=dataapr.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(dataapr_ratio.columns)
existing_cols.pop(0)
existing_cols
prv_vals=[309,1635,13,150,6,47]
for i,j,l in zip(new_cols,existing_cols,prv_vals):
    dataapr_ratio[i]=list(range(len(dataapr_ratio)))
    dataapr_ratio[i][0]=dataapr_ratio[j][0]/l
    tmp=[]
    tmp.append(dataapr_ratio[i][0])
    for k in range(0,len(dataapr_ratio)-1):
        tmp.append(dataapr_ratio[j][k+1]/dataapr_ratio[j][k])
    dataapr_ratio[i]=tmp
dataapr_ratio.head()
# Out:
# <ipython-input-53-d1a8f757711b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataapr_ratio[i][0]=dataapr_ratio[j][0]/l
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0              169               6              53               1.000000
# 1              191              16              69               1.146226
# ...

# %%
colors=["Blue","Red","Yellow","Green","Orange","Violet"]
for i,j in zip(new_cols,colors):
    dataapr_ratio.plot(x="Date",y=i,color=j)

# %%
dataapr_ratio["Date_tmp"]=pd.Series(list(range(1,31)),index=list(range(0,30)))
dataapr_ratio.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-04-01              424             2059               19
# 1 2020-04-02              486             2545               22
# 2 2020-04-03              560             3105               39
# 3 2020-04-04              579             3684               56
# 4 2020-04-05              609             4293               43
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0              169               6              53               1.000000
# 1              191              16              69               1.146226
# 2              230              14              83               1.152263
# 3              286              13              96               1.033929
# 4              329              22             118               1.051813
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# ...

# %%
colss=list(dataapr_ratio.columns)
for i in range(0,7):
    colss.pop(0)
colss.pop(len(colss)-1)
for m in colss:
    fig,axs=plt.subplots(2,2)
    count=1
    for i,j,k in zip(range(0,22,7),[[0,0],[0,1],[1,0],[1,1]],["blue","red","orange","green"]):
        count+=1
        a="tab"+":"+k
        
        if(count==5):
            x=dataapr_ratio["Date_tmp"][i:i+7+2]
            y=dataapr_ratio[m][i:i+7+2]
            

        else:
        
            x=dataapr_ratio["Date_tmp"][i:i+7]
            y=dataapr_ratio[m][i:i+7]
        if(count<4):
                axs[j[0],j[1]].set_title(m)
        axs[j[0],j[1]].plot(x,y,a)
        #axs[j[0],j[1]].fill_between(x,0,y,color=k)

# %%
dataapr_ratio.drop(['Date_tmp'],axis=1)
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  2020-04-01              424             2059               19
# 1  2020-04-02              486             2545               22
# 2  2020-04-03              560             3105               39
# 3  2020-04-04              579             3684               56
# 4  2020-04-05              609             4293               43
# 5  2020-04-06              484             4777               65
# 6  2020-04-07              573             5350               75
# 7  2020-04-08              565             5915               96
# 8  2020-04-09              813             6728               70
# 9  2020-04-10              871             7599              151
# 10 2020-04-11              854             8453              186
# 11 2020-04-12              758             9211              114
# 12 2020-04-13             1243            10454              112
# ...

# %%
#dataapr_ratio.to_excel("dataapr_ratio.xlsx")

# %%
kys=["daily_cnf_diff_rat10","total_cnf_diff_rat10","daily_rcvd_diff_rat10","total_rcvd_diff_rat10","daily_dcsd_diff_rat10","total_dcsd_diff_rat10"]
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
one_zro_dict={}
one_zro_len_dict={}
a=[]
b=[]
for i,j in zip(kys,new_cols):
    pos=dataapr_ratio[dataapr_ratio[j]>=1]
    a.append(pos)
    b.append(len(pos))
    neg=dataapr_ratio[dataapr_ratio[j]<1]
    a.append(neg)
    b.append(len(neg))
    zro=dataapr_ratio[dataapr_ratio[j]==0]
    a.append(zro)
    b.append(len(zro))
    one_zro_dict.update({i:a})
    one_zro_len_dict.update({i:b})
    a=[]
    b=[]

# %% [markdown]
# #####
