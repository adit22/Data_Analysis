# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *

# %%
data=pd.read_excel(r"C:\Users\Mark 1\Desktop\data\Covid-19\merged\case_time_series.xlsx")

# %%
data
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  2020-01-30                1                1                0
# 1  2020-01-31                0                1                0
# 2  2020-02-01                0                1                0
# 3  2020-02-02                1                2                0
# 4  2020-02-03                1                3                0
# 5  2020-02-04                0                3                0
# 6  2020-02-05                0                3                0
# 7  2020-02-06                0                3                0
# 8  2020-02-07                0                3                0
# 9  2020-02-08                0                3                0
# 10 2020-02-09                0                3                0
# 11 2020-02-10                0                3                0
# 12 2020-02-11                0                3                0
# ...

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
count1=0
for i in list(data.columns):
    for j in range(len(data)):
        if(data[i][j]=="NaN" or data[i][j]=="" or data[i][j]==" " or data[i][j]=="?"):
            count1=count1+1
if(count1):
    print("yes")

# %%
count2=0
for j in range(len(data)):
    if(data["Date"][j]=="####"):
        count2=count2+1
if(count2):
    print("yes")

# %%
#no missing values

# %%
data_feb=data[2:31]
#data_feb
len(data_feb)
# Out:
# 29

# %%
#data_feb.to_excel("coviddata_feb.xlsx")

# %%
data_mar=data[31:62]
#data_mar
len(data_mar)
# Out:
# 31

# %%
#data_mar.to_excel("coviddata_mar.xlsx")
