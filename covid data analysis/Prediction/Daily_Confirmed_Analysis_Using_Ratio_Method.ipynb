# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\33\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_daily=data[53:]
data_daily.reset_index(drop=True,inplace=True)
data_daily.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_daily.tail()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 130    31 July             57486          1697068            36554
# 131  01 August             55117          1752185            51368
# 132  02 August             52672          1804857            40355
# 133  03 August             50488          1855345            43070
# 134  04 August             51282          1906627            51220
#
#      Total Recovered  Daily Deceased  Total Deceased
# 130          1095538             764           36566
# 131          1146906             854           37420
# 132          1187261             760           38180
# 133          1230331             806           38986
# 134          1281551             849           39835

# %%
colls=list(data_daily.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_daily.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_daily[data_daily.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_daily['Date'] = data_daily['Date'].astype('str')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,9):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" March")
for i in range(0,9):
    data_daily["Date"][i]="2020-03-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(9,39):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" April")
for i in range(9,39):
    data_daily["Date"][i]="2020-04-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(39,70):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" May")
for i in range(39,70):
    data_daily["Date"][i]="2020-05-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(70,100):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" June")
for i in range(70,100):
    data_daily["Date"][i]="2020-06-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(100,131):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" July")
for i in range(100,131):
    data_daily["Date"][i]="2020-07-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(131,len(data_daily)):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" August")
for i in range(131,len(data_daily)):
    data_daily["Date"][i]="2020-08-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data_daily["Date"]=data_daily["Date"].astype('datetime64[ns]')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_daily["Date"][len(data_daily)-1]
# Out:
# Timestamp('2020-08-04 00:00:00')

# %%
data_daily.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_daily_ratio_with_two_precision=data_daily.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_daily_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_daily_ratio_with_two_precision[i]=list(range(len(data_daily_ratio_with_two_precision)))
    data_daily_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_daily_ratio_with_two_precision[i][0])
    for k in range(0,len(data_daily_ratio_with_two_precision)-1):
        tmp.append(round(data_daily_ratio_with_two_precision[j][k+1]/data_daily_ratio_with_two_precision[j][k],2))
    data_daily_ratio_with_two_precision[i]=tmp
data_daily_ratio_with_two_precision.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_daily_ratio=data_daily.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_daily_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_daily_ratio[i]=list(range(len(data_daily_ratio)))
    data_daily_ratio[i][0]=1
    tmp=[]
    tmp.append(data_daily_ratio[i][0])
    for k in range(0,len(data_daily_ratio)-1):
        tmp.append(data_daily_ratio[j][k+1]/data_daily_ratio[j][k])
    data_daily_ratio[i]=tmp
data_daily_ratio.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_daily_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_daily_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    dcr=data_daily_ratio.iloc[st:en,7:8]
    dcr.reset_index(inplace = True, drop = True)
    dc=data_daily_ratio.iloc[st:en,1:2]
    dc.reset_index(inplace = True, drop = True)



    next_day_confirmed_case_count_mean_based=dcr.mean()[0]*dc.mean()[0]

    next_day_confirmed_case_count_max_based=max(dcr["Daily_Confirmed_Ratio"])*max(dc["Daily Confirmed"])


    next_day_confirmed_case_count_mean_max_based=dcr.mean()[0]*max(dc["Daily Confirmed"])


    next_day_confirmed_case_count_max_mean_based=max(dcr["Daily_Confirmed_Ratio"])*dc.mean()[0]


    next_day_confirmed_case_count_mean_last_based=dcr.mean()[0]*dc["Daily Confirmed"][len(dc)-1]


    next_day_confirmed_case_count_last_mean_based=dcr["Daily_Confirmed_Ratio"][len(dcr)-1]*dc.mean()[0]


    next_day_confirmed_case_count_last_based=dcr["Daily_Confirmed_Ratio"][len(dcr)-1]*dc["Daily Confirmed"][len(dc)-1]


    next_day_confirmed_case_count_middle_based=dcr["Daily_Confirmed_Ratio"][3]*dc["Daily Confirmed"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_confirmed_case_count_mean_based))
    pred_val.append(np.round(next_day_confirmed_case_count_max_based))
    pred_val.append(np.round(next_day_confirmed_case_count_mean_max_based))
    pred_val.append(np.round(next_day_confirmed_case_count_max_mean_based))
    pred_val.append(np.round(next_day_confirmed_case_count_mean_last_based))
    pred_val.append(np.round(next_day_confirmed_case_count_last_mean_based))
    pred_val.append(np.round(next_day_confirmed_case_count_last_based))
    pred_val.append(np.round(next_day_confirmed_case_count_middle_based))

    if(en<len(data_daily_ratio)):
        pred_dict={"date":data_daily_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_daily_ratio["Daily Confirmed"][en],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_daily_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
   
    pred_df=pd.DataFrame(pred_dict, index=[0])
    
    
    
    d=pd.read_excel(r"C:\Users\Mark 1\amprd_df_strd.xlsx")
    d=pd.concat([d,pred_df])
    d.reset_index(drop=True,inplace=True)
    d.to_excel("amprd_df_strd.xlsx")

# %%
dc=pd.read_excel(r"C:/Users/Mark 1/amprd_df_strd.xlsx")
dc.tail()
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 625 2020-08-01         55117       52683      61378           58880
# 626 2020-08-02         52672       52934      61378           58343
# 627 2020-08-03         50488       53314      61378           58165
# 628 2020-08-04         51282       53958      61378           58236
# 629 2020-08-05             0       53799      60785           57809
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 625           54918            58880            53792       60119
# 626           55688            55938            50007       52846
# 627           56258            53294            50354       50335
# 628           56869            51146            51054       48395
# 629           56569            51570            54340       52088
#
#      middle_based
# 625         52991
# 626         55490
# 627         57575
# 628         60119
# 629         52846

# %%
dce=dc.copy()

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_daily_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_daily_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))
#print(len(strt_lst))
#print(len(end_lst))
# Out:
# 129

# %%
colls=list(dc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    dce[i]=pd.Series(range(1,len(dce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(dce)):
        dce[j][k]=dce["original_val"][k]-dce[i][k]
dce
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 600    636  -3984  -1620  -1512    -55   2632   2002   -369
# 601   2223  -1570    680    113   1582   2384   1748    169
# 602   1410  -3084   -836   -648   -836    -56  -2437   1924
# 603   3223   -718   1342   1310   1342   3594   1741   6617
# 604   2334  -2900   -847    509   -847   1196  -2128   3944
# 605   3340  -1551    730   1269    735   3902   1354    879
# 606   1466  -3963  -1787   -474  -1787    971  -2343   2157
# 607   2261  -2224   -166    369    793   4013   2637     32
# 608   3821   -430   1545   1991   1545   3172    844   4855
# 609   5696    -71   1680   4154   1680   4154    -71   4947
# 610   3277  -3837  -2332   1999  -2332   2064  -3760   7540
# 611   5233  -1246    739   3491   1409   6858   3227   5648
# 612   6284   -540   1155   4812   1155   5316     40   4696
# 613   1064  -7047  -5378   -350  -5378    142  -6466  -1774
# 614   2404  -4683  -2708    670    861   6857   5501   4986
# 615   7447   1748   3709   5661   4818   6602   3915   5406
# 616   7947  -4645    480   3620    480   3620  -4645   5171
# 617   6589  -7508  -1888   1907  -1888   6018  -2574  15219
# 618   5501  -6843  -1362    752  -1362   7318    735   8386
# 619   2774  -9361  -3389  -2494  -3389   3689  -2353  -4156
# 620   -334 -11809  -5134  -6388  -3959   2102  -1334  -4978
# 621   1152  -8662  -2239  -4851   1478   5174   5473    294
# 622   2428  -5814    584  -3743   1041    917   -512   1194
# 623   4650  -1064   1379   2356   1379   2865   -522   7150
# 624   6323  -1203   1473   3879   1473   4897    -89  13328
# 625   2434  -6261  -3763    199  -3763   1325  -5002   2126
# 626   -262  -8706  -5671  -3016  -3266   2665   -174  -2818
# 627  -2826 -10890  -7677  -5770  -2806    134    153  -7087
# 628  -2676 -10096  -6954  -5587    136    228   2887  -8837
# 629 -53799 -60785 -57809 -56569 -51570 -54340 -52088 -52846
#
# [630 rows x 8 columns]

# %%
for j,k in zip(range(len(edf)),range(len(dce)-1)):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(dce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)
# Out:
# for date: 2020-03-31  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-04-01  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-05  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-04-06  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-07  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-08  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-09  the lowest positve error was by the method: mxb and the highest negative error by the method: mb
# for date: 2020-04-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-11  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-12  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-04-13  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-04-14  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-15  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-16  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-17  the lowest positve error was by the method: mb and the highest negative error by the method: mb
# for date: 2020-04-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-04-19  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-04-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-21  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-22  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-23  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-24  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-04-25  the lowest positve error was by the method: memb and the highest negative error by the method: mdb
# for date: 2020-04-26  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-27  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-28  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-29  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-30  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-05-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-03  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-05  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-07  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-08  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-09  the lowest positve error was by the method: mdb and the highest negative error by the method: lmb
# for date: 2020-05-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-11  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-05-12  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-13  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-05-14  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-17  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-18  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-05-20  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-21  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-05-22  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-05-23  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-24  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-25  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-05-26  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-28  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-05-29  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-30  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-31  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-01  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-02  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-06-03  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-05  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-06-07  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-06-08  the lowest positve error was by the method: memb and the highest negative error by the method: mb
# for date: 2020-06-09  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-10  the lowest positve error was by the method: memb and the highest negative error by the method: mdb
# for date: 2020-06-11  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-12  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-06-13  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-14  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-16  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-06-17  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-06-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-06-19  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-20  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-21  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-22  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-06-23  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-06-24  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-06-25  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-29  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-06-30  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-07-01  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-07-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-03  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-06  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-07  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-07-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-09  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-07-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-12  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-13  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-14  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-15  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-19  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-22  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-07-23  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-25  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-26  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-27  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-07-28  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-29  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-30  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-31  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-08-01  the lowest positve error was by the method: memb and the highest negative error by the method: mb
# for date: 2020-03-31  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-04-01  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-05  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-04-06  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-07  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-08  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-09  the lowest positve error was by the method: mxb and the highest negative error by the method: mb
# for date: 2020-04-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-11  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-12  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-04-13  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-04-14  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-15  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-16  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-17  the lowest positve error was by the method: mb and the highest negative error by the method: mb
# for date: 2020-04-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-04-19  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-04-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-21  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-22  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-23  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-24  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-04-25  the lowest positve error was by the method: memb and the highest negative error by the method: mdb
# for date: 2020-04-26  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-27  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-28  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-29  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-30  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-05-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-03  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-05  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-07  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-08  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-09  the lowest positve error was by the method: mdb and the highest negative error by the method: lmb
# for date: 2020-05-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-11  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-05-12  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-13  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-05-14  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-17  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-18  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-05-20  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-21  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-05-22  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-05-23  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-24  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-25  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-05-26  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-28  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-05-29  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-30  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-31  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-01  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-02  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-06-03  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-05  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-06-07  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-06-08  the lowest positve error was by the method: memb and the highest negative error by the method: mb
# for date: 2020-06-09  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-10  the lowest positve error was by the method: memb and the highest negative error by the method: mdb
# for date: 2020-06-11  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-12  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-06-13  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-14  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-16  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-06-17  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-06-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-06-19  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-20  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-21  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-22  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-06-23  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-06-24  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-06-25  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-29  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-06-30  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-07-01  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-07-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-03  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-06  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-07  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-07-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-09  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-07-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-12  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-13  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-14  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-15  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-19  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-22  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-07-23  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-25  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-26  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-27  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-07-28  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-29  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-30  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-31  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-08-01  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-08-02  the lowest positve error was by the method: lmb and the highest negative error by the method: lmb
# for date: 2020-03-31  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-04-01  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-05  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-04-06  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-07  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-08  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-09  the lowest positve error was by the method: mxb and the highest negative error by the method: mb
# for date: 2020-04-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-11  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-12  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-04-13  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-04-14  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-15  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-16  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-17  the lowest positve error was by the method: mb and the highest negative error by the method: mb
# for date: 2020-04-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-04-19  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-04-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-21  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-22  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-23  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-24  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-04-25  the lowest positve error was by the method: memb and the highest negative error by the method: mdb
# for date: 2020-04-26  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-27  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-28  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-29  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-30  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-05-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-03  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-05  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-07  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-08  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-09  the lowest positve error was by the method: mdb and the highest negative error by the method: lmb
# for date: 2020-05-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-11  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-05-12  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-13  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-05-14  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-17  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-18  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-05-20  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-21  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-05-22  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-05-23  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-24  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-25  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-05-26  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-28  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-05-29  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-30  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-31  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-01  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-02  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-06-03  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-05  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-06-07  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-06-08  the lowest positve error was by the method: memb and the highest negative error by the method: mb
# for date: 2020-06-09  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-10  the lowest positve error was by the method: memb and the highest negative error by the method: mdb
# for date: 2020-06-11  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-12  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-06-13  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-14  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-16  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-06-17  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-06-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-06-19  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-20  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-21  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-22  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-06-23  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-06-24  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-06-25  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-29  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-06-30  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-07-01  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-07-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-03  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-06  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-07  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-07-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-09  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-07-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-12  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-13  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-14  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-15  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-19  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-22  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-07-23  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-25  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-26  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-27  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-07-28  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-29  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-30  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-31  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-08-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-08-02  the lowest positve error was by the method: lmb and the highest negative error by the method: lb
# for date: 2020-08-03  the lowest positve error was by the method: lmb and the highest negative error by the method: lb
# for date: 2020-03-31  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-04-01  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-05  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-04-06  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-07  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-08  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-09  the lowest positve error was by the method: mxb and the highest negative error by the method: mb
# for date: 2020-04-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-11  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-12  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-04-13  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-04-14  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-15  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-16  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-17  the lowest positve error was by the method: mb and the highest negative error by the method: mb
# for date: 2020-04-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-04-19  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-04-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-21  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-22  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-23  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# ...
# for date: 2020-07-30  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-31  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-08-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-08-02  the lowest positve error was by the method: lmb and the highest negative error by the method: lb
# for date: 2020-08-03  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-08-04  the lowest positve error was by the method: lmb and the highest negative error by the method: lb
# for date: 2020-03-31  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-04-01  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-05  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-04-06  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-07  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-08  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-09  the lowest positve error was by the method: mxb and the highest negative error by the method: mb
# for date: 2020-04-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-11  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-12  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-04-13  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-04-14  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-15  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-16  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-17  the lowest positve error was by the method: mb and the highest negative error by the method: mb
# for date: 2020-04-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-04-19  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-04-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-04-21  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-22  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-04-23  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-24  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-04-25  the lowest positve error was by the method: memb and the highest negative error by the method: mdb
# for date: 2020-04-26  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-27  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-28  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-04-29  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-30  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-05-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-03  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-05  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-07  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-08  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-09  the lowest positve error was by the method: mdb and the highest negative error by the method: lmb
# for date: 2020-05-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-11  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-05-12  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-13  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-05-14  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-17  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-18  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-05-20  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-21  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-05-22  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-05-23  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-24  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-25  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-05-26  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-28  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-05-29  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-05-30  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-31  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-01  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-02  the lowest positve error was by the method: mlb and the highest negative error by the method: memb
# for date: 2020-06-03  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-05  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-06-07  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-06-08  the lowest positve error was by the method: memb and the highest negative error by the method: mb
# for date: 2020-06-09  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-10  the lowest positve error was by the method: memb and the highest negative error by the method: mdb
# for date: 2020-06-11  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-12  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-06-13  the lowest positve error was by the method: memb and the highest negative error by the method: mxmb
# for date: 2020-06-14  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-16  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-06-17  the lowest positve error was by the method: mdb and the highest negative error by the method: mxb
# for date: 2020-06-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-06-19  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-20  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-21  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-22  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-06-23  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-06-24  the lowest positve error was by the method: lmb and the highest negative error by the method: mdb
# for date: 2020-06-25  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-29  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-06-30  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-07-01  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-07-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-03  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-06  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-07  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-07-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-09  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-07-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mxb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-12  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-13  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-14  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-15  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-19  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-20  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-22  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-07-23  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-25  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-26  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-27  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-07-28  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-29  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-30  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-07-31  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-08-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-08-02  the lowest positve error was by the method: lmb and the highest negative error by the method: lb
# for date: 2020-08-03  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-08-04  the lowest positve error was by the method: mlb and the highest negative error by the method: mb

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(dce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(dce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(dce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(dce["date"][k]).strip("00:00:00"))
    org_val.append(dce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-08-02 ',
#   '2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-08-02 ',
#   '2020-08-03 ',
#   '2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-08-02 ',
#   '2020-08-03 ',
#   '2020-08-04 ',
#   '2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-08-02 ',
#   '2020-08-03 ',
#   '2020-08-04 ',
#   '2020-08-05 '],
#  'mipe': ['lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lmb',
#   'mlb',
#   'No',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mdb',
#   'mb',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'lmb',
#   'No',
#   'mlb',
#   'No',
#   'mlb',
#   'mdb',
#   'memb',
#   'mb',
#   'mb',
#   'mlb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'memb',
#   'lmb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'mb',
#   'memb',
#   'mdb',
#   'lb',
#   'memb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mb',
#   'mlb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'mb',
#   'lb',
#   'memb',
#   'mb',
#   'No',
#   'mlb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'lb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'lmb',
#   'mdb',
#   'lb',
#   'memb',
#   'mxmb',
#   'memb',
#   'lb',
#   'lmb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mdb',
#   'memb',
#   'memb',
#   'memb',
#   'No',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lmb',
#   'mlb',
#   'No',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mdb',
#   'mb',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'lmb',
#   'No',
#   'mlb',
#   'No',
#   'mlb',
#   'mdb',
#   'memb',
#   'mb',
#   'mb',
#   'mlb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'memb',
#   'lmb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'mb',
#   'memb',
#   'mdb',
#   'lb',
#   'memb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mb',
#   'mlb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'mb',
#   'lb',
#   'memb',
#   'mb',
#   'No',
#   'mlb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'lb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'lmb',
#   'mdb',
#   'lb',
#   'memb',
#   'mxmb',
#   'memb',
#   'lb',
#   'lmb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mdb',
#   'memb',
#   'memb',
#   'memb',
#   'lmb',
#   'No',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lmb',
#   'mlb',
#   'No',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mdb',
#   'mb',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'lmb',
#   'No',
#   'mlb',
#   'No',
#   'mlb',
#   'mdb',
#   'memb',
#   'mb',
#   'mb',
#   'mlb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'memb',
#   'lmb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'mb',
#   'memb',
#   'mdb',
#   'lb',
#   'memb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mb',
#   'mlb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'mb',
#   'lb',
#   'memb',
#   'mb',
#   'No',
#   'mlb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'lb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'lmb',
#   'mdb',
#   'lb',
#   'memb',
#   'mxmb',
#   'memb',
#   'lb',
#   'lmb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mdb',
#   'memb',
#   'memb',
#   'memb',
#   'mxmb',
#   'lmb',
#   'No',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lmb',
#   'mlb',
#   'No',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mdb',
#   'mb',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'lmb',
#   'No',
#   'mlb',
#   'No',
#   'mlb',
#   'mdb',
#   'memb',
#   'mb',
#   'mb',
#   'mlb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'memb',
#   'lmb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'mb',
#   'memb',
#   'mdb',
#   'lb',
#   'memb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mb',
#   'mlb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'mb',
#   'lb',
#   'memb',
#   'mb',
#   'No',
#   'mlb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'lb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'lmb',
#   'mdb',
#   'lb',
#   'memb',
#   'mxmb',
#   'memb',
#   'lb',
#   'lmb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mdb',
#   'memb',
#   'memb',
#   'memb',
#   'mxmb',
#   'lmb',
#   'lmb',
#   'No',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lmb',
#   'mlb',
#   'No',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mdb',
#   'mb',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'lmb',
#   'No',
#   'mlb',
#   'No',
#   'mlb',
#   'mdb',
#   'memb',
#   'mb',
#   'mb',
#   'mlb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'memb',
#   'lmb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'mb',
#   'memb',
#   'mdb',
#   'lb',
#   'memb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mb',
#   'mlb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'mb',
#   'lb',
#   'memb',
#   'mb',
#   'No',
#   'mlb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'lb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'lmb',
#   'mdb',
#   'lb',
#   'memb',
#   'mxmb',
#   'memb',
#   'lb',
#   'lmb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mdb',
#   'memb',
#   'memb',
#   'memb',
#   'mxmb',
#   'lmb',
#   'lmb',
#   'mlb',
#   'No'],
#  'mxne': ['mdb',
#   'lb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'No',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'memb',
#   'mb',
#   'memb',
#   'mb',
#   'mdb',
#   'memb',
#   'mlb',
#   'memb',
#   'lmb',
#   'mlb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'lmb',
#   'memb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'mlb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mlb',
#   'mxmb',
#   'lmb',
#   'lmb',
#   'mb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'lb',
#   'mlb',
#   'mxb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'No',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'mb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'mb',
#   'mdb',
#   'lb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'No',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'memb',
#   'mb',
#   'memb',
#   'mb',
#   'mdb',
#   'memb',
#   'mlb',
#   'memb',
#   'lmb',
#   'mlb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'lmb',
#   'memb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'mlb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mlb',
#   'mxmb',
#   'lmb',
#   'lmb',
#   'mb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'lb',
#   'mlb',
#   'mxb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'No',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'mb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'mxmb',
#   'lmb',
#   'mdb',
#   'lb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'No',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'memb',
#   'mb',
#   'memb',
#   'mb',
#   'mdb',
#   'memb',
#   'mlb',
#   'memb',
#   'lmb',
#   'mlb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'lmb',
#   'memb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'mlb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mlb',
#   'mxmb',
#   'lmb',
#   'lmb',
#   'mb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'lb',
#   'mlb',
#   'mxb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'No',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'mb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'mdb',
#   'lb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'No',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'memb',
#   'mb',
#   'memb',
#   'mb',
#   'mdb',
#   'memb',
#   'mlb',
#   'memb',
#   'lmb',
#   'mlb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'lmb',
#   'memb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'mlb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mlb',
#   'mxmb',
#   'lmb',
#   'lmb',
#   'mb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'lb',
#   'mlb',
#   'mxb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'No',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'mb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'mlb',
#   'lb',
#   'mdb',
#   'lb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'No',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'memb',
#   'mb',
#   'memb',
#   'mb',
#   'mdb',
#   'memb',
#   'mlb',
#   'memb',
#   'lmb',
#   'mlb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'lmb',
#   'memb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mdb',
#   'mb',
#   'mlb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'mlb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mlb',
#   'mxmb',
#   'lmb',
#   'lmb',
#   'mb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'lb',
#   'mlb',
#   'mxb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'No',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'mb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'mlb',
#   'mb',
#   'mlb'],
#  'mipv': [18,
#   23,
#   66,
#   3,
#   54,
#   10,
#   10,
#   6,
#   'No',
#   92,
#   11,
#   161,
#   27,
#   73,
#   82,
#   31,
#   46,
#   'No',
#   81,
#   35,
#   'No',
#   266,
#   'No',
#   270,
#   436,
#   16,
#   0,
#   17,
#   251,
#   15,
#   35,
#   194,
#   129,
#   208,
#   257,
#   215,
#   172,
#   140,
#   235,
#   761,
#   235,
#   488,
#   39,
#   25,
#   93,
#   6,
#   357,
#   52,
#   337,
#   838,
#   714,
#   705,
#   87,
#   612,
#   75,
#   72,
#   122,
#   158,
#   439,
#   653,
#   553,
#   106,
#   11,
#   838,
#   313,
#   268,
#   285,
#   188,
#   107,
#   'No',
#   114,
#   1,
#   816,
#   192,
#   363,
#   387,
#   'No',
#   778,
#   288,
#   297,
#   150,
#   207,
#   1248,
#   797,
#   1077,
#   51,
#   31,
#   96,
#   1259,
#   174,
#   154,
#   1106,
#   462,
#   1103,
#   131,
#   502,
#   653,
#   616,
#   636,
#   113,
#   1410,
#   1310,
#   509,
#   730,
#   971,
#   32,
#   844,
#   1680,
#   1999,
#   739,
#   40,
#   142,
#   670,
#   1748,
#   480,
#   1907,
#   735,
#   2774,
#   2102,
#   294,
#   584,
#   1379,
#   1199,
#   'No',
#   18,
#   23,
#   66,
#   3,
#   54,
#   10,
#   10,
#   6,
#   'No',
#   92,
#   11,
#   161,
#   27,
#   73,
#   82,
#   31,
#   46,
#   'No',
#   81,
#   35,
#   'No',
#   266,
#   'No',
#   270,
#   436,
#   16,
#   0,
#   17,
#   251,
#   15,
#   35,
#   194,
#   129,
#   208,
#   257,
#   215,
#   172,
#   140,
#   235,
#   761,
#   235,
#   488,
#   39,
#   25,
#   93,
#   6,
#   357,
#   52,
#   337,
#   838,
#   714,
#   705,
#   87,
#   612,
#   75,
#   72,
#   122,
#   158,
#   439,
#   653,
#   553,
#   106,
#   11,
#   838,
#   313,
#   268,
#   285,
#   188,
#   107,
#   'No',
#   114,
#   1,
#   816,
#   192,
#   363,
#   387,
#   'No',
#   778,
#   288,
#   297,
#   150,
#   207,
#   1248,
#   797,
#   1077,
#   51,
#   31,
#   96,
#   1259,
#   174,
#   154,
#   1106,
#   462,
#   1103,
#   131,
#   502,
#   653,
#   616,
#   636,
#   113,
#   1410,
#   1310,
#   509,
#   730,
#   971,
#   32,
#   844,
#   1680,
#   1999,
#   739,
#   40,
#   142,
#   670,
#   1748,
#   480,
#   1907,
#   735,
#   2774,
#   2102,
#   294,
#   584,
#   1379,
#   1473,
#   1073,
#   'No',
#   18,
#   23,
#   66,
#   3,
#   54,
#   10,
#   10,
#   6,
#   'No',
#   92,
#   11,
#   161,
#   27,
#   73,
#   82,
#   31,
#   46,
#   'No',
#   81,
#   35,
#   'No',
#   266,
#   'No',
#   270,
#   436,
#   16,
#   0,
#   17,
#   251,
#   15,
#   35,
#   194,
#   129,
#   208,
#   257,
#   215,
#   172,
#   140,
#   235,
#   761,
#   235,
#   488,
#   39,
#   25,
#   93,
#   6,
#   357,
#   52,
#   337,
#   838,
#   714,
#   705,
#   87,
#   612,
#   75,
#   72,
#   122,
#   158,
#   439,
#   653,
#   553,
#   106,
#   11,
#   838,
#   313,
#   268,
#   285,
#   188,
#   107,
#   'No',
#   114,
#   1,
#   816,
#   192,
#   363,
#   387,
#   'No',
#   778,
#   288,
#   297,
#   150,
#   207,
#   1248,
#   797,
#   1077,
#   51,
#   31,
#   96,
#   1259,
#   174,
#   154,
#   1106,
#   462,
#   1103,
#   131,
#   502,
#   653,
#   616,
#   636,
#   113,
#   1410,
#   1310,
#   509,
#   730,
#   971,
#   32,
#   844,
#   1680,
#   1999,
#   739,
#   40,
#   142,
#   670,
#   1748,
#   480,
#   1907,
#   735,
#   2774,
#   2102,
#   294,
#   584,
#   1379,
#   1473,
#   199,
#   2524,
#   'No',
#   18,
#   23,
#   66,
#   3,
#   54,
#   10,
#   10,
#   6,
#   'No',
#   92,
#   11,
#   161,
#   27,
#   73,
#   82,
#   31,
#   46,
#   'No',
#   81,
#   35,
#   'No',
#   266,
#   'No',
#   270,
#   436,
#   16,
#   0,
#   17,
#   251,
#   15,
#   35,
#   194,
#   129,
#   208,
#   257,
#   215,
#   172,
#   140,
#   235,
#   761,
#   235,
#   488,
#   39,
#   25,
#   93,
#   6,
#   357,
#   52,
#   337,
#   838,
#   714,
#   705,
#   87,
#   612,
#   75,
#   72,
#   122,
#   158,
#   439,
#   653,
#   553,
#   106,
#   11,
#   838,
#   313,
#   268,
#   285,
#   188,
#   107,
#   'No',
#   114,
#   1,
#   816,
#   192,
#   363,
#   387,
#   'No',
#   778,
#   288,
#   297,
#   150,
#   207,
#   1248,
#   797,
#   1077,
#   51,
#   31,
#   96,
#   1259,
#   174,
#   154,
#   1106,
#   462,
#   1103,
#   131,
#   502,
#   653,
#   616,
#   636,
#   113,
#   1410,
#   1310,
#   509,
#   730,
#   971,
#   32,
#   844,
#   1680,
#   1999,
#   739,
#   40,
#   142,
#   670,
#   1748,
#   480,
#   1907,
#   735,
#   2774,
#   2102,
#   294,
#   584,
#   1379,
#   1473,
#   199,
#   2665,
#   134,
#   'No',
#   18,
#   23,
#   66,
#   3,
#   54,
#   10,
#   10,
#   6,
#   'No',
#   92,
#   11,
#   161,
#   27,
#   73,
#   82,
#   31,
#   46,
#   'No',
#   81,
#   35,
#   'No',
#   266,
#   'No',
#   270,
#   436,
#   16,
#   0,
#   17,
#   251,
#   15,
#   35,
#   194,
#   129,
#   208,
#   257,
#   215,
#   172,
#   140,
#   235,
#   761,
#   235,
#   488,
#   39,
#   25,
#   93,
#   6,
#   357,
#   52,
#   337,
#   838,
#   714,
#   705,
#   87,
#   612,
#   75,
#   72,
#   122,
#   158,
#   439,
#   653,
#   553,
#   106,
#   11,
#   838,
#   313,
#   268,
#   285,
#   188,
#   107,
#   'No',
#   114,
#   1,
#   816,
#   192,
#   363,
#   387,
#   'No',
#   778,
#   288,
#   297,
#   150,
#   207,
#   1248,
#   797,
#   1077,
#   51,
#   31,
#   96,
#   1259,
#   174,
#   154,
#   1106,
#   462,
#   1103,
#   131,
#   502,
#   653,
#   616,
#   636,
#   113,
#   1410,
#   1310,
#   509,
#   730,
#   971,
#   32,
#   844,
#   1680,
#   1999,
#   739,
#   40,
#   142,
#   670,
#   1748,
#   480,
#   1907,
#   735,
#   2774,
#   2102,
#   294,
#   584,
#   1379,
#   1473,
#   199,
#   2665,
#   134,
#   136,
#   'No'],
#  'mxnv': [-12,
#   -87,
#   -77,
#   -106,
#   -66,
#   -20,
#   -73,
#   -5,
#   -21,
#   'No',
#   -17,
#   -70,
#   -79,
#   -10,
#   -299,
#   -95,
#   -308,
#   -99,
#   -211,
#   -124,
#   -32,
#   -83,
#   -40,
#   -42,
#   -95,
#   -72,
#   -348,
#   -80,
#   -30,
#   -250,
#   -1,
#   -83,
#   -55,
#   -459,
#   -271,
#   -32,
#   -344,
#   -55,
#   -56,
#   -24,
#   -56,
#   -142,
#   5318,
#   6449,
#   6055,
#   7036,
#   6342,
#   5785,
#   7088,
#   6815,
#   7485,
#   7811,
#   8683,
#   7712,
#   7974,
#   9376,
#   9579,
#   9187,
#   10220,
#   10775,
#   'No',
#   9867,
#   11155,
#   10319,
#   11114,
#   11676,
#   11018,
#   'No',
#   10308,
#   12820,
#   13532,
#   14590,
#   15711,
#   13903,
#   12763,
#   14579,
#   16817,
#   18174,
#   18159,
#   18883,
#   19436,
#   18185,
#   17150,
#   18967,
#   20844,
#   22587,
#   23516,
#   23289,
#   21884,
#   22511,
#   25448,
#   24380,
#   26452,
#   27248,
#   28376,
#   27207,
#   29885,
#   31763,
#   33788,
#   32821,
#   36672,
#   40195,
#   36664,
#   38500,
#   43853,
#   47963,
#   46981,
#   49337,
#   46158,
#   44382,
#   49337,
#   51895,
#   53589,
#   56013,
#   'No',
#   291,
#   401,
#   420,
#   557,
#   525,
#   599,
#   474,
#   567,
#   'No',
#   721,
#   860,
#   693,
#   731,
#   1170,
#   949,
#   855,
#   1015,
#   'No',
#   1290,
#   1545,
#   'No',
#   1271,
#   'No',
#   1397,
#   972,
#   1819,
#   1607,
#   1551,
#   1651,
#   1690,
#   1766,
#   2202,
#   2435,
#   2744,
#   3399,
#   2756,
#   3430,
#   3204,
#   3104,
#   2414,
#   4076,
#   3104,
#   3523,
#   3701,
#   3898,
#   3802,
#   4437,
#   4997,
#   4291,
#   5316,
#   5006,
#   5318,
#   6449,
#   6055,
#   7036,
#   6342,
#   5785,
#   7088,
#   6815,
#   7485,
#   7811,
#   8683,
#   7712,
#   7974,
#   9376,
#   9579,
#   9187,
#   10220,
#   10775,
#   'No',
#   9867,
#   11155,
#   10319,
#   11114,
#   11676,
#   11018,
#   'No',
#   10308,
#   12820,
#   13532,
#   14590,
#   15711,
#   13903,
#   12763,
#   14579,
#   16817,
#   18174,
#   18159,
#   18883,
#   19436,
#   18185,
#   17150,
#   18967,
#   20844,
#   22587,
#   23516,
#   23289,
#   21884,
#   22511,
#   25448,
#   24380,
#   26452,
#   27248,
#   28376,
#   27207,
#   29885,
#   31763,
#   33788,
#   32821,
#   36672,
#   40195,
#   36664,
#   38500,
#   43853,
#   47963,
#   46981,
#   49337,
#   46158,
#   44382,
#   49337,
#   51895,
#   53589,
#   56013,
#   53792,
#   'No',
#   291,
#   401,
#   420,
#   557,
#   525,
#   599,
#   474,
#   567,
#   'No',
#   721,
#   860,
#   693,
#   731,
#   1170,
#   949,
#   855,
#   1015,
#   'No',
#   1290,
#   1545,
#   'No',
#   1271,
#   'No',
#   1397,
#   972,
#   1819,
#   1607,
#   1551,
#   1651,
#   1690,
#   1766,
#   2202,
#   2435,
#   2744,
#   3399,
#   2756,
#   3430,
#   3204,
#   3104,
#   2414,
#   4076,
#   3104,
#   3523,
#   3701,
#   3898,
#   3802,
#   4437,
#   4997,
#   4291,
#   5316,
#   5006,
#   5318,
#   6449,
#   6055,
#   7036,
#   6342,
#   5785,
#   7088,
#   6815,
#   7485,
#   7811,
#   8683,
#   7712,
#   7974,
#   9376,
#   9579,
#   9187,
#   10220,
#   10775,
#   'No',
#   9867,
#   11155,
#   10319,
#   11114,
#   11676,
#   11018,
#   'No',
#   10308,
#   12820,
#   13532,
#   14590,
#   15711,
#   13903,
#   12763,
#   14579,
#   16817,
#   18174,
#   18159,
#   18883,
#   19436,
#   18185,
#   17150,
#   18967,
#   20844,
#   22587,
#   23516,
#   23289,
#   21884,
#   22511,
#   25448,
#   24380,
#   26452,
#   27248,
#   28376,
#   27207,
#   29885,
#   31763,
#   33788,
#   32821,
#   36672,
#   40195,
#   36664,
#   38500,
#   43853,
#   47963,
#   46981,
#   49337,
#   46158,
#   44382,
#   49337,
#   51895,
#   53589,
#   56013,
#   54918,
#   50007,
#   'No',
#   291,
#   401,
#   420,
#   557,
#   525,
#   599,
#   474,
#   567,
#   'No',
#   721,
#   860,
#   693,
#   731,
#   1170,
#   949,
#   855,
#   1015,
#   'No',
#   1290,
#   1545,
#   'No',
#   1271,
#   'No',
#   1397,
#   972,
#   1819,
#   1607,
#   1551,
#   1651,
#   1690,
#   1766,
#   2202,
#   2435,
#   2744,
#   3399,
#   2756,
#   3430,
#   3204,
#   3104,
#   2414,
#   4076,
#   3104,
#   3523,
#   3701,
#   3898,
#   3802,
#   4437,
#   4997,
#   4291,
#   5316,
#   5006,
#   5318,
#   6449,
#   6055,
#   7036,
#   6342,
#   5785,
#   7088,
#   6815,
#   7485,
#   7811,
#   8683,
#   7712,
#   7974,
#   9376,
#   9579,
#   9187,
#   10220,
#   10775,
#   'No',
#   9867,
#   11155,
#   10319,
#   11114,
#   11676,
#   11018,
#   'No',
#   10308,
#   12820,
#   13532,
#   14590,
#   15711,
#   13903,
#   12763,
#   14579,
#   16817,
#   18174,
#   18159,
#   18883,
#   19436,
#   18185,
#   17150,
#   18967,
#   20844,
#   22587,
#   23516,
#   23289,
#   21884,
#   22511,
#   25448,
#   24380,
#   26452,
#   27248,
#   28376,
#   27207,
#   29885,
#   31763,
#   33788,
#   32821,
#   36672,
#   40195,
#   36664,
#   38500,
#   43853,
#   47963,
#   46981,
#   49337,
#   46158,
#   44382,
#   49337,
#   51895,
#   53589,
#   56013,
#   54918,
#   50007,
#   50354,
#   'No',
#   291,
#   401,
#   420,
#   557,
#   525,
#   599,
#   474,
#   567,
#   'No',
#   721,
#   860,
#   693,
#   731,
#   1170,
#   949,
#   855,
#   1015,
#   'No',
#   1290,
#   1545,
#   'No',
#   1271,
#   'No',
#   1397,
#   972,
#   1819,
#   1607,
#   1551,
#   1651,
#   1690,
#   1766,
#   2202,
#   2435,
#   2744,
#   3399,
#   2756,
#   3430,
#   3204,
#   3104,
#   2414,
#   4076,
#   3104,
#   3523,
#   3701,
#   3898,
#   3802,
#   4437,
#   4997,
#   4291,
#   5316,
#   5006,
#   5318,
#   6449,
#   6055,
#   7036,
#   6342,
#   5785,
#   7088,
#   6815,
#   7485,
#   7811,
#   8683,
#   7712,
#   7974,
#   9376,
#   9579,
#   9187,
#   10220,
#   15222,
#   14022,
#   15711,
#   17190,
#   19475,
#   18995,
#   21077,
#   20902,
#   19092,
#   18305,
#   20440,
#   22224,
#   24791,
#   25662,
#   24671,
#   23866,
#   23202,
#   27131,
#   25846,
#   28480,
#   28604,
#   30657,
#   28652,
#   30083,
#   33037,
#   35539,
#   37152,
#   38657,
#   40775,
#   37156,
#   41878,
#   'No',
#   53088,
#   50776,
#   51434,
#   51285,
#   46818,
#   51870,
#   52991,
#   55490,
#   57575,
#   58880,
#   52846,
#   53294,
#   48395,
#   321,
#   511,
#   563,
#   666,
#   645,
#   629,
#   557,
#   578,
#   586,
#   'No',
#   888,
#   924,
#   837,
#   1253,
#   1330,
#   981,
#   1369,
#   1021,
#   1582,
#   1704,
#   1271,
#   1620,
#   1332,
#   1709,
#   1503,
#   1907,
#   1955,
#   1648,
#   1932,
#   1955,
#   1802,
#   2479,
#   2619,
#   3411,
#   3927,
#   3003,
#   3946,
#   3399,
#   3395,
#   3199,
#   4367,
#   3734,
#   3640,
#   4479,
#   4377,
#   3932,
#   5075,
#   5145,
#   5130,
#   6356,
#   6035,
#   6139,
#   6589,
#   7093,
#   7746,
#   6470,
#   6727,
#   7717,
#   7530,
#   8260,
#   8439,
#   8838,
#   7823,
#   9075,
#   9871,
#   10133,
#   10002,
#   11235,
#   11436,
#   9877,
#   11026,
#   11436,
#   11222,
#   11415,
#   12261,
#   11414,
#   10226,
#   11310,
#   13456,
#   15499,
#   16351,
#   17428,
#   15222,
#   14022,
#   15711,
#   17190,
#   19475,
#   18995,
#   21077,
#   20902,
#   19092,
#   18305,
#   20440,
#   22224,
#   24791,
#   25662,
#   24671,
#   23866,
#   23202,
#   27131,
#   25846,
#   28480,
#   28604,
#   30657,
#   28652,
#   30083,
#   33037,
#   35539,
#   37152,
#   38657,
#   40775,
#   37156,
#   41878,
#   'No',
#   53088,
#   50776,
#   51434,
#   51285,
#   46818,
#   51870,
#   52991,
#   55490,
#   57575,
#   58880,
#   52846,
#   53294,
#   53958,
#   51570]}

# %%
err_df=pd.DataFrame(err_dict)
err_df
# Out:
#             date  mipe  mxne  mipv    mxnv  original_val pprd_val nprd_val
# 0    2020-03-31     lb   mdb    18     -12           309      291      321
# 1    2020-04-01   memb    lb    23     -87           424      401      511
# 2    2020-04-02   mxmb  memb    66     -77           486      420      563
# 3    2020-04-03     lb  memb     3    -106           560      557      666
# 4    2020-04-04   mxmb    lb    54     -66           579      525      645
# 5    2020-04-05     lb  mxmb    10     -20           609      599      629
# 6    2020-04-06    lmb   mdb    10     -73           484      474      557
# 7    2020-04-07    mlb    mb     6      -5           573      567      578
# 8    2020-04-08     No    mb    No     -21           565       No      586
# 9    2020-04-09    mxb    No    92      No           813      721       No
# 10   2020-04-10   mxmb  memb    11     -17           871      860      888
# 11   2020-04-11     mb  mxmb   161     -70           854      693      924
# 12   2020-04-12     mb    lb    27     -79           758      731      837
# 13   2020-04-13    mdb   mxb    73     -10          1243     1170     1253
# 14   2020-04-14     mb  mxmb    82    -299          1031      949     1330
# 15   2020-04-15     lb    mb    31     -95           886      855      981
# 16   2020-04-16     mb  memb    46    -308          1061     1015     1369
# 17   2020-04-17     No    mb    No     -99           922       No     1021
# 18   2020-04-18   memb  mxmb    81    -211          1371     1290     1582
# 19   2020-04-19    lmb  mxmb    35    -124          1580     1545     1704
# 20   2020-04-20     No   mdb    No     -32          1239       No     1271
# 21   2020-04-21    mlb  memb   266     -83          1537     1271     1620
# 22   2020-04-22     No    mb    No     -40          1292       No     1332
# 23   2020-04-23    mlb  memb   270     -42          1667     1397     1709
# 24   2020-04-24    mdb    mb   436     -95          1408      972     1503
# 25   2020-04-25   memb   mdb    16     -72          1835     1819     1907
# 26   2020-04-26     mb  memb     0    -348          1607     1607     1955
# 27   2020-04-27     mb   mlb    17     -80          1568     1551     1648
# 28   2020-04-28    mlb  memb   251     -30          1902     1651     1932
# 29   2020-04-29     mb   lmb    15    -250          1705     1690     1955
# ..           ...   ...   ...   ...     ...           ...      ...      ...
# 600  2020-07-07     mb   mlb   636     -55         23147    22511    23202
# 601  2020-07-08   mxmb   mxb   113   -1570         25561    25448    27131
# 602  2020-07-09     mb   lmb  1410     -56         25790    24380    25846
# 603  2020-07-10   mxmb   mxb  1310    -718         27762    26452    28480
# 604  2020-07-11   mxmb  memb   509    -847         27757    27248    28604
# 605  2020-07-12   memb   mxb   730   -1551         29106    28376    30657
# 606  2020-07-13    lmb  mxmb   971    -474         28178    27207    28652
# 607  2020-07-14    mdb  memb    32    -166         29917    29885    30083
# 608  2020-07-15     lb   mxb   844    -430         32607    31763    33037
# 609  2020-07-16   memb   mxb  1680     -71         35468    33788    35539
# 610  2020-07-17   mxmb  memb  1999   -2332         34820    32821    37152
# 611  2020-07-18   memb   mxb   739   -1246         37411    36672    38657
# 612  2020-07-19     lb   mxb    40    -540         40235    40195    40775
# 613  2020-07-20    lmb  mxmb   142    -350         36806    36664    37156
# 614  2020-07-21   mxmb  memb   670   -2708         39170    38500    41878
# 615  2020-07-22    mxb    No  1748      No         45601    43853       No
# 616  2020-07-23   memb   mxb   480   -4645         48443    47963    53088
# 617  2020-07-24   mxmb  memb  1907   -1888         48888    46981    50776
# 618  2020-07-25     lb  memb   735   -1362         50072    49337    51434
# 619  2020-07-26     mb    lb  2774   -2353         48932    46158    51285
# 620  2020-07-27    lmb    mb  2102    -334         46484    44382    46818
# 621  2020-07-28    mdb  memb   294   -2239         49631    49337    51870
# 622  2020-07-29   memb    lb   584    -512         52479    51895    52991
# 623  2020-07-30   memb    lb  1379    -522         54968    53589    55490
# 624  2020-07-31   memb    lb  1473     -89         57486    56013    57575
# 625  2020-08-01   mxmb  memb   199   -3763         55117    54918    58880
# 626  2020-08-02    lmb    lb  2665    -174         52672    50007    52846
# 627  2020-08-03    lmb   mlb   134   -2806         50488    50354    53294
# 628  2020-08-04    mlb    mb   136   -2676         51282    51146    53958
# 629  2020-08-05     No   mlb    No  -51570             0       No    51570
#
# [630 rows x 8 columns]

# %%
err_df.to_excel("dcerr_df.xlsx")
