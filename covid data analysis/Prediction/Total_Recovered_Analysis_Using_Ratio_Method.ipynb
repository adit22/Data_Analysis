# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\30\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_total=data[53:]
data_total.reset_index(drop=True,inplace=True)
data_total.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_total.tail()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 127    28 July             49631          1532135            35683
# 128    29 July             52479          1584614            32886
# 129    30 July             54968          1639582            37425
# 130    31 July             57486          1697068            36554
# 131  01 August             54865          1751933            51232
#
#      Total Recovered  Daily Deceased  Total Deceased
# 127           988673             774           34243
# 128          1021559             775           35018
# 129          1058984             784           35802
# 130          1095538             764           36566
# 131          1146770             852           37418

# %%
colls=list(data_total.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_total.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_total[data_total.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_total['Date'] = data_total['Date'].astype('str')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,9):
    data_total["Date"][i]=data_total["Date"][i].strip(" March")
for i in range(0,9):
    data_total["Date"][i]="2020-03-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(9,39):
    data_total["Date"][i]=data_total["Date"][i].strip(" April")
for i in range(9,39):
    data_total["Date"][i]="2020-04-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(39,70):
    data_total["Date"][i]=data_total["Date"][i].strip(" May")
for i in range(39,70):
    data_total["Date"][i]="2020-05-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(70,100):
    data_total["Date"][i]=data_total["Date"][i].strip(" June")
for i in range(70,100):
    data_total["Date"][i]="2020-06-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(100,131):
    data_total["Date"][i]=data_total["Date"][i].strip(" July")
for i in range(100,131):
    data_total["Date"][i]="2020-07-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(131,len(data_total)):
    data_total["Date"][i]=data_total["Date"][i].strip(" August")
for i in range(131,len(data_total)):
    data_total["Date"][i]="2020-08-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data_total["Date"]=data_total["Date"].astype('datetime64[ns]')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_total.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_total_ratio_with_two_precision=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio_with_two_precision[i]=list(range(len(data_total_ratio_with_two_precision)))
    data_total_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio_with_two_precision[i][0])
    for k in range(0,len(data_total_ratio_with_two_precision)-1):
        tmp.append(round(data_total_ratio_with_two_precision[j][k+1]/data_total_ratio_with_two_precision[j][k],2))
    data_total_ratio_with_two_precision[i]=tmp
data_total_ratio_with_two_precision.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_total_ratio=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio[i]=list(range(len(data_total_ratio)))
    data_total_ratio[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio[i][0])
    for k in range(0,len(data_total_ratio)-1):
        tmp.append(data_total_ratio[j][k+1]/data_total_ratio[j][k])
    data_total_ratio[i]=tmp
data_total_ratio.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_total_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_total_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    dcr=data_total_ratio.iloc[st:en,10:11]
    dcr.reset_index(inplace = True, drop = True)
    dc=data_total_ratio.iloc[st:en,4:5]
    dc.reset_index(inplace = True, drop = True)



    next_day_recovered_case_count_mean_based=dcr.mean()[0]*dc.mean()[0]

    next_day_recovered_case_count_max_based=max(dcr["Total_Recovered_Ratio"])*max(dc["Total Recovered"])


    next_day_recovered_case_count_mean_max_based=dcr.mean()[0]*max(dc["Total Recovered"])


    next_day_recovered_case_count_max_mean_based=max(dcr["Total_Recovered_Ratio"])*dc.mean()[0]


    next_day_recovered_case_count_mean_last_based=dcr.mean()[0]*dc["Total Recovered"][len(dc)-1]


    next_day_recovered_case_count_last_mean_based=dcr["Total_Recovered_Ratio"][len(dcr)-1]*dc.mean()[0]


    next_day_recovered_case_count_last_based=dcr["Total_Recovered_Ratio"][len(dcr)-1]*dc["Total Recovered"][len(dc)-1]


    next_day_recovered_case_count_middle_based=dcr["Total_Recovered_Ratio"][3]*dc["Total Recovered"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_recovered_case_count_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_middle_based))


    
    if(en<len(data_total_ratio)):
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_total_ratio["Total Recovered"][en],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
        
        
        
    
    
    pred_df=pd.DataFrame(pred_dict, index=[0])
    
    
    
    d=pd.read_excel(r"C:\Users\Mark 1\tramprd_df_strd.xlsx")
    d=pd.concat([d,pred_df])
    d.reset_index(drop=True,inplace=True)
    d.to_excel("tramprd_df_strd.xlsx")

# %%
tc=pd.read_excel(r"C:\Users\Mark 1\tramprd_df_strd.xlsx")
tc.tail()
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 244 2020-07-29       1021559      920837    1031855         1028034
# 245 2020-07-30       1058984      954905    1066177         1060900
# 246 2020-07-31       1095538      989935    1105237         1098879
# 247 2020-08-01       1146770     1025591    1143387         1135987
# 248 2020-08-02             0     1064505    1200398         1189617
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 244          924260          1028034           918740     1025692
# 245          959655          1060900           950080     1055539
# 246          995662          1098879           988945     1097780
# 247         1032271          1135987          1023213     1133354
# 248         1074152          1189617          1074152     1200398
#
#      middle_based
# 244        925870
# 245        951267
# 246        988629
# 247       1025692
# 248       1055539

# %%
tce=tc.copy()

# %%
colls=list(tc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    tce[i]=pd.Series(range(1,len(tce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(tce)):
        tce[j][k]=tce["original_val"][k]-tce[i][k]
tce
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31           150          98        219             176
# 1   2020-04-01           169         111        225             182
# 2   2020-04-02           191         134        254             207
# 3   2020-04-03           230         158        286             233
# 4   2020-04-04           286         179        309             270
# 5   2020-04-05           329         215        384             341
# 6   2020-04-06           394         253        442             390
# 7   2020-04-07           469         291        490             459
# 8   2020-04-08           565         348        583             552
# 9   2020-04-09           635         418        703             672
# 10  2020-04-10           786         493        790             754
# 11  2020-04-11           972         590        977             937
# 12  2020-04-12          1086         706       1203            1158
# 13  2020-04-13          1198         832       1344            1289
# 14  2020-04-14          1365         957       1483            1406
# 15  2020-04-15          1509        1101       1690            1592
# 16  2020-04-16          1767        1243       1868            1738
# 17  2020-04-17          2040        1437       2187            2047
# 18  2020-04-18          2466        1628       2523            2339
# 19  2020-04-19          2854        1866       2981            2818
# 20  2020-04-20          3273        2166       3450            3278
# 21  2020-04-21          3976        2520       3956            3780
# 22  2020-04-22          4370        2978       4830            4634
# 23  2020-04-23          5012        3452       5309            5089
# 24  2020-04-24          5496        3980       6089            5820
# 236          681665           749592           679983      749841
# 237          705806           778279           705806      780923
# 238          734108           812103           734108      817385
# 239          761137           847228           761137      852227
# 240          790315           882422           788249      883806
# 241          822438           921928           822438      925870
# 242          854977           954937           848297      951267
# 243          889015           991015           883666      988629
# 244          924260          1028034           918740     1025692
# 245          959655          1060900           950080     1055539
# 246          995662          1098879           988945     1097780
# 247         1032271          1135987          1023213     1133354
# 248         1074152          1189617          1074152     1200398
#
#      middle_based       mb      mxb     memb     mxmb      mlb      lmb  \
# 0             112       52      -69      -26       28      -26       48
# 1              96       58      -56      -13       31      -13       69
# 2             122       57      -63      -16       26      -16       67
# 3             184       72      -56       -3       35       -3       83
# 4             164      107      -23       16       82       16      103
# 5             190      114      -55      -12       86      -12      104
# 6             216      141      -48        4      108        4      149
# 7             277      178      -21       10      158       10      170
# 8             356      217      -18       13      198       13      213
# 9             378      217      -68      -37      197      -37      211
# 10            472      293       -4       32      269       32      319
# 11            558      382       -5       35      357       35      359
# 12            681      380     -117      -72      352      -72      353
# 13            714      366     -146      -91      330      -91      415
# 14            973      408     -118      -41      355      -41      465
# 15           1202      408     -181      -83      341      -83      434
# 16           1213      524     -101       29      432       29      574
# 17           1322      603     -147       -7      505       -7      587
# 18           1555      838      -57      127      710      127      827
# 19           1668      988     -127       36      880       36      880
# 20           2069     1107     -177       -5      994       -5     1091
# 21           2355     1456       20      196     1338      196     1474
# 22           2981     1392     -460     -264     1266     -264     1266
# 23           3303     1560     -297      -77     1412      -77     1755
# 24           3754     1516     -593     -324     1333     -324     1565
# 25           4830     1417     -738     -398     1175     -398     1638
# 26           4803     1512     -690     -214     1157     -214     1751
# 27           5748     1538     -821     -243     1101     -243     1675
# 28           6027     1604     -890     -201     1072     -201     1763
# 29           6416     1801     -447      -84     1518      -84     1864
# ..            ...      ...      ...      ...      ...      ...      ...
# 219        360876    44530    -7165    -1771    39743    -1771    45907
# 220        372386    46191    -6902     -681    40655     -681    47270
# 221        401013    46116    -8295    -1906    40421    -1906    46811
# 222        409284    47686    -7625     -635    41433     -635    49120
# 223        424363    50929    -5889     1319    44473     1319    51564
# 224        441337    52522    -7073     -102    46291     -102    51780
# 225        456077    56491     -880     1036    54781     1036    55648
# 226        474526    58183    -2054     -278    56600     -278    57417
# 227        496895    57412    -4690    -2945    55856    -2945    57759
# 228        516160    56198    -5982    -3801    54244    -3801    58588
# 229        537370    57907    -3442     -853    55574     -853    61136
# 230        556986    58497    -4669    -1851    55956    -1851    59174
# 231        573246    61647    -2240      278    59373      278    62754
# 232        590360    58577    -8566    -5640    55935    -5640    58032
# 233        614836    62898    -1733     1090    60333     1090    67020
# 234        635101    64961    -2519     -318    62965     -318    63705
# 235        660322    67739    -1793      522    65639      522    68001
# 236        672035    72527      588     2692    70619     2692    72301
# 237        702095    80742     3236     5880    78353     5880    78353
# 238        723884    88120      100     5382    83377     5382    83377
# 239        749841    93327    -2228     2771    88862     2771    88862
# 240        780923   100110     1001     4702    96809     4702    98875
# 241        817385    99700    -7234    -3292    96198    -3292    96198
# 242        852227   101421    -5769    -1947    98013    -1947   104693
# 243        883806   102874    -5940    -2342    99658    -2342   105007
# 244        925870   100722   -10296    -6475    97299    -6475   102819
# 245        951267   104079    -7193    -1916    99329    -1916   108904
# 246        988629   105603    -9699    -3341    99876    -3341   106593
# 247       1025692   121179     3383    10783   114499    10783   123557
# 248       1055539 -1064505 -1200398 -1189617 -1074152 -1189617 -1074152
#
#           lb      mdb
# 0        -34       38
# 1          5       73
# 2          1       69
# 3         14       46
# 4          9      122
# 5        -27      139
# 6         16      178
# 7         -3      192
# 8          7      209
# 9        -46      257
# 10        72      314
# 11        -1      414
# 12      -116      405
# 13       -15      484
# 14        43      392
# 15       -46      307
# 16        99      554
# 17       -29      718
# 18       111      911
# 19      -127     1186
# 20       -30     1204
# 21       222     1621
# 22      -460     1389
# 23       209     1709
# 24      -252     1742
# 25       -89     1108
# 26       107     1720
# 27       -63     1355
# 28         4     1712
# 29        -3     2013
# ..       ...      ...
# 219     -218    48190
# 220      532    52509
# 221    -1127    39197
# 222      969    47762
# 223     2028    52191
# 224     -933    54625
# 225       91    60174
# 226    -1138    61706
# 227    -2556    57535
# 228    -1133    55953
# 229     2730    55720
# 230    -1100    56750
# 231     1502    63357
# 232    -6243    63719
# 233     5627    62826
# 234    -1703    65291
# 235      811    64373
# 236     2443    80249
# 237     3236    82064
# 238      100    93601
# 239    -2228   100158
# 240     3318   106201
# 241    -7234   101251
# 242     1723   100763
# 243       44   104867
# 244    -4133    95689
# 245     3445   107717
# 246    -2242   106909
# 247    13416   121078
# 248 -1200398 -1055539
#
# [249 rows x 18 columns]

# %%
tce.to_excel("tramerrprd_df_strd.xlsx")

# %%
edf=tce.iloc[0:len(tce),10:]
edf
# Out:
#           mb      mxb     memb     mxmb      mlb      lmb       lb      mdb
# 0         52      -69      -26       28      -26       48      -34       38
# 1         58      -56      -13       31      -13       69        5       73
# 2         57      -63      -16       26      -16       67        1       69
# 3         72      -56       -3       35       -3       83       14       46
# 4        107      -23       16       82       16      103        9      122
# 5        114      -55      -12       86      -12      104      -27      139
# 6        141      -48        4      108        4      149       16      178
# 7        178      -21       10      158       10      170       -3      192
# 8        217      -18       13      198       13      213        7      209
# 9        217      -68      -37      197      -37      211      -46      257
# 10       293       -4       32      269       32      319       72      314
# 11       382       -5       35      357       35      359       -1      414
# 12       380     -117      -72      352      -72      353     -116      405
# 13       366     -146      -91      330      -91      415      -15      484
# 14       408     -118      -41      355      -41      465       43      392
# 15       408     -181      -83      341      -83      434      -46      307
# 16       524     -101       29      432       29      574       99      554
# 17       603     -147       -7      505       -7      587      -29      718
# 18       838      -57      127      710      127      827      111      911
# 19       988     -127       36      880       36      880     -127     1186
# 20      1107     -177       -5      994       -5     1091      -30     1204
# 21      1456       20      196     1338      196     1474      222     1621
# 22      1392     -460     -264     1266     -264     1266     -460     1389
# 23      1560     -297      -77     1412      -77     1755      209     1709
# 24      1516     -593     -324     1333     -324     1565     -252     1742
# 25      1417     -738     -398     1175     -398     1638      -89     1108
# 26      1512     -690     -214     1157     -214     1751      107     1720
# 27      1538     -821     -243     1101     -243     1675      -63     1355
# 28      1604     -890     -201     1072     -201     1763        4     1712
# 29      1801     -447      -84     1518      -84     1864       -3     2013
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 219    44530    -7165    -1771    39743    -1771    45907     -218    48190
# 220    46191    -6902     -681    40655     -681    47270      532    52509
# 221    46116    -8295    -1906    40421    -1906    46811    -1127    39197
# 222    47686    -7625     -635    41433     -635    49120      969    47762
# 223    50929    -5889     1319    44473     1319    51564     2028    52191
# 224    52522    -7073     -102    46291     -102    51780     -933    54625
# 225    56491     -880     1036    54781     1036    55648       91    60174
# 226    58183    -2054     -278    56600     -278    57417    -1138    61706
# 227    57412    -4690    -2945    55856    -2945    57759    -2556    57535
# 228    56198    -5982    -3801    54244    -3801    58588    -1133    55953
# 229    57907    -3442     -853    55574     -853    61136     2730    55720
# 230    58497    -4669    -1851    55956    -1851    59174    -1100    56750
# 231    61647    -2240      278    59373      278    62754     1502    63357
# 232    58577    -8566    -5640    55935    -5640    58032    -6243    63719
# 233    62898    -1733     1090    60333     1090    67020     5627    62826
# 234    64961    -2519     -318    62965     -318    63705    -1703    65291
# 235    67739    -1793      522    65639      522    68001      811    64373
# 236    72527      588     2692    70619     2692    72301     2443    80249
# 237    80742     3236     5880    78353     5880    78353     3236    82064
# 238    88120      100     5382    83377     5382    83377      100    93601
# 239    93327    -2228     2771    88862     2771    88862    -2228   100158
# 240   100110     1001     4702    96809     4702    98875     3318   106201
# 241    99700    -7234    -3292    96198    -3292    96198    -7234   101251
# 242   101421    -5769    -1947    98013    -1947   104693     1723   100763
# 243   102874    -5940    -2342    99658    -2342   105007       44   104867
# 244   100722   -10296    -6475    97299    -6475   102819    -4133    95689
# 245   104079    -7193    -1916    99329    -1916   108904     3445   107717
# 246   105603    -9699    -3341    99876    -3341   106593    -2242   106909
# 247   121179     3383    10783   114499    10783   123557    13416   121078
# 248 -1064505 -1200398 -1189617 -1074152 -1189617 -1074152 -1200398 -1055539
#
# [249 rows x 8 columns]

# %%
for j,k in zip(range(len(edf)),range(len(tce)-1)):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(tce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)
# Out:
# for date: 2020-03-31  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-01  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-02  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-06  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-04-07  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-08  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-09  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-10  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-04-11  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-12  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-14  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-15  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-04-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-04-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-18  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-19  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-04-20  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-21  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-04-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-23  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-25  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-04-26  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-27  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-28  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-29  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-01  the lowest positve error was by the method: mxb and the highest negative error by the method: lb
# for date: 2020-05-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-04  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-05  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-07  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-09  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-10  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-12  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-15  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-16  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-05-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-19  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-20  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-05-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-24  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-25  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-26  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-27  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-29  the lowest positve error was by the method: mxb and the highest negative error by the method: lb
# for date: 2020-05-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-31  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-06-02  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-03  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-06-04  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-05  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-06  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-07  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-09  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-10  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-12  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-06-13  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-06-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-15  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-06-16  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-06-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-19  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-06-20  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-06-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-22  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-06-24  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-25  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-29  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-02  the lowest positve error was by the method: mxb and the highest negative error by the method: lb
# for date: 2020-07-03  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-05  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-06  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-07-07  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-08  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-09  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-10  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-12  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-14  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-15  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-20  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-21  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-07-22  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-07-23  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-07-24  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-25  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-07-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-27  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-28  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-29  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-07-30  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-31  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-08-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-03-31  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-01  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-02  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-04  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-06  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-04-07  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-08  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-09  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-10  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-04-11  the lowest positve error was by the method: memb and the highest negative error by the method: lb
# for date: 2020-04-12  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-14  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-15  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-04-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-04-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-18  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-19  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-04-20  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-21  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-04-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-23  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-25  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-04-26  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-27  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-28  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-04-29  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-01  the lowest positve error was by the method: mxb and the highest negative error by the method: lb
# for date: 2020-05-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-03  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-04  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-05  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-05-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-07  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-09  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-10  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-12  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-15  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-05-16  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-05-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-19  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-20  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-05-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-24  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-25  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-26  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-05-27  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-05-29  the lowest positve error was by the method: mxb and the highest negative error by the method: lb
# for date: 2020-05-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-31  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-06-02  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-03  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-06-04  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-05  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-06  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-07  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-09  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-10  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-12  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-06-13  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-06-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-15  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-06-16  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-06-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-19  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-06-20  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-06-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-22  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-06-24  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-25  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-06-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-27  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-06-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-29  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-06-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-02  the lowest positve error was by the method: mxb and the highest negative error by the method: lb
# for date: 2020-07-03  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-05  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-06  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-07-07  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-08  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-09  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-10  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-12  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-14  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-15  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-16  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-18  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-20  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-21  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-07-22  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-07-23  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-07-24  the lowest positve error was by the method: memb and the highest negative error by the method: mxb
# for date: 2020-07-25  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-07-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-27  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-28  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-29  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-07-30  the lowest positve error was by the method: lb and the highest negative error by the method: memb
# for date: 2020-07-31  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-08-01  the lowest positve error was by the method: mxb and the highest negative error by the method: lb

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(tce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(tce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(tce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(tce["date"][k]).strip("00:00:00"))
    org_val.append(tce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-08-02 '],
#  'mipe': ['mxmb',
#   'lb',
#   'lb',
#   'lb',
#   'lb',
#   'mxmb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mdb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'memb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'mdb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mdb',
#   'lb',
#   'mxmb',
#   'No',
#   'mxmb',
#   'lb',
#   'lb',
#   'lb',
#   'lb',
#   'mxmb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mdb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'memb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'mdb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mdb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'No'],
#  'mxne': ['memb',
#   'memb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'No',
#   'memb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'No',
#   'memb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxb',
#   'No',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'No',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'No',
#   'No',
#   'memb',
#   'No',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'No',
#   'memb',
#   'memb',
#   'lb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'lb',
#   'No',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'No',
#   'No',
#   'No',
#   'mxb',
#   'No',
#   'memb',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lmb',
#   'memb',
#   'memb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'No',
#   'memb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'No',
#   'memb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxb',
#   'No',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'No',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'mxb',
#   'memb',
#   'No',
#   'No',
#   'memb',
#   'No',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'No',
#   'memb',
#   'memb',
#   'lb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'lb',
#   'No',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'No',
#   'No',
#   'No',
#   'mxb',
#   'No',
#   'memb',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'No',
#   'mdb'],
#  'mipv': [28,
#   5,
#   1,
#   14,
#   9,
#   86,
#   4,
#   10,
#   7,
#   197,
#   32,
#   35,
#   352,
#   330,
#   43,
#   307,
#   29,
#   505,
#   111,
#   36,
#   994,
#   20,
#   1266,
#   209,
#   1333,
#   1108,
#   107,
#   1101,
#   4,
#   1518,
#   1483,
#   70,
#   2190,
#   11,
#   48,
#   113,
#   3116,
#   114,
#   3396,
#   229,
#   13,
#   4115,
#   16,
#   4922,
#   4775,
#   105,
#   1397,
#   6553,
#   6474,
#   383,
#   6621,
#   7079,
#   7035,
#   6118,
#   581,
#   8462,
#   416,
#   8999,
#   9018,
#   6946,
#   10617,
#   401,
#   8322,
#   485,
#   4817,
#   458,
#   195,
#   220,
#   13306,
#   14599,
#   17,
#   395,
#   16905,
#   211,
#   470,
#   20538,
#   1736,
#   22206,
#   21065,
#   1585,
#   22580,
#   543,
#   27320,
#   1443,
#   28058,
#   935,
#   232,
#   30560,
#   238,
#   35265,
#   1430,
#   35542,
#   34202,
#   1476,
#   39836,
#   39743,
#   532,
#   39197,
#   969,
#   1319,
#   46291,
#   91,
#   56600,
#   55856,
#   54244,
#   2730,
#   55956,
#   278,
#   55935,
#   1090,
#   62965,
#   522,
#   588,
#   3236,
#   100,
#   2771,
#   1001,
#   96198,
#   1723,
#   44,
#   95689,
#   3445,
#   99876,
#   'No',
#   28,
#   5,
#   1,
#   14,
#   9,
#   86,
#   4,
#   10,
#   7,
#   197,
#   32,
#   35,
#   352,
#   330,
#   43,
#   307,
#   29,
#   505,
#   111,
#   36,
#   994,
#   20,
#   1266,
#   209,
#   1333,
#   1108,
#   107,
#   1101,
#   4,
#   1518,
#   1483,
#   70,
#   2190,
#   11,
#   48,
#   113,
#   3116,
#   114,
#   3396,
#   229,
#   13,
#   4115,
#   16,
#   4922,
#   4775,
#   105,
#   1397,
#   6553,
#   6474,
#   383,
#   6621,
#   7079,
#   7035,
#   6118,
#   581,
#   8462,
#   416,
#   8999,
#   9018,
#   6946,
#   10617,
#   401,
#   8322,
#   485,
#   4817,
#   458,
#   195,
#   220,
#   13306,
#   14599,
#   17,
#   395,
#   16905,
#   211,
#   470,
#   20538,
#   1736,
#   22206,
#   21065,
#   1585,
#   22580,
#   543,
#   27320,
#   1443,
#   28058,
#   935,
#   232,
#   30560,
#   238,
#   35265,
#   1430,
#   35542,
#   34202,
#   1476,
#   39836,
#   39743,
#   532,
#   39197,
#   969,
#   1319,
#   46291,
#   91,
#   56600,
#   55856,
#   54244,
#   2730,
#   55956,
#   278,
#   55935,
#   1090,
#   62965,
#   522,
#   588,
#   3236,
#   100,
#   2771,
#   1001,
#   96198,
#   1723,
#   44,
#   95689,
#   3445,
#   99876,
#   3383,
#   'No'],
#  'mxnv': [-26,
#   -13,
#   -16,
#   -3,
#   -23,
#   -12,
#   -48,
#   -3,
#   -18,
#   -37,
#   -4,
#   -1,
#   -72,
#   -15,
#   -41,
#   -46,
#   -101,
#   -7,
#   -57,
#   -127,
#   -5,
#   'No',
#   -264,
#   -77,
#   -252,
#   -89,
#   -214,
#   -63,
#   -201,
#   -3,
#   -122,
#   'No',
#   -67,
#   -66,
#   -167,
#   -69,
#   -111,
#   -150,
#   -433,
#   -130,
#   -277,
#   -228,
#   -368,
#   -28,
#   -527,
#   -188,
#   'No',
#   -395,
#   -244,
#   -217,
#   -153,
#   -211,
#   -67,
#   -926,
#   -434,
#   -471,
#   -314,
#   'No',
#   189162,
#   195066,
#   206631,
#   215204,
#   'No',
#   239571,
#   248910,
#   259516,
#   275470,
#   289413,
#   299511,
#   315222,
#   324051,
#   336099,
#   349338,
#   360876,
#   'No',
#   395703,
#   409284,
#   425576,
#   441337,
#   457681,
#   482443,
#   496064,
#   517131,
#   536510,
#   556986,
#   573246,
#   593943,
#   614836,
#   638843,
#   659719,
#   679395,
#   700710,
#   726488,
#   'No',
#   'No',
#   'No',
#   852227,
#   'No',
#   921928,
#   954937,
#   991015,
#   1025692,
#   1060900,
#   1097780,
#   1023213,
#   176,
#   182,
#   207,
#   233,
#   309,
#   341,
#   442,
#   472,
#   583,
#   672,
#   790,
#   973,
#   1158,
#   1213,
#   1406,
#   1555,
#   1868,
#   2047,
#   2523,
#   2981,
#   3278,
#   'No',
#   4634,
#   5089,
#   5748,
#   6027,
#   6737,
#   7166,
#   7940,
#   8432,
#   9181,
#   'No',
#   10919,
#   11829,
#   13012,
#   14209,
#   15412,
#   16926,
#   18320,
#   19431,
#   21247,
#   22777,
#   24822,
#   26445,
#   28538,
#   30433,
#   'No',
#   37190,
#   39521,
#   42526,
#   45575,
#   48764,
#   51900,
#   55335,
#   58128,
#   61177,
#   64605,
#   68088,
#   71342,
#   'No',
#   88381,
#   93013,
#   97069,
#   102252,
#   105020,
#   110731,
#   115331,
#   119642,
#   124051,
#   129249,
#   135210,
#   141114,
#   147168,
#   'No',
#   'No',
#   169760,
#   'No',
#   189162,
#   195066,
#   206631,
#   215204,
#   'No',
#   239571,
#   248910,
#   259516,
#   275470,
#   289413,
#   299511,
#   315222,
#   324051,
#   336099,
#   349338,
#   360876,
#   'No',
#   395703,
#   409284,
#   425576,
#   441337,
#   457681,
#   482443,
#   496064,
#   517131,
#   536510,
#   556986,
#   573246,
#   593943,
#   614836,
#   638843,
#   659719,
#   679395,
#   700710,
#   726488,
#   'No',
#   'No',
#   'No',
#   852227,
#   'No',
#   921928,
#   954937,
#   991015,
#   1025692,
#   1060900,
#   1097780,
#   'No',
#   1055539]}

# %%
err_df=pd.DataFrame(err_dict)
err_df
# Out:
#             date  mipe  mxne   mipv      mxnv  original_val pprd_val nprd_val
# 0    2020-03-31   mxmb  memb     28       -26           150      122      176
# 1    2020-04-01     lb  memb      5       -13           169      164      182
# 2    2020-04-02     lb  memb      1       -16           191      190      207
# 3    2020-04-03     lb  memb     14        -3           230      216      233
# 4    2020-04-04     lb   mxb      9       -23           286      277      309
# 5    2020-04-05   mxmb  memb     86       -12           329      243      341
# 6    2020-04-06   memb   mxb      4       -48           394      390      442
# 7    2020-04-07   memb    lb     10        -3           469      459      472
# 8    2020-04-08     lb   mxb      7       -18           565      558      583
# 9    2020-04-09   mxmb  memb    197       -37           635      438      672
# 10   2020-04-10   memb   mxb     32        -4           786      754      790
# 11   2020-04-11   memb    lb     35        -1           972      937      973
# 12   2020-04-12   mxmb  memb    352       -72          1086      734     1158
# 13   2020-04-13   mxmb    lb    330       -15          1198      868     1213
# 14   2020-04-14     lb  memb     43       -41          1365     1322     1406
