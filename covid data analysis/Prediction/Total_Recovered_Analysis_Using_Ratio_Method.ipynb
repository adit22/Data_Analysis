# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\28\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_total=data[53:]
data_total.reset_index(drop=True,inplace=True)
data_total.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_total.tail()
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 125  26 July             48932          1436020            31512
# 126  27 July             46484          1482504            34354
# 127  28 July             49631          1532135            35683
# 128  29 July             52479          1584614            32886
# 129  30 July             54750          1639364            37425
#
#      Total Recovered  Daily Deceased  Total Deceased
# 125           918636             704           32827
# 126           952990             642           33469
# 127           988673             774           34243
# 128          1021559             775           35018
# 129          1058984             783           35801

# %%
colls=list(data_total.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_total.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_total[data_total.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_total['Date'] = data_total['Date'].astype('str')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,9):
    data_total["Date"][i]=data_total["Date"][i].strip(" March")
for i in range(0,9):
    data_total["Date"][i]="2020-03-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(9,39):
    data_total["Date"][i]=data_total["Date"][i].strip(" April")
for i in range(9,39):
    data_total["Date"][i]="2020-04-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(39,70):
    data_total["Date"][i]=data_total["Date"][i].strip(" May")
for i in range(39,70):
    data_total["Date"][i]="2020-05-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(70,100):
    data_total["Date"][i]=data_total["Date"][i].strip(" June")
for i in range(70,100):
    data_total["Date"][i]="2020-06-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(100,130):
    data_total["Date"][i]=data_total["Date"][i].strip(" July")
for i in range(100,130):
    data_total["Date"][i]="2020-07-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
data_total["Date"]=data_total["Date"].astype('datetime64[ns]')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_total.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_total_ratio_with_two_precision=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio_with_two_precision[i]=list(range(len(data_total_ratio_with_two_precision)))
    data_total_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio_with_two_precision[i][0])
    for k in range(0,len(data_total_ratio_with_two_precision)-1):
        tmp.append(round(data_total_ratio_with_two_precision[j][k+1]/data_total_ratio_with_two_precision[j][k],2))
    data_total_ratio_with_two_precision[i]=tmp
data_total_ratio_with_two_precision.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_total_ratio=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio[i]=list(range(len(data_total_ratio)))
    data_total_ratio[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio[i][0])
    for k in range(0,len(data_total_ratio)-1):
        tmp.append(data_total_ratio[j][k+1]/data_total_ratio[j][k])
    data_total_ratio[i]=tmp
data_total_ratio.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_total_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_total_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    dcr=data_total_ratio.iloc[st:en,10:11]
    dcr.reset_index(inplace = True, drop = True)
    dc=data_total_ratio.iloc[st:en,4:5]
    dc.reset_index(inplace = True, drop = True)



    next_day_recovered_case_count_mean_based=dcr.mean()[0]*dc.mean()[0]

    next_day_recovered_case_count_max_based=max(dcr["Total_Recovered_Ratio"])*max(dc["Total Recovered"])


    next_day_recovered_case_count_mean_max_based=dcr.mean()[0]*max(dc["Total Recovered"])


    next_day_recovered_case_count_max_mean_based=max(dcr["Total_Recovered_Ratio"])*dc.mean()[0]


    next_day_recovered_case_count_mean_last_based=dcr.mean()[0]*dc["Total Recovered"][len(dc)-1]


    next_day_recovered_case_count_last_mean_based=dcr["Total_Recovered_Ratio"][len(dcr)-1]*dc.mean()[0]


    next_day_recovered_case_count_last_based=dcr["Total_Recovered_Ratio"][len(dcr)-1]*dc["Total Recovered"][len(dc)-1]


    next_day_recovered_case_count_middle_based=dcr["Total_Recovered_Ratio"][3]*dc["Total Recovered"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_recovered_case_count_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_middle_based))


    
    if(en!=len(data_total_ratio)):
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_total_ratio["Daily Confirmed"][en-1],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
        
        
        
    
    
    pred_df=pd.DataFrame(pred_dict, index=[0])
    
    
    
    d=pd.read_excel(r"C:\Users\Mark 1\tramprd_df_strd.xlsx")
    d=pd.concat([d,pred_df])
    d.reset_index(drop=True,inplace=True)
    d.to_excel("tramprd_df_strd.xlsx")

# %%
tc=pd.read_excel(r"C:\Users\Mark 1\tramprd_df_strd.xlsx")
tc
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31           187          98        219             176
# 1   2020-04-01           309         111        225             182
# 2   2020-04-02           424         134        254             207
# 3   2020-04-03           486         158        286             233
# 4   2020-04-04           560         179        309             270
# 5   2020-04-05           579         215        384             341
# 6   2020-04-06           609         253        442             390
# 7   2020-04-07           484         291        490             459
# 8   2020-04-08           573         348        583             552
# 9   2020-04-09           565         418        703             672
# 10  2020-04-10           813         493        790             754
# 11  2020-04-11           871         590        977             937
# 12  2020-04-12           854         706       1203            1158
# 13  2020-04-13           758         832       1344            1289
# 14  2020-04-14          1243         957       1483            1406
# 15  2020-04-15          1031        1101       1690            1592
# 16  2020-04-16           886        1243       1868            1738
# 17  2020-04-17          1061        1437       2187            2047
# 18  2020-04-18           922        1628       2523            2339
# 19  2020-04-19          1371        1866       2981            2818
# 20  2020-04-20          1580        2166       3450            3278
# 21  2020-04-21          1239        2520       3956            3780
# 22  2020-04-22          1537        2978       4830            4634
# 23  2020-04-23          1292        3452       5309            5089
# 24  2020-04-24          1667        3980       6089            5820
# 25  2020-04-25          1408        4521       6676            6336
# 26  2020-04-26          1835        5011       7213            6737
# 27  2020-04-27          1607        5565       7924            7346
# 28  2020-04-28          1568        6135       8629            7940
# 29  2020-04-29          1902        6628       8876            8513
# ..         ...           ...         ...        ...             ...
# 93  2020-07-02         19429      335580     378427          374661
# 94  2020-07-03         21947      349790     401013          395703
# 95  2020-07-04         22718      364536     416231          410837
# 96  2020-07-05         24018      378704     431797          425576
# 97  2020-07-06         23942      394094     448505          442116
# 98  2020-07-07         22500      409360     464671          457681
# 99  2020-07-08         23147      425625     482443          475235
# 100 2020-07-09         25561      443440     503035          496064
# 101 2020-07-10         25790      459760     517131          515215
# 102 2020-07-11         27762      478049     538286          536510
# 103 2020-07-12         27757      497018     559120          557375
# 104 2020-07-13         29106      515915     578095          575914
# 105 2020-07-14         28178      535183     596532          593943
# 106 2020-07-15         29917      555239     618405          615587
# 107 2020-07-16         32607      574956     638843          636325
# 108 2020-07-17         35468      595502     662645          659719
# 109 2020-07-18         34820      614764     679395          676572
# 110 2020-07-19         37411      635431     702911          700710
# 111 2020-07-20         40235      656956     726488          724173
# 112 2020-07-21         36806      679757     751696          749592
# 113 2020-07-22         39170      703417     780923          778279
# 114 2020-07-23         45601      729365     817385          812103
# 115 2020-07-24         48443      756672     852227          847228
# 116 2020-07-25         48888      787014     886123          882422
# 117 2020-07-26         50072      818936     925870          921928
# 118 2020-07-27         48932      851569     958759          954937
# 119 2020-07-28         46484      885799     994613          991015
# 120 2020-07-29         49631      920837    1031855         1028034
# 121 2020-07-30         52479      954905    1066177         1060900
# 122 2020-07-31             0      989935    1105237         1098879
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 0               122              176              102         184
# 1               138              182              100         164
# 2               165              207              124         190
# 3               195              233              147         216
# 4               204              270              183         277
# 5               243              341              225         356
# 6               286              390              245         378
# 7               311              459              299         472
# 8               367              552              352         558
# 9               438              672              424         681
# 10              517              754              467         714
# 11              615              937              613         973
# 12              734             1158              733        1202
# 13              868             1289              783        1213
# 14             1010             1406              900        1322
# 15             1168             1592             1075        1555
# 16             1335             1738             1193        1668
# 17             1535             2047             1453        2069
# 18             1756             2339             1639        2355
# 19             1974             2818             1974        2981
# 20             2279             3278             2182        3303
# 21             2638             3780             2502        3754
# 22             3104             4634             3104        4830
# 23             3600             5089             3257        4803
# 24             4163             5820             3931        5748
# 25             4763             6336             4300        6027
# 26             5366             6737             4772        6416
# 27             6002             7346             5428        7166
# 28             6667             7940             5976        7735
# 29             6911             8513             6565        8432
# ..              ...              ...              ...         ...
# 93           338953           374661           333542      372386
# 94           354484           395703           354484      401013
# 95           369323           410837           363159      409284
# 96           384240           425576           377625      424363
# 97           399789           442116           393399      441337
# 98           415613           457681           407926      456077
# 99           432081           475235           424990      474526
# 100          449671           496064           444182      496895
# 101          461470           515215           460603      516160
# 102          479632           536510           478815      537370
# 103          498574           557375           496671      556986
# 104          517869           575914           513525      573246
# 105          537516           593943           531954      590360
# 106          557780           615587           554562      614836
# 107          577230           636325           573849      635101
# 108          598144           659719           596047      660322
# 109          617329           676572           610642      672035
# 110          637427           700710           636687      702095
# 111          659056           724173           656694      723884
# 112          681665           749592           679983      749841
# 113          705806           778279           705806      780923
# 114          734108           812103           734108      817385
# 115          761137           847228           761137      852227
# 116          790315           882422           788249      883806
# 117          822438           921928           822438      925870
# 118          854977           954937           848297      951267
# 119          889015           991015           883666      988629
# 120          924260          1028034           918740     1025692
# 121          959655          1060900           950080     1055539
# 122          995662          1098879           988945     1097780
#
#      middle_based
# 0             112
# 1              96
# 2             122
# 3             184
# 4             164
# 5             190
# 6             216
# 7             277
# 8             356
# 9             378
# 10            472
# 11            558
# 12            681
# 13            714
# 14            973
# 15           1202
# 16           1213
# 17           1322
# 18           1555
# 19           1668
# 20           2069
# 21           2355
# 22           2981
# 23           3303
# 24           3754
# 25           4830
# 26           4803
# 27           5748
# 28           6027
# 29           6416
# ..            ...
# 93         333845
# 94         349338
# 95         360876
# 96         372386
# 97         401013
# 98         409284
# 99         424363
# 100        441337
# 101        456077
# 102        474526
# 103        496895
# 104        516160
# 105        537370
# 106        556986
# 107        573246
# 108        590360
# 109        614836
# 110        635101
# 111        660322
# 112        672035
# 113        702095
# 114        723884
# 115        749841
# 116        780923
# 117        817385
# 118        852227
# 119        883806
# 120        925870
# 121        951267
# 122        988629
#
# [123 rows x 10 columns]

# %%
tce=tc.copy()

# %%
colls=list(tc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    tce[i]=pd.Series(range(1,len(tce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(tce)):
        tce[j][k]=tce["original_val"][k]-tce[i][k]
tce
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 0               122              176              102         184
# 1               138              182              100         164
# 2               165              207              124         190
# 3               195              233              147         216
# 4               204              270              183         277
# 5               243              341              225         356
# 6               286              390              245         378
# 7               311              459              299         472
# 8               367              552              352         558
# 9               438              672              424         681
# 10              517              754              467         714
# 11              615              937              613         973
# 12              734             1158              733        1202
# 13              868             1289              783        1213
# 14             1010             1406              900        1322
# 15             1168             1592             1075        1555
# 16             1335             1738             1193        1668
# 17             1535             2047             1453        2069
# 18             1756             2339             1639        2355
# 19             1974             2818             1974        2981
# 20             2279             3278             2182        3303
# 21             2638             3780             2502        3754
# 22             3104             4634             3104        4830
# 23             3600             5089             3257        4803
# 24             4163             5820             3931        5748
# 25             4763             6336             4300        6027
# 26             5366             6737             4772        6416
# 27             6002             7346             5428        7166
# 28             6667             7940             5976        7735
# 29             6911             8513             6565        8432
# ..              ...              ...              ...         ...
# 93           338953           374661           333542      372386
# 94           354484           395703           354484      401013
# 95           369323           410837           363159      409284
# 96           384240           425576           377625      424363
# 97           399789           442116           393399      441337
# 98           415613           457681           407926      456077
# 99           432081           475235           424990      474526
# 100          449671           496064           444182      496895
# 101          461470           515215           460603      516160
# 102          479632           536510           478815      537370
# 103          498574           557375           496671      556986
# 104          517869           575914           513525      573246
# 105          537516           593943           531954      590360
# 106          557780           615587           554562      614836
# 107          577230           636325           573849      635101
# 108          598144           659719           596047      660322
# 109          617329           676572           610642      672035
# 110          637427           700710           636687      702095
# 111          659056           724173           656694      723884
# 112          681665           749592           679983      749841
# 113          705806           778279           705806      780923
# 114          734108           812103           734108      817385
# 115          761137           847228           761137      852227
# 116          790315           882422           788249      883806
# 117          822438           921928           822438      925870
# 118          854977           954937           848297      951267
# 119          889015           991015           883666      988629
# 120          924260          1028034           918740     1025692
# 121          959655          1060900           950080     1055539
# 122          995662          1098879           988945     1097780
#
#      middle_based      mb      mxb     memb    mxmb      mlb     lmb       lb  \
# 0             112      89      -32       11      65       11      85        3
# 1              96     198       84      127     171      127     209      145
# 2             122     290      170      217     259      217     300      234
# 3             184     328      200      253     291      253     339      270
# 4             164     381      251      290     356      290     377      283
# 5             190     364      195      238     336      238     354      223
# 6             216     356      167      219     323      219     364      231
# 7             277     193       -6       25     173       25     185       12
# 8             356     225      -10       21     206       21     221       15
# 9             378     147     -138     -107     127     -107     141     -116
# 10            472     320       23       59     296       59     346       99
# 11            558     281     -106      -66     256      -66     258     -102
# 12            681     148     -349     -304     120     -304     121     -348
# 13            714     -74     -586     -531    -110     -531     -25     -455
# 14            973     286     -240     -163     233     -163     343      -79
# 15           1202     -70     -659     -561    -137     -561     -44     -524
# 16           1213    -357     -982     -852    -449     -852    -307     -782
# 17           1322    -376    -1126     -986    -474     -986    -392    -1008
# 18           1555    -706    -1601    -1417    -834    -1417    -717    -1433
# 19           1668    -495    -1610    -1447    -603    -1447    -603    -1610
# 20           2069    -586    -1870    -1698    -699    -1698    -602    -1723
# 21           2355   -1281    -2717    -2541   -1399    -2541   -1263    -2515
# 22           2981   -1441    -3293    -3097   -1567    -3097   -1567    -3293
# 23           3303   -2160    -4017    -3797   -2308    -3797   -1965    -3511
# 24           3754   -2313    -4422    -4153   -2496    -4153   -2264    -4081
# 25           4830   -3113    -5268    -4928   -3355    -4928   -2892    -4619
# 26           4803   -3176    -5378    -4902   -3531    -4902   -2937    -4581
# 27           5748   -3958    -6317    -5739   -4395    -5739   -3821    -5559
# 28           6027   -4567    -7061    -6372   -5099    -6372   -4408    -6167
# 29           6416   -4726    -6974    -6611   -5009    -6611   -4663    -6530
# ..            ...     ...      ...      ...     ...      ...     ...      ...
# 93         333845 -316151  -358998  -355232 -319524  -355232 -314113  -352957
# 94         349338 -327843  -379066  -373756 -332537  -373756 -332537  -379066
# 95         360876 -341818  -393513  -388119 -346605  -388119 -340441  -386566
# 96         372386 -354686  -407779  -401558 -360222  -401558 -353607  -400345
# 97         401013 -370152  -424563  -418174 -375847  -418174 -369457  -417395
# 98         409284 -386860  -442171  -435181 -393113  -435181 -385426  -433577
# 99         424363 -402478  -459296  -452088 -408934  -452088 -401843  -451379
# 100        441337 -417879  -477474  -470503 -424110  -470503 -418621  -471334
# 101        456077 -433970  -491341  -489425 -435680  -489425 -434813  -490370
# 102        474526 -450287  -510524  -508748 -451870  -508748 -451053  -509608
# 103        496895 -469261  -531363  -529618 -470817  -529618 -468914  -529229
# 104        516160 -486809  -548989  -546808 -488763  -546808 -484419  -544140
# 105        537370 -507005  -568354  -565765 -509338  -565765 -503776  -562182
# 106        556986 -525322  -588488  -585670 -527863  -585670 -524645  -584919
# 107        573246 -542349  -606236  -603718 -544623  -603718 -541242  -602494
# 108        590360 -560034  -627177  -624251 -562676  -624251 -560579  -624854
# 109        614836 -579944  -644575  -641752 -582509  -641752 -575822  -637215
# 110        635101 -598020  -665500  -663299 -600016  -663299 -599276  -664684
# 111        660322 -616721  -686253  -683938 -618821  -683938 -616459  -683649
# 112        672035 -642951  -714890  -712786 -644859  -712786 -643177  -713035
# 113        702095 -664247  -741753  -739109 -666636  -739109 -666636  -741753
# 114        723884 -683764  -771784  -766502 -688507  -766502 -688507  -771784
# 115        749841 -708229  -803784  -798785 -712694  -798785 -712694  -803784
# 116        780923 -738126  -837235  -833534 -741427  -833534 -739361  -834918
# 117        817385 -768864  -875798  -871856 -772366  -871856 -772366  -875798
# 118        852227 -802637  -909827  -906005 -806045  -906005 -799365  -902335
# 119        883806 -839315  -948129  -944531 -842531  -944531 -837182  -942145
# 120        925870 -871206  -982224  -978403 -874629  -978403 -869109  -976061
# 121        951267 -902426 -1013698 -1008421 -907176 -1008421 -897601 -1003060
# 122        988629 -989935 -1105237 -1098879 -995662 -1098879 -988945 -1097780
#
#         mdb
# 0        75
# 1       213
# 2       302
# 3       302
# 4       396
# 5       389
# 6       393
# 7       207
# 8       217
# 9       187
# 10      341
# 11      313
# 12      173
# 13       44
# 14      270
# 15     -171
# 16     -327
# 17     -261
# 18     -633
# 19     -297
# 20     -489
# 21    -1116
# 22    -1444
# 23    -2011
# 24    -2087
# 25    -3422
# 26    -2968
# 27    -4141
# 28    -4459
# 29    -4514
# ..      ...
# 93  -314416
# 94  -327391
# 95  -338158
# 96  -348368
# 97  -377071
# 98  -386784
# 99  -401216
# 100 -415776
# 101 -430287
# 102 -446764
# 103 -469138
# 104 -487054
# 105 -509192
# 106 -527069
# 107 -540639
# 108 -554892
# 109 -580016
# 110 -597690
# 111 -620087
# 112 -635229
# 113 -662925
# 114 -678283
# 115 -701398
# 116 -732035
# 117 -767313
# 118 -803295
# 119 -837322
# 120 -876239
# 121 -898788
# 122 -988629
#
# [123 rows x 18 columns]

# 111 -616721  -686253  -683938 -618821  -683938 -616459  -683649 -620087
# 112 -642951  -714890  -712786 -644859  -712786 -643177  -713035 -635229
# 113 -664247  -741753  -739109 -666636  -739109 -666636  -741753 -662925
# 114 -683764  -771784  -766502 -688507  -766502 -688507  -771784 -678283
# 115 -708229  -803784  -798785 -712694  -798785 -712694  -803784 -701398
# 116 -738126  -837235  -833534 -741427  -833534 -739361  -834918 -732035
# 117 -768864  -875798  -871856 -772366  -871856 -772366  -875798 -767313
# 118 -802637  -909827  -906005 -806045  -906005 -799365  -902335 -803295
# 119 -839315  -948129  -944531 -842531  -944531 -837182  -942145 -837322
# 120 -871206  -982224  -978403 -874629  -978403 -869109  -976061 -876239
# 121 -902426 -1013698 -1008421 -907176 -1008421 -897601 -1003060 -898788
# 122 -989935 -1105237 -1098879 -995662 -1098879 -988945 -1097780 -988629
#
# [123 rows x 8 columns]

# %%
for j,k in zip(range(len(edf)),range(len(tce)-1)):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(tce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)
# Out:
# for date: 2020-03-31  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-01  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-04-02  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-04-03  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-04-04  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-04-05  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-04-06  the lowest positve error was by the method: mxb and the highest negative error by the method: mxb
# for date: 2020-04-07  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-08  the lowest positve error was by the method: lb and the highest negative error by the method: mxb
# for date: 2020-04-09  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-10  the lowest positve error was by the method: mxb and the highest negative error by the method: memb
# for date: 2020-04-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-12  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-13  the lowest positve error was by the method: mdb and the highest negative error by the method: lmb
# for date: 2020-04-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-15  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-04-16  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-04-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-04-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-04-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-04-20  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-04-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-04-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: mb
# for date: 2020-04-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-04-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-04-25  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-04-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-04-27  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-04-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-04-29  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-04-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-03  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: mb
# for date: 2020-05-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-07  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-09  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: mb
# for date: 2020-05-12  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-15  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-16  the lowest positve error was by the method: mxmb and the highest negative error by the method: mb
# for date: 2020-05-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-20  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-25  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-27  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-05-29  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-05-31  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-03  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-07  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-09  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mb
# for date: 2020-06-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-12  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-15  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-16  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: mb
# for date: 2020-06-20  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-25  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-27  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-06-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: mb
# for date: 2020-06-29  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-06-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-01  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-03  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-06  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-07  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-08  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-09  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-10  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-12  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-15  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-16  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-18  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-20  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-21  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-25  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-07-27  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-29  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb
# for date: 2020-07-30  the lowest positve error was by the method: mxmb and the highest negative error by the method: lmb

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(tce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(tce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(tce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(tce["date"][k]).strip("00:00:00"))
    org_val.append(tce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 '],
#  'mipe': ['lb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'lb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'mxmb',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'],
#  'mxne': ['mxb',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'mxb',
#   'mxb',
#   'memb',
#   'No',
#   'memb',
#   'memb',
#   'lmb',
#   'lb',
#   'lmb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'mb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'mdb'],
#  'mipv': [3,
#   84,
#   170,
#   200,
#   251,
#   195,
#   167,
#   12,
#   15,
#   127,
#   23,
#   256,
#   120,
#   44,
#   233,
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'],
#  'mxnv': [-32,
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   -6,
#   -10,
#   -107,
#   'No',
#   -66,
#   -304,
#   -25,
#   -79,
#   -44,
#   -307,
#   -261,
#   -633,
#   -297,
#   -489,
#   -1116,
#   -1441,
#   -1965,
#   -2087,
#   -2892,
#   -2937,
#   -3821,
#   -4408,
#   -4514,
#   -5461,
#   -5920,
#   -6036,
#   -6617,
#   -6784,
#   -7338,
#   -8781,
#   -9148,
#   -10683,
#   -11826,
#   -13382,
#   -13877,
#   -15480,
#   -17265,
#   -19057,
#   -20183,
#   -22671,
#   -23744,
#   -24652,
#   -28029,
#   -30365,
#   -33591,
#   -35903,
#   -38979,
#   -41109,
#   -44317,
#   -47839,
#   -51206,
#   -53733,
#   -56621,
#   -59950,
#   -62978,
#   -65426,
#   -75670,
#   -80370,
#   -84068,
#   -89900,
#   -95009,
#   -97588,
#   -102147,
#   -109668,
#   -113977,
#   -118110,
#   -123271,
#   -129227,
#   -135456,
#   -141870,
#   -151825,
#   -158597,
#   -163957,
#   -174027,
#   -180326,
#   -185665,
#   -199806,
#   -210076,
#   -220470,
#   -229827,
#   -241311,
#   -251248,
#   -264563,
#   -275625,
#   -288192,
#   -303113,
#   -314113,
#   -327391,
#   -338158,
#   -348368,
#   -369457,
#   -385426,
#   -401216,
#   -415776,
#   -430287,
#   -446764,
#   -468914,
#   -484419,
#   -503776,
#   -524645,
#   -540639,
#   -554892,
#   -575822,
#   -597690,
#   -616459,
#   -635229,
#   -662925,
#   -678283,
#   -701398,
#   -732035,
#   -767313,
#   -799365,
#   -837182,
#   -869109,
#   -897601,
#   -988629],
#  'original_val': [187,
#   309,
#   424,
#   486,
#   560,
#   579,
#   609,
#   484,
#   573,
#   565,
#   813,
#   871,
#   854,
#   758,
#   1243,
#   1031,
#   886,
#   1061,
#   922,
#   1371,
#   1580,
#   1239,
#   1537,
#   1292,
#   1667,
#   1408,
#   1835,
#   1607,
#   1568,
#   1902,
#   1705,
#   1801,
#   2396,
#   2564,
#   2952,
#   3656,
#   2971,
#   3602,
#   3344,
#   3339,
#   3175,
#   4311,
#   3592,
#   3562,
#   3726,
#   3991,
#   3808,
#   4794,
#   5049,
#   4628,
#   6154,
#   5720,
#   6023,
#   6536,
#   6667,
#   7111,
#   6414,
#   5907,
#   7246,
#   7254,
#   8138,
#   8364,
#   8789,
#   7723,
#   8812,
#   9689,
#   9847,
#   9472,
#   10408,
#   10882,
#   8536,
#   9981,
#   11156,
#   11135,
#   11306,
#   12039,
#   11405,
#   10032,
#   11086,
#   13108,
#   13829,
#   14740,
#   15918,
#   15151,
#   13560,
#   15656,
#   16868,
#   18205,
#   18255,
#   20142,
#   19610,
#   18339,
#   18256,
#   19429,
#   21947,
#   22718,
#   24018,
#   23942,
#   22500,
#   23147,
#   25561,
#   25790,
#   27762,
#   27757,
#   29106,
#   28178,
#   29917,
#   32607,
#   35468,
#   34820,
#   37411,
#   40235,
#   36806,
#   39170,
#   45601,
#   48443,
#   48888,
#   50072,
#   48932,
#   46484,
#   49631,
#   52479,
#   0],
#  'pprd_val': [184,
#   225,
#   254,
#   286,
#   309,
#   384,
#   442,
#   472,
#   558,
#   438,
#   790,
#   615,
#   734,
#   714,
#   1010,
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'],
#  'nprd_val': [219,
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   490,
#   583,
#   672,
#   'No',
#   937,
#   1158,
#   783,
#   1322,
#   1075,
#   1193,
#   1322,
#   1555,
#   1668,
#   2069,
#   2355,
#   2978,
#   3257,
#   3754,
#   4300,
#   4772,
#   5428,
#   5976,
#   6416,
#   7166,
#   7721,
#   8432,
#   9181,
#   9736,
#   10994,
#   11752,
#   12750,
#   14027,
#   15165,
#   16557,
#   18188,
#   19072,
#   20827,
#   22783,
#   24174,
#   26479,
#   28538,
#   29701,
#   32657,
#   36519,
#   39311,
#   41926,
#   45515,
#   47776,
#   51428,
#   54253,
#   57113,
#   60979,
#   63875,
#   68088,
#   71342,
#   74215,
#   83393,
#   89182,
#   93757,
#   99747,
#   104481,
#   107996,
#   113029,
#   118204,
#   123958,
#   129266,
#   134406,
#   140533,
#   147495,
#   153275,
#   161857,
#   169683,
#   177065,
#   187856,
#   195066,
#   201583,
#   214957,
#   223636,
#   236126,
#   246695,
#   259516,
#   269503,
#   284705,
#   295235,
#   306531,
#   321369,
#   333542,
#   349338,
#   360876,
#   372386,
#   393399,
#   407926,
#   424363,
#   441337,
#   456077,
#   474526,
#   496671,
#   513525,
#   531954,
#   554562,
#   573246,
#   590360,
#   610642,
#   635101,
#   656694,
#   672035,
#   702095,
#   723884,
#   749841,
#   780923,
#   817385,
#   848297,
#   883666,
#   918740,
#   950080,
#   988629]}

# %%
pd.DataFrame(err_dict)
# Out:
#             date  mipe  mxne mipv     mxnv  original_val pprd_val nprd_val
# 0    2020-03-31     lb   mxb    3      -32           187      184      219
# 1    2020-04-01    mxb    No   84       No           309      225       No
# 2    2020-04-02    mxb    No  170       No           424      254       No
# 3    2020-04-03    mxb    No  200       No           486      286       No
# 4    2020-04-04    mxb    No  251       No           560      309       No
# 5    2020-04-05    mxb    No  195       No           579      384       No
# 6    2020-04-06    mxb    No  167       No           609      442       No
# 7    2020-04-07     lb   mxb   12       -6           484      472      490
# 8    2020-04-08     lb   mxb   15      -10           573      558      583
# 9    2020-04-09   mxmb  memb  127     -107           565      438      672
