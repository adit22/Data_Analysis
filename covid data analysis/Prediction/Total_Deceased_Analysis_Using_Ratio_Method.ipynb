# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\52\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_total=data[53:]
data_total.reset_index(drop=True,inplace=True)
data_total.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_total.tail()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 149  19 August             69196          2835836            59365
# 150  20 August             68518          2904354            61873
# 151  21 August             69029          2973383            62858
# 152  22 August             70067          3043450            59101
# 153  23 August             61749          3105199            56896
#
#      Total Recovered  Daily Deceased  Total Deceased
# 149          2096061             979           54006
# 150          2157934             981           54987
# 151          2220792             953           55940
# 152          2279893             918           56858
# 153          2336789             846           57704

# %%
colls=list(data_total.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_total.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_total[data_total.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_total['Date'] = data_total['Date'].astype('str')
# Out:
# <ipython-input-8-99f82638761e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total['Date'] = data_total['Date'].astype('str')

# %%
for i in range(0,9):
    data_total["Date"][i]=data_total["Date"][i].strip(" March")
for i in range(0,9):
    data_total["Date"][i]="2020-03-"+data_total["Date"][i]
# Out:
# <ipython-input-9-d239740191b3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]=data_total["Date"][i].strip(" March")
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <ipython-input-9-d239740191b3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]="2020-03-"+data_total["Date"][i]

# %%
for i in range(9,39):
    data_total["Date"][i]=data_total["Date"][i].strip(" April")
for i in range(9,39):
    data_total["Date"][i]="2020-04-"+data_total["Date"][i]
# Out:
# <ipython-input-10-aa71c839161c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]=data_total["Date"][i].strip(" April")
# <ipython-input-10-aa71c839161c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]="2020-04-"+data_total["Date"][i]

# %%
for i in range(39,70):
    data_total["Date"][i]=data_total["Date"][i].strip(" May")
for i in range(39,70):
    data_total["Date"][i]="2020-05-"+data_total["Date"][i]
# Out:
# <ipython-input-11-53c499d84780>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]=data_total["Date"][i].strip(" May")
# <ipython-input-11-53c499d84780>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]="2020-05-"+data_total["Date"][i]

# %%
for i in range(70,100):
    data_total["Date"][i]=data_total["Date"][i].strip(" June")
for i in range(70,100):
    data_total["Date"][i]="2020-06-"+data_total["Date"][i]
# Out:
# <ipython-input-12-1a0a85fafe5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]=data_total["Date"][i].strip(" June")
# <ipython-input-12-1a0a85fafe5b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]="2020-06-"+data_total["Date"][i]

# %%
for i in range(100,131):
    data_total["Date"][i]=data_total["Date"][i].strip(" July")
for i in range(100,131):
    data_total["Date"][i]="2020-07-"+data_total["Date"][i]
# Out:
# <ipython-input-13-208466873f51>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]=data_total["Date"][i].strip(" July")
# <ipython-input-13-208466873f51>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]="2020-07-"+data_total["Date"][i]

# %%
for i in range(131,len(data_total)):
    data_total["Date"][i]=data_total["Date"][i].strip(" August")
for i in range(131,len(data_total)):
    data_total["Date"][i]="2020-08-"+data_total["Date"][i]
# Out:
# <ipython-input-14-3bacb11f10f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]=data_total["Date"][i].strip(" August")
# <ipython-input-14-3bacb11f10f3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"][i]="2020-08-"+data_total["Date"][i]

# %%
data_total["Date"]=data_total["Date"].astype('datetime64[ns]')
# Out:
# <ipython-input-15-a317546e137f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total["Date"]=data_total["Date"].astype('datetime64[ns]')

# %%
data_total.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_total_ratio_with_two_precision=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio_with_two_precision[i]=list(range(len(data_total_ratio_with_two_precision)))
    data_total_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio_with_two_precision[i][0])
    for k in range(0,len(data_total_ratio_with_two_precision)-1):
        tmp.append(round(data_total_ratio_with_two_precision[j][k+1]/data_total_ratio_with_two_precision[j][k],2))
    data_total_ratio_with_two_precision[i]=tmp
data_total_ratio_with_two_precision.head()
# Out:
# <ipython-input-18-c038b6b9f526>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total_ratio_with_two_precision[i][0]=1
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_total_ratio=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio[i]=list(range(len(data_total_ratio)))
    data_total_ratio[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio[i][0])
    for k in range(0,len(data_total_ratio)-1):
        tmp.append(data_total_ratio[j][k+1]/data_total_ratio[j][k])
    data_total_ratio[i]=tmp
data_total_ratio.head()
# Out:
# <ipython-input-20-6e1737506d3a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_total_ratio[i][0]=1
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_total_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_total_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    tcr=data_total_ratio.iloc[st:en,12:13]
    tcr.reset_index(inplace = True, drop = True)
    tc=data_total_ratio.iloc[st:en,6:7]
    tc.reset_index(inplace = True, drop = True)



    next_day_tconfirmed_case_count_mean_based=tcr.mean()[0]*tc.mean()[0]

    next_day_tconfirmed_case_count_max_based=max(tcr["Total_Deceased_Ratio"])*max(tc["Total Deceased"])


    next_day_tconfirmed_case_count_mean_max_based=tcr.mean()[0]*max(tc["Total Deceased"])


    next_day_tconfirmed_case_count_max_mean_based=max(tcr["Total_Deceased_Ratio"])*tc.mean()[0]


    next_day_tconfirmed_case_count_mean_last_based=tcr.mean()[0]*tc["Total Deceased"][len(tc)-1]


    next_day_tconfirmed_case_count_last_mean_based=tcr["Total_Deceased_Ratio"][len(tcr)-1]*tc.mean()[0]


    next_day_tconfirmed_case_count_last_based=tcr["Total_Deceased_Ratio"][len(tcr)-1]*tc["Total Deceased"][len(tc)-1]


    next_day_tconfirmed_case_count_middle_based=tcr["Total_Deceased_Ratio"][3]*tc["Total Deceased"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_tconfirmed_case_count_mean_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_max_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_mean_max_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_max_mean_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_mean_last_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_last_mean_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_last_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_middle_based))


    
    if(en<len(data_total_ratio)):
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_total_ratio["Total Deceased"][en],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
        
        
        
    
    
    pred_df=pd.DataFrame(pred_dict, index=[0])
    
    

d=pd.read_excel(r"C:\Users\Mark 1\tdamprd_df_strd.xlsx")
d=pd.concat([d,pred_df])
d.reset_index(drop=True,inplace=True)
d['original_val'][len(d)-2]=data_total_ratio['Total Deceased'][len(data_total_ratio)-1]
d.to_excel("tdamprd_df_strd.xlsx")
# Out:
# <ipython-input-21-f86d80fdf799>:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['original_val'][len(d)-2]=data_total_ratio['Total Deceased'][len(data_total_ratio)-1]

# %%
tc=pd.read_excel(r"C:\Users\Mark 1\tdamprd_df_strd.xlsx")
tc = tc.loc[:, ~tc.columns.str.contains('^Unnamed')]
tc
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31            47          26         62              51
# 1   2020-04-01            53          33         71              59
# 2   2020-04-02            69          41         80              67
# 3   2020-04-03            83          50        105              85
# 4   2020-04-04            96          61        126             103
# ..         ...           ...         ...        ...             ...
# 142 2020-08-20         54987       52058      55158           55064
# 143 2020-08-21         55940       53029      56151           56039
# 144 2020-08-22         56858       53995      57124           56985
# 145 2020-08-23         57704       54956      58061           57896
# 146 2020-08-24             0       55892      58925           58723
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 0                32               51               32          62
# 1                40               59               30          54
# 2                49               67               37          60
# 3                61               85               52          90
# 4                75              103               59         100
# ..              ...              ...              ...         ...
# 142           52147            55064            52000       55003
# 143           53135            56039            52979       55986
# 144           54126            56985            53923       56910
# 145           55113            57896            54856       57791
# 146           56084            58723            55739       58563
#
#      middle_based
# 0              23
# 1              30
# 2              30
# 3              62
# 4              54
# ..            ...
# 142         52018
# 143         52823
# 144         54149
# 145         55003
# 146         55986
#
# [147 rows x 10 columns]

# %%
tce=tc.copy()

# %%
colls=list(tc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    tce[i]=pd.Series(range(1,len(tce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(tce)):
        tce[j][k]=tce["original_val"][k]-tce[i][k]
tce
# Out:
# <ipython-input-25-35e3607d3c2a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tce[j][k]=tce["original_val"][k]-tce[i][k]
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31            47          26         62              51
# 1   2020-04-01            53          33         71              59
# 2   2020-04-02            69          41         80              67
# 3   2020-04-03            83          50        105              85
# 4   2020-04-04            96          61        126             103
# ..         ...           ...         ...        ...             ...
# 142 2020-08-20         54987       52058      55158           55064
# 143 2020-08-21         55940       53029      56151           56039
# 144 2020-08-22         56858       53995      57124           56985
# 145 2020-08-23         57704       54956      58061           57896
# 146 2020-08-24             0       55892      58925           58723
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 0                32               51               32          62
# 1                40               59               30          54
# 2                49               67               37          60
# 3                61               85               52          90
# 4                75              103               59         100
# ..              ...              ...              ...         ...
# 142           52147            55064            52000       55003
# 143           53135            56039            52979       55986
# 144           54126            56985            53923       56910
# 145           55113            57896            54856       57791
# 146           56084            58723            55739       58563
#
#      middle_based     mb    mxb   memb   mxmb    mlb    lmb     lb    mdb
# 0              23     21    -15     -4     15     -4     15    -15     24
# 1              30     20    -18     -6     13     -6     23     -1     23
# 2              30     28    -11      2     20      2     32      9     39
# 3              62     33    -22     -2     22     -2     31     -7     21
# 4              54     35    -30     -7     21     -7     37     -4     42
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 142         52018   2929   -171    -77   2840    -77   2987    -16   2969
# 143         52823   2911   -211    -99   2805    -99   2961    -46   3117
# 144         54149   2863   -266   -127   2732   -127   2935    -52   2709
# 145         55003   2748   -357   -192   2591   -192   2848    -87   2701
# 146         55986 -55892 -58925 -58723 -56084 -58723 -55739 -58563 -55986
#
# [147 rows x 18 columns]

# %%
tce.to_excel("tdamerrprd_df_strd.xlsx")
tce=pd.read_excel(r"C:\Users\Mark 1\tdamerrprd_df_strd.xlsx")
tce = tce.loc[:, ~tce.columns.str.contains('^Unnamed')]
tce.to_excel("tdamerrprd_df_strd.xlsx")

# %%
edf=tce.iloc[0:len(tce),10:]
edf
# Out:
#         mb    mxb   memb   mxmb    mlb    lmb     lb    mdb
# 0       21    -15     -4     15     -4     15    -15     24
# 1       20    -18     -6     13     -6     23     -1     23
# 2       28    -11      2     20      2     32      9     39
# 3       33    -22     -2     22     -2     31     -7     21
# 4       35    -30     -7     21     -7     37     -4     42
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 142   2929   -171    -77   2840    -77   2987    -16   2969
# 143   2911   -211    -99   2805    -99   2961    -46   3117
# 144   2863   -266   -127   2732   -127   2935    -52   2709
# 145   2748   -357   -192   2591   -192   2848    -87   2701
# 146 -55892 -58925 -58723 -56084 -58723 -55739 -58563 -55986
#
# [147 rows x 8 columns]

# %%
"""
for j,k in zip(range(len(edf)),range(len(tce)-1)):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(tce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)
    """
# Out:
# '\nfor j,k in zip(range(len(edf)),range(len(tce)-1)):\n    \n    a=list(edf.loc[j])\n    pos=[]\n    neg=[]\n    for i in a:\n        if(i>=0):\n            pos.append(i)\n        else:\n            neg.append(i)\n    if(len(pos)):\n        ps=min(pos)\n        psi=a.index(ps)\n        psc=list(edf.columns)[psi]\n    if(len(neg)):\n        ng=max(neg)\n        ngi=a.index(ng)\n        ngc=list(edf.columns)[ngi]\n    \n    \n    print("for date: "+str(tce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)\n    '

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(tce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(tce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(tce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(tce["date"][k]).strip("00:00:00"))
    org_val.append(tce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-08-02 ',
#   '2020-08-03 ',
#   '2020-08-04 ',
#   '2020-08-05 ',
#   '2020-08-06 ',
#   '2020-08-07 ',
#   '2020-08-08 ',
#   '2020-08-09 ',
#   '2020-08-10 ',
#   '2020-08-11 ',
#   '2020-08-12 ',
#   '2020-08-13 ',
#   '2020-08-14 ',
#   '2020-08-15 ',
#   '2020-08-16 ',
#   '2020-08-17 ',
#   '2020-08-18 ',
#   '2020-08-19 ',
#   '2020-08-20 ',
#   '2020-08-21 ',
#   '2020-08-22 ',
#   '2020-08-23 ',
#   '2020-08-24 '],
#  'mipe': ['mxmb',
#   'mxmb',
#   'memb',
#   'mdb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mdb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'memb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mb',
#   'lb',
#   'mb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mdb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'lb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'mxmb',
#   'No'],
#  'mxne': ['memb',
#   'lb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'mxb',
#   'lb',
#   'lb',
#   'memb',
#   'No',
#   'No',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'memb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'No',
#   'memb',
#   'No',
#   'memb',
#   'mxb',
#   'lb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'No',
#   'No',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'No',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'memb',
#   'No',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'memb',
#   'memb',
#   'memb',
#   'No',
#   'No',
#   'No',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'No',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'No',
#   'memb',
#   'memb',
#   'memb',
#   'mxb',
#   'lb',
#   'mxb',
#   'memb',
#   'No',
#   'memb',
#   'lb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'mxb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'lb',
#   'lmb'],
#  'mipv': [15,
#   13,
#   2,
#   21,
#   21,
#   0,
#   24,
#   2,
#   48,
#   11,
#   70,
#   17,
#   88,
#   74,
#   8,
#   59,
#   41,
#   10,
#   67,
#   0,
#   89,
#   9,
#   109,
#   2,
#   8,
#   121,
#   0,
#   141,
#   5,
#   5,
#   2,
#   201,
#   2,
#   41,
#   271,
#   9,
#   283,
#   8,
#   256,
#   13,
#   241,
#   249,
#   36,
#   11,
#   313,
#   3,
#   12,
#   21,
#   354,
#   9,
#   370,
#   9,
#   397,
#   393,
#   9,
#   423,
#   3,
#   1,
#   500,
#   65,
#   558,
#   0,
#   573,
#   14,
#   9,
#   3,
#   0,
#   17,
#   804,
#   0,
#   799,
#   9,
#   19,
#   29,
#   978,
#   4,
#   9,
#   1522,
#   920,
#   549,
#   11,
#   1440,
#   111,
#   955,
#   149,
#   15,
#   1142,
#   1124,
#   24,
#   1103,
#   24,
#   47,
#   1250,
#   1195,
#   58,
#   52,
#   1286,
#   43,
#   1281,
#   2,
#   1287,
#   30,
#   10,
#   1507,
#   30,
#   5,
#   12,
#   50,
#   50,
#   1771,
#   25,
#   1791,
#   62,
#   345,
#   2002,
#   2015,
#   1956,
#   1751,
#   1726,
#   119,
#   1666,
#   2151,
#   2173,
#   8,
#   2312,
#   31,
#   26,
#   49,
#   6,
#   18,
#   2616,
#   10,
#   2712,
#   2616,
#   100,
#   14,
#   2746,
#   2737,
#   2729,
#   2742,
#   84,
#   2855,
#   2840,
#   2805,
#   2709,
#   2591,
#   'No'],
#  'mxnv': [-4,
#   -1,
#   -11,
#   -2,
#   -4,
#   -28,
#   -11,
#   -13,
#   -11,
#   -9,
#   -20,
#   -2,
#   -6,
#   -21,
#   -18,
#   -14,
#   -3,
#   -8,
#   -6,
#   -8,
#   -8,
#   -8,
#   -11,
#   -8,
#   -6,
#   -11,
#   -18,
#   -1,
#   -15,
#   -3,
#   -1,
#   -3,
#   'No',
#   'No',
#   -7,
#   -38,
#   -40,
#   -29,
#   -13,
#   -26,
#   -10,
#   -37,
#   -9,
#   -4,
#   -37,
#   -27,
#   -11,
#   -11,
#   -7,
#   -1,
#   -17,
#   -1,
#   -12,
#   -6,
#   -12,
#   -12,
#   -20,
#   'No',
#   -7,
#   'No',
#   -6,
#   -74,
#   -31,
#   -20,
#   -74,
#   -74,
#   -77,
#   -2,
#   -35,
#   -31,
#   -9,
#   'No',
#   'No',
#   -25,
#   -68,
#   -53,
#   -67,
#   'No',
#   -432,
#   -8,
#   -385,
#   -67,
#   -310,
#   -128,
#   -265,
#   -60,
#   -21,
#   -31,
#   -19,
#   -41,
#   -25,
#   -58,
#   -26,
#   -71,
#   -16,
#   'No',
#   -82,
#   -35,
#   -5,
#   -18,
#   -25,
#   -15,
#   -4,
#   -34,
#   -5,
#   'No',
#   'No',
#   'No',
#   -23,
#   -109,
#   -57,
#   -83,
#   -16,
#   'No',
#   -32,
#   -11,
#   -79,
#   -15,
#   -77,
#   -73,
#   -17,
#   -9,
#   -38,
#   'No',
#   -65,
#   -27,
#   -10,
#   -11,
#   -41,
#   -36,
#   -63,
#   'No',
#   -95,
#   -68,
#   -39,
#   -93,
#   -18,
#   -60,
#   -8,
#   -98,
#   -10,
#   -85,
#   -16,
#   -46,
#   -52,
#   -87,
#   -55739],
#  'original_val': [47,
#   53,
#   69,
#   83,
#   96,
#   118,
#   134,
#   161,
#   181,
#   227,
#   249,
#   290,
#   332,
#   359,
#   396,
#   423,
#   449,
#   487,
#   522,
#   560,
#   593,
#   646,
#   682,
#   722,
#   781,
#   825,
#   881,
#   939,
#   1008,
#   1079,
#   1154,
#   1231,
#   1323,
#   1463,
#   1566,
#   1694,
#   1785,
#   1889,
#   1986,
#   2101,
#   2213,
#   2294,
#   2414,
#   2551,
#   2648,
#   2752,
#   2872,
#   3024,
#   3155,
#   3301,
#   3435,
#   3583,
#   3725,
#   3867,
#   4023,
#   4173,
#   4346,
#   4534,
#   4710,
#   4979,
#   5184,
#   5406,
#   5607,
#   5829,
#   6088,
#   6362,
#   6648,
#   6945,
#   7206,
#   7477,
#   7749,
#   8107,
#   8501,
#   8889,
#   9198,
#   9522,
#   9918,
#   11922,
#   12263,
#   12606,
#   12970,
#   13278,
#   13704,
#   14016,
#   14484,
#   14908,
#   15309,
#   15690,
#   16104,
#   16488,
#   16905,
#   17411,
#   17849,
#   18227,
#   18671,
#   19282,
#   19703,
#   20176,
#   20655,
#   21147,
#   21626,
#   22146,
#   22689,
#   23189,
#   23730,
#   24317,
#   24931,
#   25611,
#   26287,
#   26830,
#   27505,
#   28101,
#   28772,
#   29902,
#   30657,
#   31420,
#   32123,
#   32827,
#   33469,
#   34243,
#   35018,
#   35802,
#   36566,
#   37420,
#   38180,
#   38986,
#   39835,
#   40754,
#   41653,
#   42590,
#   43465,
#   44478,
#   45364,
#   46200,
#   47150,
#   48156,
#   49146,
#   50096,
#   51057,
#   51937,
#   53035,
#   54006,
#   54987,
#   55940,
#   56858,
#   57704,
#   0],
#  'pprd_val': [32,
#   40,
#   67,
#   62,
#   75,
#   118,
#   110,
#   159,
#   133,
#   216,
#   179,
#   273,
#   244,
#   285,
#   388,
#   364,
#   408,
#   477,
#   455,
#   560,
#   504,
#   637,
#   573,
#   720,
#   773,
#   704,
#   881,
#   798,
#   1003,
#   1074,
#   1152,
#   1030,
#   1321,
#   1422,
#   1295,
#   1685,
#   1502,
#   1881,
#   1730,
#   2088,
#   1972,
#   2045,
#   2378,
#   2540,
#   2335,
#   2749,
#   2860,
#   3003,
#   2801,
#   3292,
#   3065,
#   3574,
#   3328,
#   3474,
#   4014,
#   3750,
#   4343,
#   4533,
#   4210,
#   4914,
#   4626,
#   5406,
#   5034,
#   5815,
#   6079,
#   6359,
#   6648,
#   6928,
#   6402,
#   7477,
#   6950,
#   8098,
#   8482,
#   8860,
#   8220,
#   9518,
#   9909,
#   10400,
#   11343,
#   12057,
#   12959,
#   11838,
#   13593,
#   13061,
#   14335,
#   14893,
#   14167,
#   14566,
#   16080,
#   15385,
#   16881,
#   17364,
#   16599,
#   17032,
#   18613,
#   19230,
#   18417,
#   20133,
#   19374,
#   21145,
#   20339,
#   22116,
#   22679,
#   21682,
#   23700,
#   24312,
#   24919,
#   25561,
#   26237,
#   25059,
#   27480,
#   26310,
#   28710,
#   29557,
#   28655,
#   29405,
#   30167,
#   31076,
#   31743,
#   34124,
#   33352,
#   33651,
#   34393,
#   37412,
#   35868,
#   38955,
#   39809,
#   40705,
#   41647,
#   42572,
#   40849,
#   44468,
#   42652,
#   43584,
#   47050,
#   48142,
#   46400,
#   47359,
#   48328,
#   49195,
#   52951,
#   51151,
#   52147,
#   53135,
#   54149,
#   55113,
#   'No'],
#  'nprd_val': [51,
#   54,
#   80,
#   85,
#   100,
#   146,
#   145,
#   174,
#   192,
#   236,
#   269,
#   292,
#   338,
#   380,
#   414,
#   437,
#   452,
#   495,
#   528,
#   568,
#   601,
#   654,
#   693,
#   730,
#   787,
#   836,
#   899,
#   940,
#   1023,
#   1082,
#   1155,
#   1234,
#   'No',
#   'No',
#   1573,
#   1732,
#   1825,
#   1918,
#   1999,
#   2127,
#   2223,
#   2331,
#   2423,
#   2555,
#   2685,
#   2779,
#   2883,
#   3035,
#   3162,
#   3302,
#   3452,
#   3584,
#   3737,
#   3873,
#   4035,
#   4185,
#   4366,
#   'No',
#   4717,
#   'No',
#   5190,
#   5480,
#   5638,
#   5849,
#   6162,
#   6436,
#   6725,
#   6947,
#   7241,
#   7508,
#   7758,
#   'No',
#   'No',
#   8914,
#   9266,
#   9575,
#   9985,
#   'No',
#   12695,
#   12614,
#   13355,
#   13345,
#   14014,
#   14144,
#   14749,
#   14968,
#   15330,
#   15721,
#   16123,
#   16529,
#   16930,
#   17469,
#   17875,
#   18298,
#   18687,
#   'No',
#   19785,
#   20211,
#   20660,
#   21165,
#   21651,
#   22161,
#   22693,
#   23223,
#   23735,
#   'No',
#   'No',
#   'No',
#   26310,
#   26939,
#   27562,
#   28184,
#   28788,
#   'No',
#   30689,
#   31431,
#   32202,
#   32842,
#   33546,
#   34316,
#   35035,
#   35811,
#   36604,
#   'No',
#   38245,
#   39013,
#   39845,
#   40765,
#   41694,
#   42626,
#   43528,
#   'No',
#   45459,
#   46268,
#   47189,
#   48249,
#   49164,
#   50156,
#   51065,
#   52035,
#   53045,
#   54091,
#   55003,
#   55986,
#   56910,
#   57791,
#   55739]}

# %%
err_df=pd.DataFrame(err_dict)
err_df
# Out:
#             date  mipe  mxne  mipv    mxnv  original_val pprd_val nprd_val
# 0    2020-03-31   mxmb  memb    15      -4            47       32       51
# 1    2020-04-01   mxmb    lb    13      -1            53       40       54
# 2    2020-04-02   memb   mxb     2     -11            69       67       80
# 3    2020-04-03    mdb  memb    21      -2            83       62       85
# 4    2020-04-04   mxmb    lb    21      -4            96       75      100
# ..           ...   ...   ...   ...     ...           ...      ...      ...
# 142  2020-08-20   mxmb    lb  2840     -16         54987    52147    55003
# 143  2020-08-21   mxmb    lb  2805     -46         55940    53135    55986
# 144  2020-08-22    mdb    lb  2709     -52         56858    54149    56910
# 145  2020-08-23   mxmb    lb  2591     -87         57704    55113    57791
# 146  2020-08-24     No   lmb    No  -55739             0       No    55739
#
# [147 rows x 8 columns]

# %%
err_df.to_excel("tderr_df.xlsx")
errdf=pd.read_excel(r"C:\Users\Mark 1\tderr_df.xlsx")
errdf = errdf.loc[:, ~errdf.columns.str.contains('^Unnamed')]
errdf.to_excel("tderr_df.xlsx")
