# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\28\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_total=data[53:]
data_total.reset_index(drop=True,inplace=True)
data_total.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_total.tail()
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 125  26 July             48932          1436020            31512
# 126  27 July             46484          1482504            34354
# 127  28 July             49631          1532135            35683
# 128  29 July             52479          1584614            32886
# 129  30 July             54750          1639364            37425
#
#      Total Recovered  Daily Deceased  Total Deceased
# 125           918636             704           32827
# 126           952990             642           33469
# 127           988673             774           34243
# 128          1021559             775           35018
# 129          1058984             783           35801

# %%
colls=list(data_total.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_total.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_total[data_total.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_total['Date'] = data_total['Date'].astype('str')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,9):
    data_total["Date"][i]=data_total["Date"][i].strip(" March")
for i in range(0,9):
    data_total["Date"][i]="2020-03-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(9,39):
    data_total["Date"][i]=data_total["Date"][i].strip(" April")
for i in range(9,39):
    data_total["Date"][i]="2020-04-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(39,70):
    data_total["Date"][i]=data_total["Date"][i].strip(" May")
for i in range(39,70):
    data_total["Date"][i]="2020-05-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(70,100):
    data_total["Date"][i]=data_total["Date"][i].strip(" June")
for i in range(70,100):
    data_total["Date"][i]="2020-06-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(100,130):
    data_total["Date"][i]=data_total["Date"][i].strip(" July")
for i in range(100,130):
    data_total["Date"][i]="2020-07-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
data_total["Date"]=data_total["Date"].astype('datetime64[ns]')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_total.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_total_ratio_with_two_precision=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio_with_two_precision[i]=list(range(len(data_total_ratio_with_two_precision)))
    data_total_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio_with_two_precision[i][0])
    for k in range(0,len(data_total_ratio_with_two_precision)-1):
        tmp.append(round(data_total_ratio_with_two_precision[j][k+1]/data_total_ratio_with_two_precision[j][k],2))
    data_total_ratio_with_two_precision[i]=tmp
data_total_ratio_with_two_precision.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_total_ratio=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio[i]=list(range(len(data_total_ratio)))
    data_total_ratio[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio[i][0])
    for k in range(0,len(data_total_ratio)-1):
        tmp.append(data_total_ratio[j][k+1]/data_total_ratio[j][k])
    data_total_ratio[i]=tmp
data_total_ratio.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_total_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_total_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    dcr=data_total_ratio.iloc[st:en,7:8]
    dcr.reset_index(inplace = True, drop = True)
    dc=data_total_ratio.iloc[st:en,1:2]
    dc.reset_index(inplace = True, drop = True)



    next_day_confirmed_case_count_mean_based=dcr.mean()[0]*dc.mean()[0]

    next_day_confirmed_case_count_max_based=max(dcr["Daily_Confirmed_Ratio"])*max(dc["Daily Confirmed"])


    next_day_confirmed_case_count_mean_max_based=dcr.mean()[0]*max(dc["Daily Confirmed"])


    next_day_confirmed_case_count_max_mean_based=max(dcr["Daily_Confirmed_Ratio"])*dc.mean()[0]


    next_day_confirmed_case_count_mean_last_based=dcr.mean()[0]*dc["Daily Confirmed"][len(dc)-1]


    next_day_confirmed_case_count_last_mean_based=dcr["Daily_Confirmed_Ratio"][len(dcr)-1]*dc.mean()[0]


    next_day_confirmed_case_count_last_based=dcr["Daily_Confirmed_Ratio"][len(dcr)-1]*dc["Daily Confirmed"][len(dc)-1]


    next_day_confirmed_case_count_middle_based=dcr["Daily_Confirmed_Ratio"][3]*dc["Daily Confirmed"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_confirmed_case_count_mean_based))
    pred_val.append(np.round(next_day_confirmed_case_count_max_based))
    pred_val.append(np.round(next_day_confirmed_case_count_mean_max_based))
    pred_val.append(np.round(next_day_confirmed_case_count_max_mean_based))
    pred_val.append(np.round(next_day_confirmed_case_count_mean_last_based))
    pred_val.append(np.round(next_day_confirmed_case_count_last_mean_based))
    pred_val.append(np.round(next_day_confirmed_case_count_last_based))
    pred_val.append(np.round(next_day_confirmed_case_count_middle_based))


    
    if(en!=len(data_total_ratio)):
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_total_ratio["Daily Confirmed"][en-1],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
        
        
        
    
    
    pred_df=pd.DataFrame(pred_dict, index=[0])
    
    
    
    d=pd.read_excel(r"C:\Users\Mark 1\tamprd_df_strd.xlsx")
    d=pd.concat([d,pred_df])
    d.reset_index(drop=True,inplace=True)
    d.to_excel("tamprd_df_strd.xlsx")

# %%
tc=pd.read_excel(r"C:\Users\Mark 1\tamprd_df_strd.xlsx")
tc
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31           187         139        392             220
# 1   2020-04-01           309         197        648             401
# 2   2020-04-02           424         266        889             563
# 3   2020-04-03           486         355       1019             666
# 4   2020-04-04           560         392        925             692
# 5   2020-04-05           579         478        957             728
# 6   2020-04-06           609         577       1006             780
# 7   2020-04-07           484         578       1006             714
# 8   2020-04-08           573         586        836             673
# 9   2020-04-09           565         578        721             639
# 10  2020-04-10           813         652       1170             888
# 11  2020-04-11           871         693       1253             941
# 12  2020-04-12           854         731       1253             934
# 13  2020-04-13           758         737       1253             914
# 14  2020-04-14          1243         949       2038            1454
# 15  2020-04-15          1031         981       2038            1391
# 16  2020-04-16           886        1015       2038            1369
# 17  2020-04-17          1061        1021       2038            1326
# 18  2020-04-18           922        1001       2038            1290
# 19  2020-04-19          1371        1153       2248            1522
# 20  2020-04-20          1580        1327       2591            1814
# 21  2020-04-21          1239        1185       2349            1620
# 22  2020-04-22          1537        1332       2349            1713
# 23  2020-04-23          1292        1391       2349            1709
# 24  2020-04-24          1667        1503       2479            1825
# 25  2020-04-25          1408        1574       2479            1819
# 26  2020-04-26          1835        1607       2391            1955
# 27  2020-04-27          1607        1551       2391            1882
# 28  2020-04-28          1568        1642       2391            1932
# 29  2020-04-29          1902        1690       2479            1995
# ..         ...           ...         ...        ...             ...
# 93  2020-07-02         19429       19306      22224           20585
# 94  2020-07-03         21947       19992      24791           22587
# 95  2020-07-04         22718       20741      25662           23486
# 96  2020-07-05         24018       21178      27131           24671
# 97  2020-07-06         23942       21884      27131           24751
# 98  2020-07-07         22500       22511      27131           24767
# 99  2020-07-08         23147       23338      27131           24881
# 100 2020-07-09         25561       24380      28874           26626
# 101 2020-07-10         25790       24539      28480           26420
# 102 2020-07-11         27762       25423      30657           28604
# 103 2020-07-12         27757       25766      30657           28376
# 24            972
# 25           1907
# 26           1086
# 27           2151
# 28           1189
# 29           2391
# ..            ...
# 93          19092
# 94          17150
# 95          18173
# 96          20677
# 97          24791
# 98          23516
# 99          25392
# 100         23866
# 101         21145
# 102         23813
# 103         28227
# 104         26021
# 105         29885
# 106         27752
# 107         30521
# 108         27280
# 109         31763
# 110         35539
# 111         38580
# 112         34184
# 113         40195
# 114         43272
# 115         33669
# 116         41686
# 117         53088
# 118         51462
# 119         49337
# 120         51285
# 121         47818
# 122         44158
#
# [123 rows x 10 columns]

# %%
tce=tc.copy()

# %%
colls=list(tc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    tce[i]=pd.Series(range(1,len(tce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(tce)):
        tce[j][k]=tce["original_val"][k]-tce[i][k]
tce
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31           187         139        392             220
# 1   2020-04-01           309         197        648             401
# 2   2020-04-02           424         266        889             563
# 3   2020-04-03           486         355       1019             666
# 4   2020-04-04           560         392        925             692
# 5   2020-04-05           579         478        957             728
# 6   2020-04-06           609         577       1006             780
# 7   2020-04-07           484         578       1006             714
# 8   2020-04-08           573         586        836             673
# 9   2020-04-09           565         578        721             639
# 10  2020-04-10           813         652       1170             888
# 11  2020-04-11           871         693       1253             941
# 12  2020-04-12           854         731       1253             934
# 13  2020-04-13           758         737       1253             914
# 14  2020-04-14          1243         949       2038            1454
# 15  2020-04-15          1031         981       2038            1391
# 16  2020-04-16           886        1015       2038            1369
# 17  2020-04-17          1061        1021       2038            1326
# 18  2020-04-18           922        1001       2038            1290
# 19  2020-04-19          1371        1153       2248            1522
# 20  2020-04-20          1580        1327       2591            1814
# 21  2020-04-21          1239        1185       2349            1620
# 22  2020-04-22          1537        1332       2349            1713
# 23  2020-04-23          1292        1391       2349            1709
# 24  2020-04-24          1667        1503       2479            1825
# 25  2020-04-25          1408        1574       2479            1819
# 26  2020-04-26          1835        1607       2391            1955
# 27  2020-04-27          1607        1551       2391            1882
# 28  2020-04-28          1568        1642       2391            1932
# 29  2020-04-29          1902        1690       2479            1995
# ..         ...           ...         ...        ...             ...
# 93  2020-07-02         19429       19306      22224           20585
# 94  2020-07-03         21947       19992      24791           22587
# 95  2020-07-04         22718       20741      25662           23486
# 96  2020-07-05         24018       21178      27131           24671
# 97  2020-07-06         23942       21884      27131           24751
# 98  2020-07-07         22500       22511      27131           24767
# 99  2020-07-08         23147       23338      27131           24881
# 100 2020-07-09         25561       24380      28874           26626
# 101 2020-07-10         25790       24539      28480           26420
# 102 2020-07-11         27762       25423      30657           28604
# 103 2020-07-12         27757       25766      30657           28376
# 104 2020-07-13         29106       26712      32141           29965
# 105 2020-07-14         28178       27656      32141           30083
# 106 2020-07-15         29917       28786      33037           31062
# 108   3925  -3189  -1684   2647  -1684   2712  -3112   8188
# 109   2642  -3837  -1852    900  -1182   4267    636   3057
# 110   3460  -3364  -1669   1988  -1669   2492  -2784   1872
# 111   4493  -3618  -1949   3079  -1949   3571  -3037   1655
# 112     40  -7047  -5072  -1694  -1503   4493   3137   2622
# 113   1016  -4683  -2722   -770  -1613    171  -2516  -1025
# 114   5105  -7487  -2362    778  -2362    778  -7487   2329
# 115   6144  -7953  -2333   1462  -2333   5573  -3019  14774
# 116   4317  -8027  -2546   -432  -2546   6134   -449   7202
# 117   3914  -8221  -2249  -1354  -2249   4829  -1213  -3016
# 118   2114  -9361  -2686  -3940  -1511   4550   1114  -2530
# 119  -1995 -11809  -5386  -7998  -1669   2027   2326  -2853
# 120   -420  -8662  -2264  -6591  -1807  -1931  -3360  -1654
# 121   2161  -3553  -1110   -133  -1110    376  -3011   4661
# 122 -51101 -58457 -55759 -53574 -55759 -52348 -57119 -44158
#
# [123 rows x 8 columns]

# %%
for j,k in zip(range(len(edf)),range(len(tce)-1)):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(tce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)
# Out:
# for date: 2020-03-31  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-04-01  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-04-02  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-03  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-04-05  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-04-06  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-04-07  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-04-08  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-04-09  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-10  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-11  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-12  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-04-13  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-14  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-15  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-16  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-04-17  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-18  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-04-19  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-20  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-04-21  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-22  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-04-23  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-24  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-25  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-04-26  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-04-27  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-28  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-29  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-30  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-01  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-05-02  the lowest positve error was by the method: mdb and the highest negative error by the method: mxmb
# for date: 2020-05-03  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-06  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-07  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-08  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-09  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-10  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-05-11  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-05-12  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-13  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-14  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-15  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-05-16  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-17  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-18  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-19  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-20  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-21  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-05-22  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-23  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-24  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-25  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-26  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-27  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-05-28  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-05-29  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-30  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-31  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-06-01  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-06-02  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-06-03  the lowest positve error was by the method: mdb and the highest negative error by the method: lmb
# for date: 2020-06-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-05  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-06-06  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-06-07  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-08  the lowest positve error was by the method: mdb and the highest negative error by the method: mxmb
# for date: 2020-06-09  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-06-10  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-06-11  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-12  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-06-13  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-06-14  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-06-15  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-06-16  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-06-17  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-06-18  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-06-19  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-20  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-21  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-06-22  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-06-23  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-06-24  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-06-25  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-26  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-27  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-06-28  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-29  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-06-30  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-07-01  the lowest positve error was by the method: lb and the highest negative error by the method: lmb
# for date: 2020-07-02  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-07-03  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-04  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-05  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-06  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-07-07  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-07-08  the lowest positve error was by the method: lb and the highest negative error by the method: lmb
# for date: 2020-07-09  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-07-10  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-12  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-07-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-14  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-07-15  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-16  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-18  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-07-19  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-20  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-21  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-07-22  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-23  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-24  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-07-25  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-07-26  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-27  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-07-28  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-07-29  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-07-30  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(tce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(tce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(tce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(tce["date"][k]).strip("00:00:00"))
    org_val.append(tce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 '],
#  'mipe': ['lmb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mb',
#   'lmb',
#   'No',
#   'lb',
#   'mb',
#   'mb',
#   'lb',
#   'mb',
#   'mb',
#   'mb',
#   'lmb',
#   'mb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mb',
#   'mb',
#   'lb',
#   'mb',
#   'lb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'lmb',
#   'lb',
#   'lb',
#   'lmb',
#   'mb',
#   'mb',
#   'lb',
#   'mb',
#   'lmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'mb',
#   'lmb',
#   'lb',
#   'mlb',
#   'mb',
#   'mb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'mb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'No',
#   'mb',
#   'lb',
#   'mb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'No',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'No',
#   'mb',
#   'mb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'mb',
#   'lb',
#   'lmb',
#   'No',
#   'lmb',
#   'No'],
#  'mxne': ['memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'lb',
#   'mlb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'mlb',
#   'mlb',
#   'mxmb',
#   'mlb',
#   'mlb',
#   'mlb',
#   'mlb',
#   'memb',
#   'memb',
#   'mlb',
#   'mlb',
#   'mb',
#   'lmb',
#   'mlb',
#   'memb',
#   'mlb',
#   'mb',
#   'lmb',
#   'mb',
#   'mlb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'memb',
#   'mlb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mlb',
#   'memb',
#   'mlb',
#   'mb',
#   'lmb',
#   'mlb',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mlb',
#   'lb',
#   'lb',
#   'lb',
#   'memb',
#   'mb',
#   'mb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'mb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'mlb',
#   'mxmb',
#   'mxmb',
#   'mlb',
#   'mb',
#   'lmb',
#   'mlb',
#   'lb',
#   'memb',
#   'mlb',
#   'mlb',
#   'mlb',
#   'memb',
#   'mxmb',
#   'memb',
#   'memb',
#   'mlb',
#   'mlb',
#   'mlb',
#   'mxmb',
#   'memb',
#   'lb',
#   'memb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mlb',
#   'memb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mb',
#   'lmb',
#   'lmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mlb',
#   'mxmb',
#   'memb',
#   'memb',
#   'mlb',
#   'memb',
#   'memb',
#   'mlb',
#   'mxmb',
#   'memb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mlb',
#   'mlb',
#   'mb',
#   'mxmb',
#   'mdb'],
#  'mipv': [2,
#   58,
#   4,
#   131,
#   35,
#   101,
#   32,
#   92,
#   'No',
#   8,
#   161,
#   178,
#   17,
#   21,
#   294,
#   50,
#   93,
#   40,
#   67,
#   218,
#   247,
#   54,
#   14,
#   206,
#   164,
#   190,
#   228,
#   56,
#   38,
#   212,
#   177,
#   16,
#   89,
#   494,
#   122,
#   430,
#   189,
#   148,
#   240,
#   5,
#   45,
#   577,
#   69,
#   30,
#   93,
#   59,
#   175,
#   534,
#   758,
#   229,
#   47,
#   402,
#   490,
#   481,
#   519,
#   584,
#   629,
#   19,
#   431,
#   306,
#   327,
#   884,
#   966,
#   937,
#   216,
#   110,
#   660,
#   290,
#   246,
#   874,
#   956,
#   'No',
#   837,
#   21,
#   476,
#   625,
#   291,
#   349,
#   'No',
#   1348,
#   1349,
#   173,
#   419,
#   561,
#   1108,
#   290,
#   596,
#   46,
#   179,
#   706,
#   518,
#   34,
#   83,
#   123,
#   4,
#   55,
#   729,
#   76,
#   1355,
#   'No',
#   1181,
#   1251,
#   514,
#   5,
#   454,
#   522,
#   482,
#   1293,
#   2647,
#   636,
#   1872,
#   1655,
#   40,
#   171,
#   778,
#   1462,
#   4317,
#   3914,
#   1114,
#   2027,
#   'No',
#   376,
#   'No'],
#  'mxnv': [-33,
#   -10,
#   -139,
#   -57,
#   -85,
#   -3,
#   -32,
#   -83,
#   -13,
#   -13,
#   -47,
#   -53,
#   -62,
#   -37,
#   -87,
#   -123,
#   -89,
#   -71,
#   -35,
#   -151,
#   -234,
#   -32,
#   -130,
#   -99,
#   -104,
#   -129,
#   -120,
#   -41,
#   -74,
#   -53,
#   -61,
#   -42,
#   -39,
#   -10,
#   -292,
#   -499,
#   -236,
#   -188,
#   -51,
#   -53,
#   -133,
#   -307,
#   -48,
#   -137,
#   -17,
#   -142,
#   -39,
#   -203,
#   -81,
#   -193,
#   -554,
#   -419,
#   -319,
#   -557,
#   -134,
#   -407,
#   -313,
#   -412,
#   -284,
#   -8,
#   -301,
#   -232,
#   -315,
#   -157,
#   -369,
#   -444,
#   -155,
#   -238,
#   -145,
#   -12,
#   -180,
#   -97,
#   -66,
#   -280,
#   12480,
#   14567,
#   15499,
#   14590,
#   12452,
#   15366,
#   16272,
#   18159,
#   18076,
#   19436,
#   19092,
#   18305,
#   18173,
#   19306,
#   21943,
#   22663,
#   23289,
#   23866,
#   21145,
#   'No',
#   24380,
#   24539,
#   27248,
#   27752,
#   28652,
#   27656,
#   29435,
#   31314,
#   32821,
#   34184,
#   35539,
#   38580,
#   36766,
#   38999,
#   44823,
#   46981,
#   44571,
#   46158,
#   47818,
#   44457,
#   'No',
#   52103,
#   'No'],
#  'nprd_val': [220,
#   319,
#   563,
#   543,
#   645,
#   582,
#   641,
#   567,
#   586,
#   578,
#   860,
#   924,
#   916,
#   795,
#   1330,
#   1154,
#   975,
#   1132,
#   957,
#   1522,
#   1814,
#   1271,
#   1667,
#   1391,
#   1771,
#   1537,
#   1955,
#   1648,
#   1642,
#   1955,
#   1766,
#   1843,
#   2435,
#   2574,
#   3244,
#   4155,
#   3207,
#   3790,
#   3395,
#   3392,
#   3308,
#   4618,
#   3640,
#   3699,
#   3743,
#   4133,
#   3847,
#   4997,
#   5130,
#   4821,
#   6708,
#   6139,
#   6342,
#   7093,
#   6801,
#   7518,
#   6727,
#   6319,
#   7530,
#   7262,
#   8439,
#   8596,
#   9104,
#   7880,
#   9181,
#   10133,
#   10002,
#   9710,
#   10553,
#   10894,
#   8716,
#   10078,
#   11222,
#   11415,
#   11480,
#   12375,
#   11563,
#   10308,
#   11289,
#   13469,
#   13987,
#   15372,
#   16635,
#   15843,
#   14209,
#   16516,
#   17438,
#   18995,
#   18305,
#   20902,
#   19648,
#   18999,
#   18441,
#   19856,
#   22587,
#   23486,
#   24671,
#   23988,
#   22511,
#   23177,
#   25846,
#   26021,
#   28604,
#   27837,
#   29965,
#   29124,
#   30616,
#   33788,
#   37152,
#   36002,
#   39080,
#   42184,
#   38309,
#   39940,
#   47963,
#   50776,
#   49320,
#   51285,
#   50443,
#   48153,
#   50051,
#   52612,
#   44158]}

# %%
pd.DataFrame(err_dict)
# Out:
#             date  mipe  mxne  mipv   mxnv  original_val pprd_val  nprd_val
# 0    2020-03-31    lmb  memb     2    -33           187      185       220
# 1    2020-04-01    lmb  mxmb    58    -10           309      251       319
# 2    2020-04-02   mxmb  memb     4   -139           424      420       563
# 3    2020-04-03     mb  mxmb   131    -57           486      355       543
# 4    2020-04-04   mxmb    lb    35    -85           560      525       645
# 5    2020-04-05     mb   mdb   101     -3           579      478       582
# 6    2020-04-06     mb    lb    32    -32           609      577       641
# 7    2020-04-07    lmb   mlb    92    -83           484      392       567
# 8    2020-04-08     No    mb    No    -13           573       No       586
# 9    2020-04-09     lb    mb     8    -13           565      557       578
# 10   2020-04-10     mb  mxmb   161    -47           813      652       860
# 11   2020-04-11     mb  mxmb   178    -53           871      693       924
# 12   2020-04-12     lb   mlb    17    -62           854      837       916
# 13   2020-04-13     mb   mlb    21    -37           758      737       795
# 14   2020-04-14     mb  mxmb   294    -87          1243      949      1330
