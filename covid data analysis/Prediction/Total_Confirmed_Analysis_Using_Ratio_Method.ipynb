# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\35\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_total=data[53:]
data_total.reset_index(drop=True,inplace=True)
data_total.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_total.tail()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 132  02 August             52672          1804857            40355
# 133  03 August             50488          1855345            43070
# 134  04 August             51282          1906627            51220
# 135  05 August             56626          1963253            45583
# 136  06 August             62170          2025423            50141
#
#      Total Recovered  Daily Deceased  Total Deceased
# 132          1187261             760           38180
# 133          1230331             806           38986
# 134          1281551             849           39835
# 135          1327134             919           40754
# 136          1377275             899           41653

# %%
colls=list(data_total.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_total.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_total[data_total.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_total['Date'] = data_total['Date'].astype('str')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,9):
    data_total["Date"][i]=data_total["Date"][i].strip(" March")
for i in range(0,9):
    data_total["Date"][i]="2020-03-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(9,39):
    data_total["Date"][i]=data_total["Date"][i].strip(" April")
for i in range(9,39):
    data_total["Date"][i]="2020-04-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(39,70):
    data_total["Date"][i]=data_total["Date"][i].strip(" May")
for i in range(39,70):
    data_total["Date"][i]="2020-05-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(70,100):
    data_total["Date"][i]=data_total["Date"][i].strip(" June")
for i in range(70,100):
    data_total["Date"][i]="2020-06-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(100,131):
    data_total["Date"][i]=data_total["Date"][i].strip(" July")
for i in range(100,131):
    data_total["Date"][i]="2020-07-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(131,len(data_total)):
    data_total["Date"][i]=data_total["Date"][i].strip(" August")
for i in range(131,len(data_total)):
    data_total["Date"][i]="2020-08-"+data_total["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data_total["Date"]=data_total["Date"].astype('datetime64[ns]')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_total.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_total_ratio_with_two_precision=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio_with_two_precision[i]=list(range(len(data_total_ratio_with_two_precision)))
    data_total_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio_with_two_precision[i][0])
    for k in range(0,len(data_total_ratio_with_two_precision)-1):
        tmp.append(round(data_total_ratio_with_two_precision[j][k+1]/data_total_ratio_with_two_precision[j][k],2))
    data_total_ratio_with_two_precision[i]=tmp
data_total_ratio_with_two_precision.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_total_ratio=data_total.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_total_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_total_ratio[i]=list(range(len(data_total_ratio)))
    data_total_ratio[i][0]=1
    tmp=[]
    tmp.append(data_total_ratio[i][0])
    for k in range(0,len(data_total_ratio)-1):
        tmp.append(data_total_ratio[j][k+1]/data_total_ratio[j][k])
    data_total_ratio[i]=tmp
data_total_ratio.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_total_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_total_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    tcr=data_total_ratio.iloc[st:en,8:9]
    tcr.reset_index(inplace = True, drop = True)
    tc=data_total_ratio.iloc[st:en,2:3]
    tc.reset_index(inplace = True, drop = True)



    next_day_tconfirmed_case_count_mean_based=tcr.mean()[0]*tc.mean()[0]

    next_day_tconfirmed_case_count_max_based=max(tcr["Total_Confirmed_Ratio"])*max(tc["Total Confirmed"])


    next_day_tconfirmed_case_count_mean_max_based=tcr.mean()[0]*max(tc["Total Confirmed"])


    next_day_tconfirmed_case_count_max_mean_based=max(tcr["Total_Confirmed_Ratio"])*tc.mean()[0]


    next_day_tconfirmed_case_count_mean_last_based=tcr.mean()[0]*tc["Total Confirmed"][len(tc)-1]


    next_day_tconfirmed_case_count_last_mean_based=tcr["Total_Confirmed_Ratio"][len(tcr)-1]*tc.mean()[0]


    next_day_tconfirmed_case_count_last_based=tcr["Total_Confirmed_Ratio"][len(tcr)-1]*tc["Total Confirmed"][len(tc)-1]


    next_day_tconfirmed_case_count_middle_based=tcr["Total_Confirmed_Ratio"][3]*tc["Total Confirmed"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_tconfirmed_case_count_mean_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_max_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_mean_max_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_max_mean_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_mean_last_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_last_mean_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_last_based))
    pred_val.append(np.round(next_day_tconfirmed_case_count_middle_based))


    
    if(en<len(data_total_ratio)):
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_total_ratio["Total Confirmed"][en],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_total_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
        
        
        
    
    
    pred_df=pd.DataFrame(pred_dict, index=[0])
    
    
    
d=pd.read_excel(r"C:\Users\Mark 1\tamprd_df_strd.xlsx")
d=pd.concat([d,pred_df])
d.reset_index(drop=True,inplace=True)
d['original_val'][len(d)-2]=data_total_ratio['Total Confirmed'][len(data_total_ratio)-1]
d.to_excel("tamprd_df_strd.xlsx")
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tc=pd.read_excel(r"C:\Users\Mark 1\tamprd_df_strd.xlsx")
tc
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31          1635        1040       1604            1526
# 1   2020-04-01          2059        1228       2016            1901
# 2   2020-04-02          2545        1480       2593            2426
# 3   2020-04-03          3105        1813       3205            3045
# 4   2020-04-04          3684        2195       3910            3719
# 5   2020-04-05          4293        2661       4639            4430
# 6   2020-04-06          4777        3221       5406            5191
# 7   2020-04-07          5350        3794       6016            5741
# 8   2020-04-08          5915        4372       6737            6343
# 9   2020-04-09          6728        4932       7311            6884
# 10  2020-04-10          7599        5560       8208            7735
# 11  2020-04-11          8453        6227       9016            8638
# 12  2020-04-12          9211        6936       9850            9519
# 13  2020-04-13         10454        7653      10477           10273
# 14  2020-04-14         11485        8582      11891           11693
# 15  2020-04-15         12371        9536      13064           12811
# 16  2020-04-16         13432       10527      14071           13749
# 17  2020-04-17         14354       11514      15245           14829
# 18  2020-04-18         15725       12480      16291           15722
# 19  2020-04-19         17305       13588      17847           17186
# 20  2020-04-20         18544       14873      19640           18939
# 21  2020-04-21         20081       16004      20407           20128
# 22  2020-04-22         21373       17301      22099           21751
# 23  2020-04-23         23040       18663      23520           23111
# 24  2020-04-24         24448       20126      25355           24888
# 25  2020-04-25         26283       21662      26904           26383
# 26  2020-04-26         27890       23227      28924           28286
# 27  2020-04-27         29458       24724      30202           29859
# 28  2020-04-28         31360       26339      31900           31473
# 29  2020-04-29         33065       27992      33806           33423
# ..         ...           ...         ...        ...             ...
# 100 2020-07-09        794847      721670     797479          795834
# 101 2020-07-10        822609      746176     824222          822212
# 102 2020-07-11        850366      771562     853010          850778
# 103 2020-07-12        879472      797280     880577          879095
# 104 2020-07-13        907650      823954     910190          909021
# 105 2020-07-14        937567      851587     939352          938119
# 106 2020-07-15        970174      880343     970314          969151
# 107 2020-07-16       1005642      910092    1004060         1002912
# 108 2020-07-17       1040462      941615    1042407         1040011
# 125         1699415          1864775          1691205     1859112
# 126         1754545          1915774          1742530     1907245
# 127         1809920          1967136          1796943     1959326
# 128         1865908          2024283          1856242     2021561
# 129         1922960          2087511          1916654     2089562
#
#      middle_based
# 0            1068
# 1            1176
# 2            1273
# 3            1544
# 4            2016
# 5            2593
# 6            3146
# 7            3788
# 8            4371
# 9            5003
# 10           5316
# 11           5992
# 12           6540
# 13           7653
# 14           8583
# 15           9403
# 16          10037
# 17          11865
# 18          12618
# 19          13325
# 20          14584
# 21          15339
# 22          17227
# 23          19044
# 24          19872
# 25          21745
# 26          22748
# 27          24837
# 28          25942
# 29          28256
# ..            ...
# 100        722642
# 101        743574
# 102        767387
# 103        795497
# 104        821502
# 105        851341
# 106        879060
# 107        909574
# 108        936731
# 109        968470
# 110       1003915
# 111       1042407
# 112       1076488
# 113       1116629
# 114       1159845
# 115       1192932
# 116       1234582
# 117       1287027
# 118       1338464
# 119       1387759
# 120       1439035
# 121       1486678
# 122       1530493
# 123       1583428
# 124       1638891
# 125       1696457
# 126       1756570
# 127       1809092
# 128       1859112
# 129       1907245
#
# [130 rows x 10 columns]

# %%
tce=tc.copy()

# %%
colls=list(tc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    tce[i]=pd.Series(range(1,len(tce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(tce)):
        tce[j][k]=tce["original_val"][k]-tce[i][k]
tce
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31          1635        1040       1604            1526
# 1   2020-04-01          2059        1228       2016            1901
# 2   2020-04-02          2545        1480       2593            2426
# 3   2020-04-03          3105        1813       3205            3045
# 4   2020-04-04          3684        2195       3910            3719
# 5   2020-04-05          4293        2661       4639            4430
# 6   2020-04-06          4777        3221       5406            5191
# 7   2020-04-07          5350        3794       6016            5741
# 8   2020-04-08          5915        4372       6737            6343
# 9   2020-04-09          6728        4932       7311            6884
# 10  2020-04-10          7599        5560       8208            7735
# 11  2020-04-11          8453        6227       9016            8638
# 12  2020-04-12          9211        6936       9850            9519
# 13  2020-04-13         10454        7653      10477           10273
# 14  2020-04-14         11485        8582      11891           11693
# 15  2020-04-15         12371        9536      13064           12811
# 16  2020-04-16         13432       10527      14071           13749
# 17  2020-04-17         14354       11514      15245           14829
# 18  2020-04-18         15725       12480      16291           15722
# 19  2020-04-19         17305       13588      17847           17186
# 20  2020-04-20         18544       14873      19640           18939
# 21  2020-04-21         20081       16004      20407           20128
# 22  2020-04-22         21373       17301      22099           21751
# 23  2020-04-23         23040       18663      23520           23111
# 24  2020-04-24         24448       20126      25355           24888
# 25  2020-04-25         26283       21662      26904           26383
# 26  2020-04-26         27890       23227      28924           28286
# 27  2020-04-27         29458       24724      30202           29859
# 28  2020-04-28         31360       26339      31900           31473
# 29  2020-04-29         33065       27992      33806           33423
# ..         ...           ...         ...        ...             ...
# 118       1338464   144525    -9631    -5783   141065    -5783   145971
# 119       1387759   145759    -8301    -4212   142069    -4212   151041
# 120       1439035   148278    -7392    -3071   144368    -3071   152129
# 121       1486678   152991    -6954    -1593   148135    -1593   155060
# 122       1530493   159408    -4741       -9   155121       -9   159970
# 123       1583428   161920    -8439    -3693   157622    -3693   161294
# 124       1638891   161757    -9139    -6803   159638    -6803   164086
# 125       1696457   158989   -12793    -9430   155930    -9430   164140
# 126       1756570   156304   -13769    -9147   152082    -9147   164097
# 127       1809092   159147   -10223    -3883   153333    -3883   166310
# 128       1859112   166682    -6664     1140   159515     1140   169181
# 129       1907245 -1914773 -2096437 -2087511 -1922960 -2087511 -1916654
#
#           lb      mdb
# 0         91      567
# 1         43      883
# 2        -48     1272
# 3        -41     1561
# 4       -104     1668
# 5        -78     1700
# 6       -226     1631
# 7         34     1562
# 8        -77     1544
# 9        188     1725
# 10       -54     2283
# 11      -130     2461
# 12      -192     2671
# 13       417     2801
# 14      -380     2902
# 15      -247     2968
# 16       107     3395
# 17      -230     2489
# 18       386     3107
# 19        78     3980
# 20      -500     3960
# 21       209     4742
# 22      -372     4146
# 23       292     3996
# 24      -389     4576
# 25       341     4538
# 26      -366     5142
# 27      -137     4621
# 28       246     5418
# 29      -320     4809
# ..       ...      ...
# 100     -650    72205
# 101     1107    79035
# 102     -975    82979
# 103      412    83975
# 104    -1924    86148
# 105      836    86226
# 106     1704    91114
# 107     1727    96068
# 108    -1945   103731
# 109     1385   109403
# 110     1479   114193
# 111    -4931   112507
# 112     1152   117596
# 113     5103   123056
# 114     1101   128283
# 115    -1448   144084
# 116     -671   152506
# 117    -3015   148993
# 118    -4174   144040
# 119     1642   144376
# 120     1186   145579
# 121      691   152904
# 122      611   166575
# 123    -4385   168757
# 124    -4235   165966
# 125    -3767   158888
# 126     -618   150057
# 127     3927   154161
# 128     3862   166311
# 129 -2089562 -1907245
#
# [130 rows x 18 columns]

# %%
tce.to_excel("tamerrprd_df_strd.xlsx")

# %%
edf=tce.iloc[0:len(tce),10:]
edf
# Out:
#           mb      mxb     memb     mxmb      mlb      lmb       lb      mdb
# 0        595       31      109      542      109      583       91      567
# 1        831       43      158      757      158      757       43      883
# 2       1065      -48      119      963      119      963      -48     1272
# 3       1292     -100       60     1197       60     1232      -41     1561
# 4       1489     -226      -35     1376      -35     1448     -104     1668
# 5       1632     -346     -137     1506     -137     1667      -78     1700
# 6       1556     -629     -414     1422     -414     1673     -226     1631
# 7       1556     -666     -391     1374     -391     1837       34     1562
# 8       1543     -822     -428     1271     -428     1785      -77     1544
# 9       1796     -583     -156     1489     -156     2042      188     1725
# 10      2039     -609     -136     1699     -136     2098      -54     2283
# 11      2226     -563     -185     1953     -185     2266     -130     2461
# 12      2275     -639     -308     2034     -308     2360     -192     2671
# 13      2801      -23      181     2649      181     2977      417     2801
# 14      2903     -406     -208     2758     -208     2777     -380     2902
# 15      2835     -693     -440     2647     -440     2979     -247     2968
# 16      2905     -639     -317     2659     -317     3230      107     3395
# 17      2840     -891     -475     2517     -475     3030     -230     2489
# 18      3245     -566        3     2793        3     3549      386     3107
# 19      3717     -542      119     3194      119     3684       78     3980
# 20      3671    -1096     -395     3121     -395     3589     -500     3960
# 21      4077     -326      -47     3854      -47     4280      209     4742
# 22      4072     -726     -378     3795     -378     4076     -372     4146
# 23      4377     -480      -71     4047      -71     4670      292     3996
# 24      4322     -907     -440     3944     -440     4363     -389     4576
# 25      4621     -621     -100     4192     -100     4983      341     4538
# 26      4663    -1034     -396     4140     -396     4688     -366     5142
# 27      4734     -744     -401     4450     -401     4952     -137     4621
# 28      5021     -540     -113     4663     -113     5321      246     5418
# 29      5073     -741     -358     4752     -358     5105     -320     4809
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 100    73177    -2632     -987    71685     -987    73483     -650    72205
# 101    76433    -1613      397    74608      397    77077     1107    79035
# 102    78804    -2644     -412    76779     -412    78293     -975    82979
# 103    82192    -1105      377    80848      377    82224      412    83975
# 104    83696    -2540    -1371    82636    -1371    83194    -1924    86148
# 105    85980    -1785     -552    84861     -552    87240      836    86226
# 106    89831     -140     1023    88775     1023    90450     1704    91114
# 107    95550     1582     2730    94509     2730    94640     1727    96068
# 108    98847    -1945      451    96679      451    96679    -1945   103731
# 109   104114     -627     1897   101830     1897   103651     1385   109403
# 110   110430      830     3103   108376     3103   108962     1479   114193
# 111   111524    -4931    -2207   109069    -2207   109069    -4931   112507
# 112   114007    -3941    -1273   111597    -1273   116199     1152   117596
# 113   121533     1028     3624   119184     3624   122870     5103   123056
# 114   129575     1101     4259   126725     4259   126725     1101   128283
# 115   136253    -1448     2514   132688     2514   132688    -1448   144084
# 116   141864    -2174     1302   138740     1302   140090     -671   152506
# 117   144745    -5271    -1961   141772    -1961   143798    -3015   148993
# 118   144525    -9631    -5783   141065    -5783   145971    -4174   144040
# 119   145759    -8301    -4212   142069    -4212   151041     1642   144376
# 120   148278    -7392    -3071   144368    -3071   152129     1186   145579
# 121   152991    -6954    -1593   148135    -1593   155060      691   152904
# 122   159408    -4741       -9   155121       -9   159970      611   166575
# 123   161920    -8439    -3693   157622    -3693   161294    -4385   168757
# 124   161757    -9139    -6803   159638    -6803   164086    -4235   165966
# 125   158989   -12793    -9430   155930    -9430   164140    -3767   158888
# 126   156304   -13769    -9147   152082    -9147   164097     -618   150057
# 127   159147   -10223    -3883   153333    -3883   166310     3927   154161
# 128   166682    -6664     1140   159515     1140   169181     3862   166311
# 129 -1914773 -2096437 -2087511 -1922960 -2087511 -1916654 -2089562 -1907245
#
# [130 rows x 8 columns]

# %%
"""
for j,k in zip(range(len(edf)),range(len(tce)-1)):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(tce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)
    """
# Out:
# '\nfor j,k in zip(range(len(edf)),range(len(tce)-1)):\n    \n    a=list(edf.loc[j])\n    pos=[]\n    neg=[]\n    for i in a:\n        if(i>=0):\n            pos.append(i)\n        else:\n            neg.append(i)\n    if(len(pos)):\n        ps=min(pos)\n        psi=a.index(ps)\n        psc=list(edf.columns)[psi]\n    if(len(neg)):\n        ng=max(neg)\n        ngi=a.index(ng)\n        ngc=list(edf.columns)[ngi]\n    \n    \n    print("for date: "+str(tce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)\n    '

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(tce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(tce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(tce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(tce["date"][k]).strip("00:00:00"))
    org_val.append(tce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-08-02 ',
#   '2020-08-03 ',
#   '2020-08-04 ',
#   '2020-08-05 ',
#   '2020-08-06 ',
#   '2020-08-07 '],
#  'mipe': ['mxb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'memb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'mxb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'lb',
#   'mxb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'lb',
#   'lb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'lb',
#   'memb',
#   'No'],
#  'mxne': ['No',
#   'No',
#   'mxb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'lb',
#   'mxb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'mxb',
#   'mxb',
#   'No',
#   'No',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'lb',
#   'mxb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'lb',
#   'memb',
#   'No',
#   'mxb',
#   'lb',
#   'mxb',
#   'memb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'memb',
#   'lb',
#   'memb',
#   'memb',
#   'memb',
#   'memb',
#   'memb',
#   'lb',
#   'lb',
#   'memb',
#   'memb',
#   'lb',
#   'memb',
#   'mxb',
#   'mxb',
#   'mxb',
#   'No',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'mxb',
#   'lb',
#   'mxb',
#   'mxb',
#   'memb',
#   'lb',
#   'memb',
#   'mxb',
#   'lb',
#   'mxb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   'lb',
#   'mxb',
#   'memb',
#   'mxb',
#   'memb',
#   'memb',
#   'mxb',
#   'No',
#   'mxb',
#   'mxb',
#   'No',
#   'memb',
#   'memb',
#   'No',
#   'No',
#   'mxb',
#   'lb',
#   'memb',
#   'lb',
#   'memb',
#   
#   1287027,
#   1334502,
#   1385786,
#   1294248,
#   1341439,
#   1530493,
#   1583428,
#   1638891,
#   1696457,
#   1594563,
#   1645219,
#   1699415,
#   1756570,
#   1959326,
#   2024283,
#   'No'],
#  'nprd_val': ['No',
#   'No',
#   2593,
#   3146,
#   3719,
#   4371,
#   5003,
#   5741,
#   5992,
#   6884,
#   7653,
#   8583,
#   9403,
#   10477,
#   11693,
#   12618,
#   13749,
#   14584,
#   16291,
#   17847,
#   18939,
#   20128,
#   21745,
#   23111,
#   24837,
#   26383,
#   28256,
#   29595,
#   31473,
#   33385,
#   35193,
#   37483,
#   40059,
#   'No',
#   'No',
#   49555,
#   53627,
#   56706,
#   59906,
#   63227,
#   68238,
#   71652,
#   74552,
#   78071,
#   82494,
#   86242,
#   91743,
#   95711,
#   100661,
#   'No',
#   113011,
#   118227,
#   125475,
#   131602,
#   138587,
#   146035,
#   151662,
#   158558,
#   165698,
#   174500,
#   181867,
#   191703,
#   199547,
#   207467,
#   217384,
#   226894,
#   237017,
#   246838,
#   257569,
#   268781,
#   277412,
#   287547,
#   298765,
#   309860,
#   321804,
#   334080,
#   344852,
#   355773,
#   368476,
#   381551,
#   395917,
#   'No',
#   428308,
#   442320,
#   456473,
#   474459,
#   492005,
#   510099,
#   529931,
#   550528,
#   569325,
#   586490,
#   607115,
#   629153,
#   649914,
#   675584,
#   698813,
#   722144,
#   743574,
#   769254,
#   795497,
#   824222,
#   850778,
#   880577,
#   909021,
#   938119,
#   970314,
#   'No',
#   1042407,
#   1078500,
#   'No',
#   1157121,
#   1195357,
#   'No',
#   'No',
#   1338464,
#   1387759,
#   1437981,
#   1486678,
#   1536347,
#   1587685,
#   1641175,
#   1697077,
#   1755878,
#   1809092,
#   1859112,
#   1907245,
#   1967136,
#   2032087,
#   1907245]}

# %%
err_df=pd.DataFrame(err_dict)
err_df
# Out:
#             date  mipe  mxne    mipv      mxnv  original_val pprd_val nprd_val
# 0    2020-03-31    mxb    No      31        No          1635     1604       No
# 1    2020-04-01    mxb    No      43        No          2059     2016       No
# 2    2020-04-02   memb   mxb     119       -48          2545     2426     2593
# 3    2020-04-03   memb    lb      60       -41          3105     3045     3146
# 4    2020-04-04   mxmb  memb    1376       -35          3684     2308     3719
# 5    2020-04-05   mxmb    lb    1506       -78          4293     2787     4371
# 6    2020-04-06   mxmb    lb    1422      -226          4777     3355     5003
# 7    2020-04-07     lb  memb      34      -391          5350     5316     5741
# 8    2020-04-08   mxmb    lb    1271       -77          5915     4644     5992
# 9    2020-04-09     lb  memb     188      -156          6728     6540     6884
# 10   2020-04-10   mxmb    lb    1699       -54          7599     5900     7653
# 11   2020-04-11   mxmb    lb    1953      -130          8453     6500     8583
# 12   2020-04-12   mxmb    lb    2034      -192          9211     7177     9403
# 13   2020-04-13   memb   mxb     181       -23         10454    10273    10477
# 14   2020-04-14   mxmb  memb    2758      -208         11485     8727    11693
# 15   2020-04-15   mxmb    lb    2647      -247         12371     9724    12618
# 16   2020-04-16     lb  memb     107      -317         13432    13325    13749
