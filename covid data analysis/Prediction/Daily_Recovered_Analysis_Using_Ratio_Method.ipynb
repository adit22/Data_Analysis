# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\106\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_daily=data[53:]
data_daily.reset_index(drop=True,inplace=True)
data_daily.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_daily.tail()
# Out:
#             Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 203  12 October             54262          7173571            78365
# 204  13 October             63717          7237288            74079
# 205  14 October             67811          7305099            81582
# 206  15 October             63441          7368540            70792
# 207  16 October             62302          7430842            70568
#
#      Total Recovered  Daily Deceased  Total Deceased
# 203          6224767             710          109308
# 204          6298846             727          110035
# 205          6380428             690          110725
# 206          6451220             882          111607
# 207          6521788             840          112447

# %%
colls=list(data_daily.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_daily.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_daily[data_daily.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_daily['Date'] = data_daily['Date'].astype('str')
# Out:
# <ipython-input-8-b893dc2657ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily['Date'] = data_daily['Date'].astype('str')

# %%
for i in range(0,9):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" March")
for i in range(0,9):
    data_daily["Date"][i]="2020-03-"+data_daily["Date"][i]
# Out:
# <ipython-input-9-5d3a9c25c0f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]=data_daily["Date"][i].strip(" March")
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <ipython-input-9-5d3a9c25c0f3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]="2020-03-"+data_daily["Date"][i]

# %%
for i in range(9,39):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" April")
for i in range(9,39):
    data_daily["Date"][i]="2020-04-"+data_daily["Date"][i]
# Out:
# <ipython-input-10-e708bf0423ae>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]=data_daily["Date"][i].strip(" April")
# <ipython-input-10-e708bf0423ae>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]="2020-04-"+data_daily["Date"][i]

# %%
for i in range(39,70):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" May")
for i in range(39,70):
    data_daily["Date"][i]="2020-05-"+data_daily["Date"][i]
# Out:
# <ipython-input-11-3a877ff4aac3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]=data_daily["Date"][i].strip(" May")
# <ipython-input-11-3a877ff4aac3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]="2020-05-"+data_daily["Date"][i]

# %%
for i in range(70,100):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" June")
for i in range(70,100):
    data_daily["Date"][i]="2020-06-"+data_daily["Date"][i]
# Out:
# <ipython-input-12-7dad98128838>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]=data_daily["Date"][i].strip(" June")
# <ipython-input-12-7dad98128838>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]="2020-06-"+data_daily["Date"][i]

# %%
for i in range(100,131):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" July")
for i in range(100,131):
    data_daily["Date"][i]="2020-07-"+data_daily["Date"][i]
# Out:
# <ipython-input-13-8446ec7a3871>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]=data_daily["Date"][i].strip(" July")
# <ipython-input-13-8446ec7a3871>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]="2020-07-"+data_daily["Date"][i]

# %%
for i in range(131,162):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" August")
for i in range(131,162):
    data_daily["Date"][i]="2020-08-"+data_daily["Date"][i]
# Out:
# <ipython-input-14-8378c44cbf95>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]=data_daily["Date"][i].strip(" August")
# <ipython-input-14-8378c44cbf95>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]="2020-08-"+data_daily["Date"][i]

# %%
for i in range(162,192):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" September")
for i in range(162,192):
    data_daily["Date"][i]="2020-09-"+data_daily["Date"][i]
# Out:
# <ipython-input-15-35b96d5b39bd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]=data_daily["Date"][i].strip(" September")
# <ipython-input-15-35b96d5b39bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]="2020-09-"+data_daily["Date"][i]

# %%
for i in range(192,len(data_daily)):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" October")
for i in range(192,len(data_daily)):
    data_daily["Date"][i]="2020-10-"+data_daily["Date"][i]
# Out:
# <ipython-input-16-4fd5b8dff3d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]=data_daily["Date"][i].strip(" October")
# <ipython-input-16-4fd5b8dff3d9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"][i]="2020-10-"+data_daily["Date"][i]

# %%
#data_daily['Date'][162]=data_daily['Date'][162].strip("2020-09-2020-08-01")
#data_daily['Date'][162]="2020-09-01"

# %%
data_daily["Date"]=data_daily["Date"].astype('datetime64[ns]')
# Out:
# <ipython-input-18-523dc667f175>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily["Date"]=data_daily["Date"].astype('datetime64[ns]')

# %%
data_daily.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_daily_ratio_with_two_precision=data_daily.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_daily_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_daily_ratio_with_two_precision[i]=list(range(len(data_daily_ratio_with_two_precision)))
    data_daily_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_daily_ratio_with_two_precision[i][0])
    for k in range(0,len(data_daily_ratio_with_two_precision)-1):
        tmp.append(round(data_daily_ratio_with_two_precision[j][k+1]/data_daily_ratio_with_two_precision[j][k],2))
    data_daily_ratio_with_two_precision[i]=tmp
data_daily_ratio_with_two_precision.head()
# Out:
# <ipython-input-21-f5761363647c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily_ratio_with_two_precision[i][0]=1
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_daily_ratio=data_daily.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_daily_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_daily_ratio[i]=list(range(len(data_daily_ratio)))
    data_daily_ratio[i][0]=1
    tmp=[]
    tmp.append(data_daily_ratio[i][0])
    for k in range(0,len(data_daily_ratio)-1):
        tmp.append(data_daily_ratio[j][k+1]/data_daily_ratio[j][k])
    data_daily_ratio[i]=tmp
data_daily_ratio.head()
# Out:
# <ipython-input-23-d765217f50de>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_daily_ratio[i][0]=1
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_daily_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_daily_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    dcr=data_daily_ratio.iloc[st:en,9:10]
    dcr.reset_index(inplace = True, drop = True)
    dc=data_daily_ratio.iloc[st:en,3:4]
    dc.reset_index(inplace = True, drop = True)



    next_day_recovered_case_count_mean_based=dcr.mean()[0]*dc.mean()[0]

    next_day_recovered_case_count_max_based=max(dcr["Daily_Recovered_Ratio"])*max(dc["Daily Recovered"])


    next_day_recovered_case_count_mean_max_based=dcr.mean()[0]*max(dc["Daily Recovered"])


    next_day_recovered_case_count_max_mean_based=max(dcr["Daily_Recovered_Ratio"])*dc.mean()[0]


    next_day_recovered_case_count_mean_last_based=dcr.mean()[0]*dc["Daily Recovered"][len(dc)-1]


    next_day_recovered_case_count_last_mean_based=dcr["Daily_Recovered_Ratio"][len(dcr)-1]*dc.mean()[0]


    next_day_recovered_case_count_last_based=dcr["Daily_Recovered_Ratio"][len(dcr)-1]*dc["Daily Recovered"][len(dc)-1]


    next_day_recovered_case_count_middle_based=dcr["Daily_Recovered_Ratio"][3]*dc["Daily Recovered"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_recovered_case_count_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_middle_based))

    if(en<len(data_daily_ratio)):
        pred_dict={"date":data_daily_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_daily_ratio["Daily Recovered"][en],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_daily_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
        
    
    pred_df=pd.DataFrame(pred_dict, index=[0])
    

d=pd.read_excel(r"C:\Users\Mark 1\ramprd_df_strd.xlsx")
d=pd.concat([d,pred_df])
d.reset_index(drop=True,inplace=True)
d['original_val'][len(d)-2]=data_daily_ratio['Daily Recovered'][len(data_daily_ratio)-1]
d.to_excel("ramprd_df_strd.xlsx")
# Out:
# <ipython-input-24-ec28887caa50>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['original_val'][len(d)-2]=data_daily_ratio['Daily Recovered'][len(data_daily_ratio)-1]

# %%
dc=pd.read_excel(r"C:\Users\Mark 1\ramprd_df_strd.xlsx")
dc = dc.loc[:, ~dc.columns.str.contains('^Unnamed')]
dc.tail()
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 196 2020-10-13         73903       81564      97482           89883
# 197 2020-10-14         81582       78843      97482           88138
# 198 2020-10-15         70792       79637      98041           89260
# 199 2020-10-16         70568       77619      98041           88260
# 200 2020-10-17             0       75337      98041           87593
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 196           88460            79123            88460       85812
# 197           87202            73169            75099       69695
# 198           87472            81798            87472       89845
# 199           86220            70185            67936       61429
# 200           84323            69434            76326       70345
#
#      middle_based
# 196         86702
# 197         95911
# 198         57530
# 199         85811
# 200         70027

# %%
dce=dc.copy()

# %%
colls=list(dc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    dce[i]=pd.Series(range(1,len(dce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(dce)):
        dce[j][k]=dce["original_val"][k]-dce[i][k]
dce
# Out:
# <ipython-input-28-e3d4143616d2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dce[j][k]=dce["original_val"][k]-dce[i][k]
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31            13          41        262              89
# 1   2020-04-01            19          24        125              53
# 2   2020-04-02            22          31        125              59
# 3   2020-04-03            39          31        125              54
# 4   2020-04-04            56          28         80              50
# ..         ...           ...         ...        ...             ...
# 196 2020-10-13         73903       81564      97482           89883
# 197 2020-10-14         81582       78843      97482           88138
# 198 2020-10-15         70792       79637      98041           89260
# 199 2020-10-16         70568       77619      98041           88260
# 200 2020-10-17             0       75337      98041           87593
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 0               120               89               33          72
# 1                56               20                6           5
# 2                64               32               26          28
# 3                72               34               23          25
# 4                46               50               39          69
# ..              ...              ...              ...         ...
# 196           88460            79123            88460       85812
# 197           87202            73169            75099       69695
# 198           87472            81798            87472       89845
# 199           86220            70185            67936       61429
# 200           84323            69434            76326       70345
#
#      middle_based     mb    mxb   memb   mxmb    mlb    lmb     lb    mdb
# 0              89    -28   -249    -76   -107    -76    -20    -59    -76
# 1               4     -5   -106    -34    -37     -1     13     14     15
# 2              29     -9   -103    -37    -42    -10     -4     -6     -7
# 3              72      8    -86    -15    -33      5     16     14    -33
# 4               5     28    -24      6     10      6     17    -13     51
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 196         86702  -7661 -23579 -15980 -14557  -5220 -14557 -11909 -12799
# 197         95911   2739 -15900  -6556  -5620   8413   6483  11887 -14329
# 198         57530  -8845 -27249 -18468 -16680 -11006 -16680 -19053  13262
# 199         85811  -7051 -27473 -17692 -15652    383   2632   9139 -15243
# 200         70027 -75337 -98041 -87593 -84323 -69434 -76326 -70345 -70027
#
# [201 rows x 18 columns]

# %%
dce.to_excel("ramerrprd_df_strd.xlsx")
dce=pd.read_excel(r"C:\Users\Mark 1\ramerrprd_df_strd.xlsx")
dce = dce.loc[:, ~dce.columns.str.contains('^Unnamed')]
dce.to_excel("ramerrprd_df_strd.xlsx")

# %%
edf=dce.iloc[0:len(dce),10:]
edf
# Out:
#         mb    mxb   memb   mxmb    mlb    lmb     lb    mdb
# 0      -28   -249    -76   -107    -76    -20    -59    -76
# 1       -5   -106    -34    -37     -1     13     14     15
# 2       -9   -103    -37    -42    -10     -4     -6     -7
# 3        8    -86    -15    -33      5     16     14    -33
# 4       28    -24      6     10      6     17    -13     51
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 196  -7661 -23579 -15980 -14557  -5220 -14557 -11909 -12799
# 197   2739 -15900  -6556  -5620   8413   6483  11887 -14329
# 198  -8845 -27249 -18468 -16680 -11006 -16680 -19053  13262
# 199  -7051 -27473 -17692 -15652    383   2632   9139 -15243
# 200 -75337 -98041 -87593 -84323 -69434 -76326 -70345 -70027
#
# [201 rows x 8 columns]

# %%
"""
for j,k in zip(range(len(edf)),range(len(dce)-1)):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(dce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+ psc +" and the highest negative error by the method: "+ngc)
    """
# Out:
# '\nfor j,k in zip(range(len(edf)),range(len(dce)-1)):\n    \n    a=list(edf.loc[j])\n    pos=[]\n    neg=[]\n    for i in a:\n        if(i>=0):\n            pos.append(i)\n        else:\n            neg.append(i)\n    if(len(pos)):\n        ps=min(pos)\n        psi=a.index(ps)\n        psc=list(edf.columns)[psi]\n    if(len(neg)):\n        ng=max(neg)\n        ngi=a.index(ng)\n        ngc=list(edf.columns)[ngi]\n    \n    \n    print("for date: "+str(dce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+ psc +" and the highest negative error by the method: "+ngc)\n    '

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(dce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(dce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(dce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(dce["date"][k]).strip("00:00:00"))
    org_val.append(dce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-08-14 ',
#   '2020-08-15 ',
#   '2020-08-16 ',
#   '2020-08-17 ',
#   '2020-08-18 ',
#   '2020-08-19 ',
#   '2020-08-20 ',
#   '2020-08-21 ',
#   '2020-08-22 ',
#   '2020-08-23 ',
#   '2020-08-24 ',
#   '2020-08-25 ',
#   '2020-08-26 ',
#   '2020-08-27 ',
#   '2020-08-28 ',
#   '2020-08-29 ',
#   '2020-08-30 ',
#   '2020-08-31 ',
#   '2020-09-01 ',
#   '2020-09-02 ',
#   '2020-09-03 ',
#   '2020-09-04 ',
#   '2020-09-05 ',
#   '2020-09-06 ',
#   '2020-09-07 ',
#   '2020-09-08 ',
#   '2020-09-09 ',
#   '2020-09-10 ',
#   '2020-09-11 ',
#   '2020-09-12 ',
#   '2020-09-13 ',
#   '2020-09-14 ',
#   '2020-09-15 ',
#   '2020-09-16 ',
#   '2020-09-17 ',
#   '2020-09-18 ',
#   '2020-09-19 ',
#   '2020-09-20 ',
#   '2020-09-21 ',
#   '2020-09-22 ',
#   '2020-09-23 ',
#   '2020-09-24 ',
#   '2020-09-25 ',
#   '2020-09-26 ',
#   '2020-09-27 ',
#   '2020-09-28 ',
#   '2020-09-29 ',
#   '2020-09-30 ',
#   '2020-10-01 ',
#   '2020-10-02 ',
#   '2020-10-03 ',
#   '2020-10-04 ',
#   '2020-10-05 ',
#   '2020-10-06 ',
#   '2020-10-07 ',
#   '2020-10-08 ',
#   '2020-10-09 ',
#   '2020-10-10 ',
#   '2020-10-11 ',
#   '2020-10-12 ',
#   '2020-10-13 ',
#   '2020-10-14 ',
#   '2020-10-15 ',
#   '2020-10-16 ',
#   '2020-10-17 '],
#  'mipe': ['No',
#   'lmb',
#   'No',
#   'mlb',
#   'memb',
#   'mb',
#   'mlb',
#   'mdb',
#   'lb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'No',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'memb',
#   'No',
#   'mb',
#   'mdb',
#   'lmb',
#   'mb',
#   'No',
#   'mb',
#   'memb',
#   'lmb',
#   'mxb',
#   'mb',
#   'mb',
#   'memb',
#   'lb',
#   'lmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'No',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'lb',
#   'mlb',
#   'mb',
#   'mb',
#   'lb',
#   'No',
#   'mdb',
#   'No',
#   'mdb',
#   'mb',
#   'lmb',
#   'mxb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mdb',
#   'mxb',
#   'No',
#   'lmb',
#   'mb',
#   'No',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'mlb',
#   'lmb',
#   'No',
#   'mb',
#   'No',
#   'mb',
#   'mdb',
#   'lmb',
#   'mxb',
#   'No',
#   'mdb',
#   'mlb',
#   'No',
#   'mlb',
#   'lb',
#   'lmb',
#   'memb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'memb',
#   'mb',
#   'memb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'memb',
#   'No',
#   'mlb',
#   'lmb',
#   'No',
#   'mb',
#   'mb',
#   'mxb',
#   'mb',
#   'mdb',
#   'lb',
#   'mb',
#   'mlb',
#   'lmb',
#   'lb',
#   'lb',
#   'No',
#   'memb',
#   'memb',
#   'mb',
#   'mlb',
#   'No',
#   'mb',
#   'mlb',
#   'memb',
#   'lmb',
#   'mxmb',
#   'lmb',
#   'No',
#   'lmb',
#   'mxb',
#   'mdb',
#   'mdb',
#   'mlb',
#   'lmb',
#   'mlb',
#   'mdb',
#   'mdb',
#   'mb',
#   'mxmb',
#   'mb',
#   'memb',
#   'lb',
#   'mb',
#   'mxmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'mxb',
#   'mb',
#   'mb',
#   'mlb',
#   'memb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'memb',
#   'No',
#   'lmb',
#   'No',
#   'mb',
#   'mb',
#   'No',
#   'mdb',
#   'mb',
#   'No',
#   'mdb',
#   'lb',
#   'mb',
#   'No',
#   'mdb',
#   'lmb',
#   'mlb',
#   'mdb',
#   'mb',
#   'mdb',
#   'No',
#   'mdb',
#   'No',
#   'mb',
#   'mdb',
#   'mlb',
#   'No'],
#  'mxne': ['lmb',
#   'mlb',
#   'lmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxb',
#   'memb',
#   'lmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'memb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'No',
#   'mxmb',
#   'mlb',
#   'mxmb',
#   'mdb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lmb',
#   'mxb',
#   'No',
#   'mb',
#   'mb',
#   'mdb',
#   'lmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'mb',
#   'No',
#   'mb',
#   'mlb',
#   'lmb',
#   'mlb',
#   'lb',
#   'mlb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'No',
#   'mxb',
#   'mxmb',
#   'No',
#   'mb',
#   'mlb',
#   'memb',
#   'mb',
#   'mxb',
#   'mb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mb',
#   'mdb',
#   'mb',
#   'mlb',
#   'No',
#   'mb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'memb',
#   'mlb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mdb',
#   'No',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'lmb',
#   'memb',
#   'mlb',
#   'mlb',
#   'mxmb',
#   'lmb',
#   'mxmb',
#   'mxmb',
#   'mdb',
#   'memb',
#   'mb',
#   'memb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'No',
#   'memb',
#   'lmb',
#   'mb',
#   'memb',
#   'lmb',
#   'lmb',
#   'memb',
#   'mlb',
#   'mxb',
#   'mxmb',
#   'mxmb',
#   'mxb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'lb',
#   'lb',
#   'No',
#   'memb',
#   'mlb',
#   'memb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxb',
#   'mb',
#   'mlb',
#   'lb',
#   'mxmb',
#   'mlb',
#   'mdb',
#   'mb',
#   'memb',
#   'mb',
#   'lb',
#   'lmb',
#   'mdb',
#   'mb',
#   'lmb',
#   'memb',
#   'memb',
#   'mb',
#   'memb',
#   'mxb',
#   'mb',
#   'mb',
#   'mlb',
#   'mxmb',
#   'mb',
#   'mb',
#   'mlb'],
#  'mipv': ['No',
#   13,
#   'No',
#   5,
#   6,
#   2,
#   10,
#   6,
#   9,
#   37,
#   32,
#   15,
#   'No',
#   42,
#   33,
#   'No',
#   44,
#   62,
#   105,
#   6,
#   66,
#   170,
#   'No',
#   138,
#   32,
#   70,
#   52,
#   'No',
#   22,
#   23,
#   1,
#   49,
#   106,
#   129,
#   41,
#   10,
#   67,
#   54,
#   'No',
#   248,
#   52,
#   27,
#   113,
#   88,
#   'No',
#   191,
#   881,
#   515,
#   876,
#   246,
#   245,
#   79,
#   131,
#   'No',
#   89,
#   'No',
#   149,
#   183,
#   119,
#   7163,
#   36,
#   1639,
#   954,
#   588,
#   2211,
#   49,
#   1712,
#   144,
#   29,
#   85,
#   86,
#   87,
#   179,
#   116,
#   353,
#   369,
#   915,
#   'No',
#   1757,
#   2805,
#   'No',
#   617,
#   2505,
#   294,
#   182,
#   1565,
#   176,
#   'No',
#   1873,
#   'No',
#   701,
#   5057,
#   196,
#   239,
#   'No',
#   3049,
#   513,
#   'No',
#   791,
#   1000,
#   99,
#   676,
#   1473,
#   307,
#   829,
#   208,
#   510,
#   1656,
#   293,
#   225,
#   1734,
#   510,
#   1604,
#   51,
#   472,
#   4891,
#   494,
#   'No',
#   1169,
#   128,
#   'No',
#   3209,
#   1291,
#   8636,
#   1020,
#   480,
#   5252,
#   852,
#   1614,
#   370,
#   1501,
#   530,
#   'No',
#   951,
#   201,
#   78,
#   1226,
#   'No',
#   2605,
#   63,
#   373,
#   187,
#   85,
#   2213,
#   'No',
#   586,
#   791,
#   292,
#   622,
#   3671,
#   37,
#   8,
#   11203,
#   1177,
#   194,
#   1092,
#   2228,
#   427,
#   1335,
#   1949,
#   103,
#   1004,
#   190,
#   719,
#   2041,
#   2198,
#   2406,
#   87,
#   480,
#   1778,
#   3213,
#   1994,
#   3633,
#   4712,
#   4030,
#   'No',
#   6488,
#   'No',
#   2229,
#   'No',
#   13357,
#   6570,
#   10585,
#   10280,
#   11524,
#   13807,
#   'No',
#   12356,
#   'No',
#   12796,
#   7508,
#   11868,
#   19760,
#   'No',
#   11697,
#   15316,
#   'No',
#   16045,
#   18508,
#   19309,
#   19613,
#   18508,
#   17891,
#   16854,
#   20769,
#   20136,
#   21211,
#   17183,
#   23358,
#   20996,
#   23793,
#   25985,
#   31824,
#   32854,
#   27623,
#   36631,
#   'No',
#   33185,
#   35555,
#   'No',
#   34216,
#   35263,
#   42732,
#   39335,
#   42590,
#   45968,
#   44731,
#   48527,
#   50017,
#   50634,
#   53944,
#   'No',
#   55510,
#   57558,
#   54698,
#   55694,
#   'No',
#   54799,
#   58109,
#   60082,
#   59178,
#   61788,
#   60645,
#   'No',
#   56310,
#   65514,
#   63859,
#   55569,
#   55949,
#   64438,
#   64974,
#   49219,
#   63258,
#   61951,
#   66782,
#   65263,
#   69198,
#   71826,
#   67681,
#   74013,
#   73604,
#   72872,
#   70185,
#   79415,
#   75664,
#   75342,
#   79126,
#   82369,
#   81146,
#   84575,
#   93521,
#   90756,
#   88214,
#   98040,
#   'No',
#   80971,
#   'No',
#   91102,
#   91607,
#   'No',
#   75281,
#   84672,
#   'No',
#   60399,
#   72690,
#   80704,
#   'No',
#   72690,
#   79207,
#   81488,
#   72070,
#   79317,
#   88524,
#   'No',
#   74520,
#   'No',
#   78843,
#   57530,
#   70185,
#   'No'],
#  'nprd_val': [33,
#   20,
#   26,
#   54,
#   69,
#   59,
#   67,
#   79,
#   99,
#   72,
#   170,
#   195,
#   121,
#   134,
#   216,
#   155,
#   291,
#   290,
#   489,
#   509,
#   453,
#   763,
#   476,
#   732,
#   561,
#   565,
#   756,
#   594,
#   650,
#   697,
#   646,
#   'No',
#   987,
#   926,
#   1143,
#   1469,
#   1396,
#   1499,
#   1266,
#   1428,
#   1800,
#   1674,
#   2124,
#   2048,
#   1636,
#   2498,
#   'No',
#   2556,
#   2527,
#   3131,
#   3116,
#   3196,
#   3380,
#   3231,
#   3517,
#   3131,
#   3904,
#   3712,
#   3268,
#   'No',
#   6128,
#   5736,
#   5590,
#   5031,
#   5289,
#   4832,
#   5086,
#   5752,
#   5290,
#   5288,
#   5696,
#   6528,
#   6102,
#   'No',
#   8728,
#   7497,
#   'No',
#   8206,
#   7667,
#   11045,
#   9340,
#   16744,
#   10665,
#   15049,
#   11544,
#   15393,
#   14974,
#   12284,
#   14801,
#   12128,
#   14938,
#   13125,
#   13193,
#   'No',
#   14708,
#   15335,
#   20771,
#   15813,
#   20952,
#   21433,
#   21460,
#   22604,
#   20183,
#   19008,
#   18618,
#   21210,
#   21734,
#   23248,
#   20639,
#   24885,
#   24507,
#   24686,
#   29415,
#   37230,
#   34356,
#   34843,
#   37769,
#   32003,
#   34843,
#   36280,
#   35076,
#   37455,
#   37452,
#   'No',
#   52152,
#   53927,
#   53813,
#   49757,
#   54685,
#   53107,
#   53570,
#   56555,
#   51797,
#   59683,
#   60720,
#   56918,
#   58727,
#   55445,
#   58172,
#   58468,
#   67203,
#   61120,
#   62038,
#   62884,
#   59934,
#   58295,
#   'No',
#   67704,
#   59509,
#   60791,
#   66198,
#   65927,
#   62289,
#   67148,
#   64343,
#   70274,
#   69269,
#   70497,
#   76044,
#   69825,
#   74745,
#   75524,
#   75103,
#   71548,
#   'No',
#   83459,
#   78721,
#   82899,
#   87779,
#   84242,
#   90750,
#   100853,
#   97790,
#   93276,
#   103922,
#   94656,
#   90900,
#   85315,
#   100921,
#   93371,
#   85315,
#   86502,
#   91609,
#   85807,
#   84407,
#   78576,
#   87113,
#   80138,
#   76508,
#   84819,
#   84798,
#   79054,
#   83323,
#   89889,
#   82285,
#   79981,
#   79123,
#   87202,
#   79637,
#   77619,
#   69434]}

# %%
err_df=pd.DataFrame(err_dict)
err_df
# Out:
#             date  mipe  mxne   mipv    mxnv  original_val pprd_val nprd_val
# 0    2020-03-31     No   lmb     No     -20            13       No       33
# 1    2020-04-01    lmb   mlb     13      -1            19        6       20
# 2    2020-04-02     No   lmb     No      -4            22       No       26
# 3    2020-04-03    mlb  memb      5     -15            39       34       54
# 4    2020-04-04   memb    lb      6     -13            56       50       69
# ..           ...   ...   ...    ...     ...           ...      ...      ...
# 196  2020-10-13     No   mlb     No   -5220         73903       No    79123
# 197  2020-10-14     mb  mxmb   2739   -5620         81582    78843    87202
# 198  2020-10-15    mdb    mb  13262   -8845         70792    57530    79637
# 199  2020-10-16    mlb    mb    383   -7051         70568    70185    77619
# 200  2020-10-17     No   mlb     No  -69434             0       No    69434
#
# [201 rows x 8 columns]

# %%
err_df.to_excel("edrrr_df.xlsx")
errdf=pd.read_excel(r"C:\Users\Mark 1\edrrr_df.xlsx")
errdf = errdf.loc[:, ~errdf.columns.str.contains('^Unnamed')]
errdf.to_excel("edrrr_df.xlsx")

# %%
Counter(err_df['mipe'])
# Out:
# Counter({'No': 29,
#          'lmb': 27,
#          'mlb': 16,
#          'memb': 21,
#          'mb': 39,
#          'mdb': 33,
#          'lb': 13,
#          'mxmb': 14,
#          'mxb': 9})

# %%
mnval=max(list(Counter(err_df['mipe']).values()))
mnvalidx=list(Counter(err_df['mipe']).values()).index(mnval)
mnkys=list(Counter(err_df['mipe']).keys())[mnvalidx]
print("method: "+mnkys+" and values is: ",Counter(err_df['mipe'])[mnkys])
# Out:
# method: mb and values is:  39

# %%
Counter(err_df['mxne'])
# Out:
# Counter({'lmb': 20,
#          'mlb': 23,
#          'memb': 39,
#          'lb': 12,
#          'mxmb': 35,
#          'mxb': 16,
#          'mb': 35,
#          'No': 9,
#          'mdb': 12})

# %%
mxval=max(list(Counter(err_df['mxne']).values()))
mxvalidx=list(Counter(err_df['mxne']).values()).index(mxval)
mxkys=list(Counter(err_df['mxne']).keys())[mxvalidx]
print("method: "+mxkys+" and values is: ",Counter(err_df['mxne'])[mxkys])
# Out:
# method: memb and values is:  39

# %%
err_df['mipe'][len(err_df)-2]
# Out:
# 'mlb'

# %%
err_df['mxne'][len(err_df)-2]
# Out:
# 'mb'
