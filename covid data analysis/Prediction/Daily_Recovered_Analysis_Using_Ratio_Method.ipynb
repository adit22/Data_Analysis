# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\30\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_daily=data[53:]
data_daily.reset_index(drop=True,inplace=True)
data_daily.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_daily.tail()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 127    28 July             49631          1532135            35683
# 128    29 July             52479          1584614            32886
# 129    30 July             54968          1639582            37425
# 130    31 July             57486          1697068            36554
# 131  01 August             54865          1751933            51232
#
#      Total Recovered  Daily Deceased  Total Deceased
# 127           988673             774           34243
# 128          1021559             775           35018
# 129          1058984             784           35802
# 130          1095538             764           36566
# 131          1146770             852           37418

# %%
colls=list(data_daily.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_daily.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_daily[data_daily.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_daily['Date'] = data_daily['Date'].astype('str')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,9):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" March")
for i in range(0,9):
    data_daily["Date"][i]="2020-03-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(9,39):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" April")
for i in range(9,39):
    data_daily["Date"][i]="2020-04-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(39,70):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" May")
for i in range(39,70):
    data_daily["Date"][i]="2020-05-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(70,100):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" June")
for i in range(70,100):
    data_daily["Date"][i]="2020-06-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(100,131):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" July")
for i in range(100,131):
    data_daily["Date"][i]="2020-07-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(131,len(data_daily)):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" August")
for i in range(131,len(data_daily)):
    data_daily["Date"][i]="2020-08-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data_daily["Date"]=data_daily["Date"].astype('datetime64[ns]')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_daily.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_daily_ratio_with_two_precision=data_daily.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_daily_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_daily_ratio_with_two_precision[i]=list(range(len(data_daily_ratio_with_two_precision)))
    data_daily_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_daily_ratio_with_two_precision[i][0])
    for k in range(0,len(data_daily_ratio_with_two_precision)-1):
        tmp.append(round(data_daily_ratio_with_two_precision[j][k+1]/data_daily_ratio_with_two_precision[j][k],2))
    data_daily_ratio_with_two_precision[i]=tmp
data_daily_ratio_with_two_precision.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_daily_ratio=data_daily.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_daily_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_daily_ratio[i]=list(range(len(data_daily_ratio)))
    data_daily_ratio[i][0]=1
    tmp=[]
    tmp.append(data_daily_ratio[i][0])
    for k in range(0,len(data_daily_ratio)-1):
        tmp.append(data_daily_ratio[j][k+1]/data_daily_ratio[j][k])
    data_daily_ratio[i]=tmp
data_daily_ratio.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_daily_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_daily_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    dcr=data_daily_ratio.iloc[st:en,9:10]
    dcr.reset_index(inplace = True, drop = True)
    dc=data_daily_ratio.iloc[st:en,3:4]
    dc.reset_index(inplace = True, drop = True)



    next_day_recovered_case_count_mean_based=dcr.mean()[0]*dc.mean()[0]

    next_day_recovered_case_count_max_based=max(dcr["Daily_Recovered_Ratio"])*max(dc["Daily Recovered"])


    next_day_recovered_case_count_mean_max_based=dcr.mean()[0]*max(dc["Daily Recovered"])


    next_day_recovered_case_count_max_mean_based=max(dcr["Daily_Recovered_Ratio"])*dc.mean()[0]


    next_day_recovered_case_count_mean_last_based=dcr.mean()[0]*dc["Daily Recovered"][len(dc)-1]


    next_day_recovered_case_count_last_mean_based=dcr["Daily_Recovered_Ratio"][len(dcr)-1]*dc.mean()[0]


    next_day_recovered_case_count_last_based=dcr["Daily_Recovered_Ratio"][len(dcr)-1]*dc["Daily Recovered"][len(dc)-1]


    next_day_recovered_case_count_middle_based=dcr["Daily_Recovered_Ratio"][3]*dc["Daily Recovered"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_recovered_case_count_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_middle_based))

    if(en<len(data_daily_ratio)):
        pred_dict={"date":data_daily_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_daily_ratio["Daily Recovered"][en],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_daily_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
        
    
    pred_df=pd.DataFrame(pred_dict, index=[0])
    
    
    d=pd.read_excel(r"C:\Users\Mark 1\ramprd_df_strd.xlsx")
    d=pd.concat([d,pred_df])
    d.reset_index(drop=True,inplace=True)
    d.to_excel("ramprd_df_strd.xlsx")

# %%
dc=pd.read_excel(r"C:\Users\Mark 1\ramprd_df_strd.xlsx")
dc
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31            13          41        262              89
# 1   2020-04-01            19          24        125              53
# 2   2020-04-02            22          31        125              59
# 3   2020-04-03            39          31        125              54
# 4   2020-04-04            56          28         80              50
# 5   2020-04-05            43          41        115              80
# 6   2020-04-06            65          42        115              72
# 7   2020-04-07            75          44        115              79
# 8   2020-04-08            96          60        133              99
# 9   2020-04-09            70          73        170             125
# 10  2020-04-10           151          78        170             119
# 11  2020-04-11           186         103        326             195
# 12  2020-04-12           114         124        401             235
# 13  2020-04-13           112         134        401             231
# 14  2020-04-14           167         134        401             216
# 15  2020-04-15           144         155        401             225
# 16  2020-04-16           258         155        401             214
# 17  2020-04-17           273         211        557             336
# 18  2020-04-18           426         206        489             313
# 19  2020-04-19           388         255        763             509
# 20  2020-04-20           419         312        763             527
# 21  2020-04-21           703         371        763             533
# 22  2020-04-22           394         476       1260             898
# 23  2020-04-23           642         504       1260             868
# 24  2020-04-24           484         561       1179             851
# 25  2020-04-25           442         576       1179             821
# 26  2020-04-26           585         533       1179             756
# 27  2020-04-27           580         594       1179             797
# 28  2020-04-28           636         614       1179             788
# 29  2020-04-29           690         558       1046             667
# ..         ...           ...         ...        ...             ...
# 343 2020-07-04         14746       15335      33153           21817
# 344 2020-07-05         15829       14677      33153           20771
# 345 2020-07-06         15315       15839      33153           21503
# 346 2020-07-07         16836       15705      33153           20952
# 347 2020-07-08         19508       16719      33153           21433
# 348 2020-07-09         19408       18332      33153           22000
# 349 2020-07-10         20289       16669      22604           19613
# 350 2020-07-11         19981       18320      23509           21338
# 351 2020-07-12         18198       19008      23509           21228
# 352 2020-07-13         17683       18932      23509           20757
# 353 2020-07-14         20977       19289      23509           20769
# 354 2020-07-15         20646       20136      24885           21734
# 355 2020-07-16         22867       19816      24885           21211
# 356 2020-07-17         17476       20639      27127           23490
# 357 2020-07-18         23583       19435      27127           22572
# 358 2020-07-19         22730       20996      31824           24507
# 359 2020-07-20         24303       21827      31824           24686
# 360 2020-07-21         27589       23120      32796           25778
# 361 2020-07-22         31875       23956      37230           29062
# 362 2020-07-23         33326       26241      43014           34356
# %%
dce=dc.copy()

# %%
colls=list(dc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    dce[i]=pd.Series(range(1,len(dce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(dce)):
        dce[j][k]=dce["original_val"][k]-dce[i][k]
dce
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31            13          41        262              89
# 1   2020-04-01            19          24        125              53
# 2   2020-04-02            22          31        125              59
# 3   2020-04-03            39          31        125              54
# 4   2020-04-04            56          28         80              50
# 5   2020-04-05            43          41        115              80
# 6   2020-04-06            65          42        115              72
# 7   2020-04-07            75          44        115              79
# 8   2020-04-08            96          60        133              99
# 9   2020-04-09            70          73        170             125
# 10  2020-04-10           151          78        170             119
# 11  2020-04-11           186         103        326             195
# 12  2020-04-12           114         124        401             235
# 13  2020-04-13           112         134        401             231
# 14  2020-04-14           167         134        401             216
# 15  2020-04-15           144         155        401             225
# 16  2020-04-16           258         155        401             214
# 17  2020-04-17           273         211        557             336
# 18  2020-04-18           426         206        489             313
# 19  2020-04-19           388         255        763             509
# 20  2020-04-20           419         312        763             527
# 21  2020-04-21           703         371        763             533
# 22  2020-04-22           394         476       1260             898
# 23  2020-04-23           642         504       1260             868
# 24  2020-04-24           484         561       1179             851
# 25  2020-04-25           442         576       1179             821
# 26  2020-04-26           585         533       1179             756
# 27  2020-04-27           580         594       1179             797
# 28  2020-04-28           636         614       1179             788
# 29  2020-04-29           690         558       1046             667
# ..         ...           ...         ...        ...             ...
# 343 2020-07-04         14746       15335      33153           21817
# 344 2020-07-05         15829       14677      33153           20771
# 345 2020-07-06         15315       15839      33153           21503
# 346 2020-07-07         16836       15705      33153           20952
# 347 2020-07-08         19508       16719      33153           21433
# 348 2020-07-09         19408       18332      33153           22000
# 349 2020-07-10         20289       16669      22604           19613
# 350 2020-07-11         19981       18320      23509           21338
# 351 2020-07-12         18198       19008      23509           21228
# 352 2020-07-13         17683       18932      23509           20757
# 353 2020-07-14         20977       19289      23509           20769
# 354 2020-07-15         20646       20136      24885           21734
# 355 2020-07-16         22867       19816      24885           21211
# 356 2020-07-17         17476       20639      27127           23490
# 357 2020-07-18         23583       19435      27127           22572
# 358 2020-07-19         22730       20996      31824           24507
# 359 2020-07-20         24303       21827      31824           24686
# 360 2020-07-21         27589       23120      32796           25778
# 361 2020-07-22         31875       23956      37230           29062
# 362 2020-07-23         33326       26241      43014           34356
# 363 2020-07-24         32514       27623      44972           35625
# 364 2020-07-25         37125       30764      44972           36631
# 365 2020-07-26         31512       32003      42892           39706
# 366 2020-07-27         34354       32833      42892           39096
# 367 2020-07-28         35683       34442      42892           39207
# 368 2020-07-29         32886       35198      42892           38695
# 369 2020-07-30         37425       34216      42390           37455
# 370 2020-07-31         36554       35263      42732           38252
# 371 2020-08-01         51232       35858      42732           38258
# 372 2020-08-02             0       39294      71804           54274
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 0               120               89               33          72
# 1                56               20                6           5
# 2                64               32               26          28
# 3                72               34               23          25
# 4                46               50               39          69
# 5                59               80               41          80
# 6                67               55               25          33
# 7                65               79               55          98
# 8                81               99               53          87
# 9               100              125               72         123
# 10              112               87               46          51
# 11              171              195              171         326
# 12              211              235              121         229
# 13              233              141               66          70
# 14              248              130              113         110
# 15              276              202              191         249
# 16              291              166              116         124
# 17              349              336              290         462
# 18              321              313              190         289
# 19              382              509              333         665
# 20              453              480              230         353
# 21              531              524              320         452
# 22              668              898              626        1179
# 23              732              486              229         221
# 24              778              777              755        1046
# 25              828              565              372         365
# 26              832              475              453         404
# 27              879              663              694         774
# 28              918              650              542         575
# 29              876              660              589         697
# ..              ...              ...              ...         ...
# 343           23304            15727            10134       10393
# 344           23426            15316            14454       15083
# 345           24420            17019            15813       16992
# 346           24851            16045            14504       14818
# 347           25862            18043            17150       18508
# 348           27625            21460            19309       22604
# 349           19211            19512            16495       19309
# 350           20183            21338            18209       21210
# 351           21050            20906            17891       19678
# 352           21442            18618            16854       16574
# 353           21834            18101            18310       17183
# 354           23055            21734            23055       24885
# 355           23248            20876            19288       20320
# 356           23834            23490            22253       25327
# 357           23358            17250            15048       13356
# 358           27265            24507            27265       31824
# 359           28138            23793            20098       21908
# 360           29415            25778            23306       25985
# 361           30689            29062            25817       31319
# 362           32854            34356            28128       36827
# 363           34870            35625            27017       34843
# 364           37769            35738            27307       31722
# 365           34572            39706            34167       42390
# 366           36021            33185            26464       26748
# 367           37680            36280            35555       37452
# 368           39016            37192            35076       37063
# 369           38724            33179            31256       30308
# 370           39392            38252            39262       42590
# 371           40051            37368            34261       35703
# 372           51986            54274            51986       71804
#
#      middle_based     mb    mxb   memb   mxmb    mlb    lmb     lb    mdb
# 0              89    -28   -249    -76   -107    -76    -20    -59    -76
# 1               4     -5   -106    -34    -37     -1     13     14     15
# 2              29     -9   -103    -37    -42    -10     -4     -6     -7
# 3              72      8    -86    -15    -33      5     16     14    -33
# 4               5     28    -24      6     10      6     17    -13     51
# 5              28      2    -72    -37    -16    -37      2    -37     15
# 6              25     23    -50     -7     -2     10     40     32     40
# 7              69     31    -40     -4     10     -4     20    -23      6
# 8              80     36    -37     -3     15     -3     43      9     16
# 9              33     -3   -100    -55    -30    -55     -2    -53     37
# 10             98     73    -19     32     39     64    105    100     53
# 11             87     83   -140     -9     15     -9     15   -140     99
# 12            123    -10   -287   -121    -97   -121     -7   -115     -9
# 13             51    -22   -289   -119   -121    -29     46     42     61
# 14            326     33   -234    -49    -81     37     54     57   -159
# 15            229    -11   -257    -81   -132    -58    -47   -105    -85
# 16             70    103   -143     44    -33     92    142    134    188
# 17            110     62   -284    -63    -76    -63    -17   -189    163
# 18            249    220    -63    113    105    113    236    137    177
# 19            124    133   -375   -121      6   -121     55   -277    264
# 20            462    107   -344   -108    -34    -61    189     66    -43

    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(dce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+ psc +" and the highest negative error by the method: "+ngc)
    """
# Out:
# '\nfor j,k in zip(range(len(edf)),range(len(dce)-1)):\n    \n    a=list(edf.loc[j])\n    pos=[]\n    neg=[]\n    for i in a:\n        if(i>=0):\n            pos.append(i)\n        else:\n            neg.append(i)\n    if(len(pos)):\n        ps=min(pos)\n        psi=a.index(ps)\n        psc=list(edf.columns)[psi]\n    if(len(neg)):\n        ng=max(neg)\n        ngi=a.index(ng)\n        ngc=list(edf.columns)[ngi]\n    \n    \n    print("for date: "+str(dce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+ psc +" and the highest negative error by the method: "+ngc)\n    '

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(dce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(dce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(dce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(dce["date"][k]).strip("00:00:00"))
    org_val.append(dce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 ',
#   '2020-08-01 ',
#   '2020-08-02 '],
#  'mipe': ['No',
#   'lmb',
#   'No',
#   'mlb',
#   'memb',
#   'mb',
#   'mlb',
#   'mdb',
#   'lb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'No',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'memb',
#   'No',
#   'mb',
#   'mdb',
#   'lmb',
#   'mb',
#   'No',
#   'mb',
#   'memb',
#   'lmb',
#   'mxb',
#   'mb',
#   'mb',
#   'memb',
#   'lb',
#   'lmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'No',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'lb',
#   'mlb',
#   'mb',
#   'mb',
#   'lb',
#   'No',
#   'mdb',
#   'No',
#   'mdb',
#   'mb',
#   'lmb',
#   'mxb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mdb',
#   'mxb',
#   'No',
#   'lmb',
#   'mb',
#   'No',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'mlb',
#   'lmb',
#   'No',
#   'mb',
#   'No',
#   'mb',
#   'mdb',
#   'lmb',
#   'mxb',
#   'No',
#   'mdb',
#   'mlb',
#   'No',
#   'mlb',
#   'lb',
#   'lmb',
#   'memb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'memb',
#   'mb',
#   'memb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'memb',
#   'No',
#   'mlb',
#   'lmb',
#   'No',
#   'mb',
#   'mb',
#   'No',
#   'No',
#   'lmb',
#   'No',
#   'mlb',
#   'memb',
#   'mb',
#   'mlb',
#   'mdb',
#   'lb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'No',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'memb',
#   'No',
#   'mb',
#   'mdb',
#   'lmb',
#   'mb',
#   'No',
#   'mb',
#   'memb',
#   'lmb',
#   'mxb',
#   'mb',
#   'mb',
#   'memb',
#   'lb',
#   'lmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'No',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'lb',
#   'mlb',
#   'mb',
#   'mb',
#   'lb',
#   'No',
#   'mdb',
#   'No',
#   'mdb',
#   'mb',
#   'lmb',
#   'mxb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mdb',
#   'mxb',
#   'No',
#   'lmb',
#   'mb',
#   'No',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'mlb',
#   'lmb',
#   'No',
#   'mb',
#   'No',
#   'mb',
#   'mdb',
#   'lmb',
#   'mxb',
#   'No',
#   'mdb',
#   'mlb',
#   'No',
#   'mlb',
#   'lb',
#   'lmb',
#   'memb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'memb',
#   'mb',
#   'memb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'memb',
#   'No',
#   'mlb',
#   'lmb',
#   'No',
#   'mb',
#   'mb',
#   'No',
#   'No',
#   'lmb',
#   'No',
#   'mlb',
#   'memb',
#   'mb',
#   'mlb',
#   'mdb',
#   'lb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'No',
#   'lb',
#   'mb',
#   'No',
#   'memb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'lb',
#   'memb',
#   'No',
#   'mb',
#   'mdb',
#   'lmb',
#   'mb',
#   'No',
#   'mb',
#   'memb',
#   'lmb',
#   'mxb',
#   'mb',
#   'mb',
#   'memb',
#   'lb',
#   'lmb',
#   'memb',
#   'No',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'mxmb',
#   'No',
#   'mxmb',
#   'mxb',
#   'mdb',
#   'lb',
#   'mlb',
#   'mb',
#   'mb',
#   'lb',
#   'No',
#   'mdb',
#   'No',
#   'mdb',
#   'mb',
#   'lmb',
#   'mxb',
#   'mdb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mdb',
#   'lmb',
#   'mdb',
#   'mxmb',
#   'mdb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mdb',
#   'mxb',
#   'No',
#   'lmb',
#   'mb',
#   'No',
#   'mxmb',
#   'mdb',
#   'mb',
#   'mb',
#   'mlb',
#   'lmb',
#   'No',
#   'mb',
#   'No',
#   'mb',
#   'mdb',
#   'lmb',
#   'mxb',
#   'No',
#   'mdb',
#   'mlb',
#   'No',
#   'mlb',
#   'lb',
#   'lmb',
#   'memb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'memb',
#   'mb',
#   'memb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'lb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'memb',
#   'No',
#   'mlb',
#   'lmb',
#   'No',
#   'mb',
#   'mb',
#   'mxb',
#   'No'],
#  'mxne': ['lmb',
#   'mlb',
#   'lmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxb',
#   'memb',
#   'lmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'memb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'No',
#   'mxmb',
#   'mlb',
#   'mxmb',
#   'mdb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lmb',
#   'mxb',
#   'No',
#   'mb',
#   'mb',
#   'mdb',
#   'lmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'mb',
#   'No',
#   'mb',
#   'mlb',
#   'lmb',
#   'mlb',
#   'lb',
#   'mlb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'No',
#   'mxb',
#   'mxmb',
#   'No',
#   'mb',
#   'mlb',
#   'memb',
#   'mb',
#   'mxb',
#   'mb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mb',
#   'mdb',
#   'mb',
#   'mlb',
#   'No',
#   'mb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'memb',
#   'mlb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'mlb',
#   'lmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxb',
#   'memb',
#   'lmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'memb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'No',
#   'mxmb',
#   'mlb',
#   'mxmb',
#   'mdb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lmb',
#   'mxb',
#   'No',
#   'mb',
#   'mb',
#   'mdb',
#   'lmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'mb',
#   'No',
#   'mb',
#   'mlb',
#   'lmb',
#   'mlb',
#   'lb',
#   'mlb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'No',
#   'mxb',
#   'mxmb',
#   'No',
#   'mb',
#   'mlb',
#   'memb',
#   'mb',
#   'mxb',
#   'mb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mb',
#   'mdb',
#   'mb',
#   'mlb',
#   'No',
#   'mb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'memb',
#   'mlb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mdb',
#   'lmb',
#   'lmb',
#   'mlb',
#   'lmb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'memb',
#   'memb',
#   'lmb',
#   'mxb',
#   'memb',
#   'lmb',
#   'mb',
#   'memb',
#   'mb',
#   'mxmb',
#   'lmb',
#   'mxb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'memb',
#   'mb',
#   'mlb',
#   'lb',
#   'mb',
#   'No',
#   'mxmb',
#   'mlb',
#   'mxmb',
#   'mdb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lmb',
#   'mxb',
#   'No',
#   'mb',
#   'mb',
#   'mdb',
#   'lmb',
#   'lb',
#   'mb',
#   'lmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'memb',
#   'mb',
#   'No',
#   'mb',
#   'mlb',
#   'lmb',
#   'mlb',
#   'lb',
#   'mlb',
#   'lb',
#   'mxb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mxb',
#   'mxmb',
#   'No',
#   'mxb',
#   'mxmb',
#   'No',
#   'mb',
#   'mlb',
#   'memb',
#   'mb',
#   'mxb',
#   'mb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mb',
#   'mdb',
#   'mb',
#   'mlb',
#   'No',
#   'mb',
#   'mb',
#   'memb',
#   'lmb',
#   'memb',
#   'memb',
#   'mlb',
#   'mxb',
#   'mxmb',
#   'mb',
#   'mlb',
#   'mdb',
#   'memb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'memb',
#   'memb',
#   'mxmb',
#   'mxb',
#   'memb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mdb',
#   'No',
#   'mdb'],
#  'mipv': ['No',
#   13,
#   'No',
#   5,
#   6,
#   2,
#   10,
#   6,
#   9,
#   37,
#   32,
#   15,
#   'No',
#   42,
#   33,
#   'No',
#   44,
#   62,
#   105,
#   6,
#   66,
#   170,
#   'No',
#   138,
#   32,
#   70,
#   52,
#   'No',
#   22,
#   23,
#   1,
#   49,
#   106,
#   129,
#   41,
#   10,
#   67,
#   54,
#   'No',
#   248,
#   52,
#   27,
#   113,
#   88,
#   'No',
#   191,
#   881,
#   515,
#   876,
#   246,
#   245,
#   79,
#   131,
#   'No',
#   89,
#   'No',
#   149,
#   183,
#   119,
#   7163,
#   36,
#   1639,
#   954,
#   588,
#   2211,
#   49,
#   1712,
#   144,
#   29,
#   85,
#   86,
#   87,
#   179,
#   116,
#   353,
#   369,
#   915,
#   'No',
#   1757,
#   2805,
#   'No',
#   617,
#   2505,
#   294,
#   182,
#   1565,
#   176,
#   'No',
#   1873,
#   'No',
#   701,
#   5057,
#   196,
#   239,
#   'No',
#   3049,
#   513,
#   'No',
#   791,
#   1000,
#   99,
#   676,
#   1473,
#   307,
#   829,
#   208,
#   510,
#   1656,
#   293,
#   225,
#   1734,
#   510,
#   1604,
#   51,
#   472,
#   4891,
#   494,
#   'No',
#   1169,
#   128,
#   'No',
#   3209,
#   1291,
#   'No',
#   'No',
#   13,
#   'No',
#   5,
#   6,
#   2,
#   10,
#   6,
#   9,
#   37,
#   32,
#   15,
#   'No',
#   42,
#   33,
#   'No',
#   44,
#   62,
#   105,
#   6,
#   66,
#   170,
#   'No',
#   138,
#   32,
#   70,
#   52,
#   'No',
#   22,
#   23,
#   1,
#   49,
#   106,
#   129,
#   41,
#   10,
#   67,
#   54,
#   'No',
#   248,
#   52,
#   27,
#   113,
#   88,
#   'No',
#   191,
#   881,
#   515,
#   876,
#   246,
#   245,
#   79,
#   131,
#   'No',
#   89,
#   'No',
#   149,
#   183,
#   119,
#   7163,
#   36,
#   1639,
#   954,
#   588,
#   2211,
#   49,
#   1712,
#   144,
#   29,
#   85,
#   86,
#   87,
#   179,
#   116,
#   353,
#   369,
#   915,
#   'No',
#   1757,
#   2805,
#   'No',
#   617,
#   2505,
#   294,
#   182,
#   1565,
#   176,
#   'No',
#   1873,
#   'No',
#   701,
#   5057,
#   196,
#   239,
#   'No',
#   3049,
#   513,
#   'No',
#   791,
#   1000,
#   99,
#   676,
#   1473,
#   307,
#   829,
#   208,
#   510,
#   1656,
#   293,
#   225,
#   1734,
#   510,
#   1604,
#   51,
#   472,
#   4891,
#   494,
#   'No',
#   1169,
#   128,
#   'No',
#   3209,
#   1291,
#   'No',
#   'No',
#   13,
#   'No',
#   5,
#   6,
#   2,
#   10,
#   6,
#   9,
#   37,
#   32,
#   15,
#   'No',
#   42,
#   33,
#   'No',
#   44,
#   62,
#   105,
#   6,
#   66,
#   170,
#   'No',
#   138,
#   32,
#   70,
#   52,
#   'No',
#   22,
#   23,
#   1,
#   49,
#   106,
#   129,
#   41,
#   10,
#   67,
#   54,
#   'No',
#   248,
#   52,
#   27,
#   113,
#   88,
#   'No',
#   191,
#   881,
#   515,
#   876,
#   246,
#   245,
#   79,
#   131,
#   'No',
#   89,
#   'No',
#   149,
#   183,
#   119,
#   7163,
#   36,
#   1639,
#   954,
#   588,
#   2211,
#   49,
#   1712,
#   144,
#   29,
#   85,
#   86,
#   87,
#   179,
#   116,
#   353,
#   369,
#   915,
#   'No',
#   1757,
#   2805,
#   'No',
#   617,
#   2505,
#   294,
#   182,
#   1565,
#   176,
#   'No',
#   1873,
#   'No',
#   701,
#   5057,
#   196,
#   239,
#   'No',
#   3049,
#   513,
#   'No',
#   791,
#   1000,
#   99,
#   676,
#   1473,
#   307,
#   829,
#   208,
#   510,
#   1656,
#   293,
#   225,
#   1734,
#   510,
#   1604,
#   51,
#   472,
#   4891,
#   494,
#   'No',
#   1169,
#   128,
#   'No',
#   3209,
#   1291,
#   8500,
#   'No'],
#  'mxnv': [-20,
#   -1,
#   -4,
#   -15,
#   -13,
#   -16,
#   -2,
#   -4,
#   -3,
#   -2,
#   -19,
#   -9,
#   -7,
#   -22,
#   -49,
#   -11,
#   -33,
#   -17,
#   -63,
#   -121,
#   -34,
#   -60,
#   -82,
#   -90,
#   -77,
#   -123,
#   -171,
#   -14,
#   -14,
#   -7,
#   -16,
#   'No',
#   -156,
#   -15,
#   -61,
#   -174,
#   -235,
#   -24,
#   -155,
#   -14,
#   -131,
#   -95,
#   -219,
#   'No',
#   3196,
#   'No',
#   3436,
#   3251,
#   3052,
#   4572,
#   4267,
#   3289,
#   2928,
#   3943,
#   1578,
#   4341,
#   3058,
#   5289,
#   5162,
#   5086,
#   5548,
#   6188,
#   5865,
#   7147,
#   7739,
#   6989,
#   9724,
#   'No',
#   5133,
#   7936,
#   'No',
#   13357,
#   6570,
#   10585,
#   10280,
#   11524,
#   13807,
#   'No',
#   12356,
#   'No',
#   12796,
#   7508,
#   11868,
#   19760,
#   'No',
#   11697,
#   15316,
#   'No',
#   16045,
#   18508,
#   19309,
#   19613,
#   18508,
#   17891,
#   16854,
#   20769,
#   20136,
#   21211,
#   17183,
#   23358,
#   20996,
#   23793,
#   25985,
#   31824,
#   32854,
#   27623,
#   36631,
#   'No',
#   33185,
#   35555,
#   'No',
#   34216,
#   35263,
#   'No',
#   'No',
#   6,
#   'No',
#   34,
#   50,
#   41,
#   55,
#   69,
#   87,
#   33,
#   119,
#   171,
#   'No',
#   70,
#   134,
#   'No',
#   214,
#   211,
#   321,
#   382,
#   353,
#   533,
#   'No',
#   504,
#   452,
#   372,
#   533,
#   'No',
#   614,
#   667,
#   629,
#   913,
#   725,
#   782,
#   1041,
#   1285,
#   1094,
#   1421,
#   'No',
#   1166,
#   1617,
#   1552,
#   1792,
#   1875,
#   'No',
#   2043,
#   3131,
#   2023,
#   1606,
#   2786,
#   2868,
#   3052,
#   3149,
#   'No',
#   3196,
#   'No',
#   3436,
#   3251,
#   3052,
#   4572,
#   4267,
#   3289,
#   2928,
#   3943,
#   1578,
#   4341,
#   3058,
#   5289,
#   5162,
#   5086,
#   5548,
#   6188,
#   5865,
#   7147,
#   7739,
#   6989,
#   9724,
#   'No',
#   5133,
#   7936,
#   'No',
#   13357,
#   6570,
#   10585,
#   10280,
#   11524,
#   13807,
#   'No',
#   12356,
#   'No',
#   12796,
#   7508,
#   11868,
#   19760,
#   'No',
#   11697,
#   15316,
#   'No',
#   16045,
#   18508,
#   19309,
#   19613,
#   18508,
#   17891,
#   16854,
#   20769,
#   20136,
#   21211,
#   17183,
#   23358,
#   20996,
#   23793,
#   25985,
#   31824,
#   32854,
#   27623,
#   36631,
#   'No',
#   33185,
#   35555,
#   'No',
#   34216,
#   35263,
#   'No',
#   'No',
#   6,
#   'No',
#   34,
#   50,
#   41,
#   55,
#   69,
#   87,
#   33,
#   119,
#   171,
#   'No',
#   70,
#   134,
#   'No',
#   214,
#   211,
#   321,
#   382,
#   353,
#   533,
#   'No',
#   504,
#   452,
#   372,
#   533,
#   'No',
#   614,
#   667,
#   629,
#   913,
#   725,
#   782,
#   1041,
#   1285,
#   1094,
#   1421,
#   'No',
#   1166,
#   1617,
#   1552,
#   1792,
#   1875,
#   'No',
#   2043,
#   3131,
#   2023,
#   1606,
#   2786,
#   2868,
#   3052,
#   3149,
#   'No',
#   3196,
#   'No',
#   3436,
#   3251,
#   3052,
#   4572,
#   4267,
#   3289,
#   2928,
#   3943,
#   1578,
#   4341,
#   3058,
#   5289,
#   5162,
#   5086,
#   5548,
#   6188,
#   5865,
#   7147,
#   7739,
#   6989,
#   9724,
#   'No',
#   5133,
#   7936,
#   'No',
#   13357,
#   6570,
#   10585,
#   10280,
#   11524,
#   13807,
#   'No',
#   12356,
#   'No',
#   12796,
#   7508,
#   11868,
#   19760,
#   'No',
#   11697,
#   15316,
#   'No',
#   16045,
#   18508,
#   19309,
#   19613,
#   18508,
#   17891,
#   16854,
#   20769,
#   20136,
#   21211,
#   17183,
#   23358,
#   20996,
#   23793,
#   25985,
#   31824,
#   32854,
#   27623,
#   36631,
#   'No',
#   33185,
#   35555,
#   'No',
#   34216,
#   35263,
#   42732,
#   'No'],
#  'nprd_val': [33,
#   20,
#   26,
#   54,
#   69,
#   59,
#   67,
#   79,
#   99,
#   72,
#   170,
#   195,
#   121,
#   134,
#   216,
#   155,
#   291,
#   290,
#   489,
#   509,
#   453,
#   763,
#   476,
#   732,
#   561,
#   565,
#   756,
#   594,
#   650,
#   697,
#   646,
#   'No',
#   987,
#   926,
#   1143,
#   1469,
#   1396,
#   1499,
#   1266,
#   1428,
#   1800,
#   1674,
#   2124,
#   2048,
#   1636,
#   2498,
#   'No',
#   2556,
#   2527,
#   3131,
#   3116,
#   3196,
#   3380,
#   3231,
#   3517,
#   3131,
#   3904,
#   3712,
#   3268,
#   'No',
#   6128,
#   5736,
#   5590,
#   5031,
#   5289,
#   4832,
#   5086,
#   5752,
#   5290,
#   5288,
#   5696,
#   6528,
#   6102,
#   'No',
#   8728,
#   7497,
#   'No',
#   8206,
#   7667,
#   11045,
#   9340,
#   16744,
#   10665,
#   15049,
#   11544,
#   15393,
#   14974,
#   12284,
#   14801,
#   12128,
#   14938,
#   13125,
#   13193,
#   'No',
#   14708,
#   15335,
#   20771,
#   15813,
#   20952,
#   21433,
#   21460,
#   22604,
#   20183,
#   19008,
#   18618,
#   21210,
#   21734,
#   23248,
#   20639,
#   24885,
#   24507,
#   24686,
#   29415,
#   37230,
#   34356,
#   34843,
#   37769,
#   32003,
#   34843,
#   36280,
#   35076,
#   37455,
#   37452,
#   34261,
#   33,
#   20,
#   26,
#   54,
#   69,
#   59,
#   67,
#   79,
#   99,
#   72,
#   170,
#   195,
#   121,
#   134,
#   216,
#   155,
#   291,
#   290,
#   489,
#   509,
#   453,
#   763,
#   476,
#   732,
#   561,
#   565,
#   756,
#   594,
#   650,
#   697,
#   646,
#   'No',
#   987,
#   926,
#   1143,
#   1469,
#   1396,
#   1499,
#   1266,
#   1428,
#   1800,
#   1674,
#   2124,
#   2048,
#   1636,
#   2498,
#   'No',
#   2556,
#   2527,
#   3131,
#   3116,
#   3196,
#   3380,
#   3231,
#   3517,
#   3131,
#   3904,
#   3712,
#   3268,
#   'No',
#   6128,
#   5736,
#   5590,
#   5031,
#   5289,
#   4832,
#   5086,
#   5752,
#   5290,
#   5288,
#   5696,
#   6528,
#   6102,
#   'No',
#   8728,
#   7497,
#   'No',
#   8206,
#   7667,
#   11045,
#   9340,
#   16744,
#   10665,
#   15049,
#   11544,
#   15393,
#   14974,
#   12284,
#   14801,
#   12128,
#   14938,
#   13125,
#   13193,
#   'No',
#   14708,
#   15335,
#   20771,
#   15813,
#   20952,
#   21433,
#   21460,
#   22604,
#   20183,
#   19008,
#   18618,
#   21210,
#   21734,
#   23248,
#   20639,
#   24885,
#   24507,
#   24686,
#   29415,
#   37230,
#   34356,
#   34843,
#   37769,
#   32003,
#   34843,
#   36280,
#   35076,
#   37455,
#   37452,
#   34261,
#   33,
#   20,
#   26,
#   54,
#   69,
#   59,
#   67,
#   79,
#   99,
#   72,
#   170,
#   195,
#   121,
#   134,
#   216,
#   155,
#   291,
#   290,
#   489,
#   509,
#   453,
#   763,
#   476,
#   732,
#   561,
#   565,
#   756,
#   594,
#   650,
#   697,
#   646,
#   'No',
#   987,
#   926,
#   1143,
#   1469,
#   1396,
#   1499,
#   1266,
#   1428,
#   1800,
#   1674,
#   2124,
#   2048,
#   1636,
#   2498,
#   'No',
#   2556,
#   2527,
#   3131,
#   3116,
#   3196,
#   3380,
#   3231,
#   3517,
#   3131,
#   3904,
#   3712,
#   3268,
#   'No',
#   6128,
#   5736,
#   5590,
#   5031,
#   5289,
#   4832,
#   5086,
#   5752,
#   5290,
#   5288,
#   5696,
#   6528,
#   6102,
#   'No',
#   8728,
#   7497,
#   'No',
#   8206,
#   7667,
#   11045,
#   9340,
#   16744,
#   10665,
#   15049,
#   11544,
#   15393,
#   14974,
#   12284,
#   14801,
#   12128,
#   14938,
#   13125,
#   13193,
#   'No',
#   14708,
#   15335,
#   20771,
#   15813,
#   20952,
#   21433,
#   21460,
#   22604,
#   20183,
#   19008,
#   18618,
#   21210,
#   21734,
#   23248,
#   20639,
#   24885,
#   24507,
#   24686,
#   29415,
#   37230,
#   34356,
#   34843,
#   37769,
#   32003,
#   34843,
#   36280,
#   35076,
#   37455,
#   37452,
#   'No',
#   30308]}

# %%
err_df=pd.DataFrame(err_dict)
err_df
# Out:
#             date  mipe  mxne  mipv    mxnv  original_val pprd_val nprd_val
# 0    2020-03-31     No   lmb    No     -20            13       No       33
# 1    2020-04-01    lmb   mlb    13      -1            19        6       20
# 2    2020-04-02     No   lmb    No      -4            22       No       26
# 3    2020-04-03    mlb  memb     5     -15            39       34       54
# 4    2020-04-04   memb    lb     6     -13            56       50       69
# 5    2020-04-05     mb  mxmb     2     -16            43       41       59
# 6    2020-04-06    mlb  mxmb    10      -2            65       55       67
# 7    2020-04-07    mdb  memb     6      -4            75       69       79
# 8    2020-04-08     lb  memb     9      -3            96       87       99
# 9    2020-04-09    mdb   lmb    37      -2            70       33       72
# 10   2020-04-10   memb   mxb    32     -19           151      119      170
# 11   2020-04-11   mxmb  memb    15      -9           186      171      195
# 12   2020-04-12     No   lmb    No      -7           114       No      121
# 13   2020-04-13     lb    mb    42     -22           112       70      134
# 14   2020-04-14     mb  memb    33     -49           167      134      216
# 15   2020-04-15     No    mb    No     -11           144       No      155
# 16   2020-04-16   memb  mxmb    44     -33           258      214      291
# 17   2020-04-17     mb   lmb    62     -17           273      211      290
# 18   2020-04-18   mxmb   mxb   105     -63           426      321      489
# 19   2020-04-19   mxmb  memb     6    -121           388      382      509
# 20   2020-04-20     lb  mxmb    66     -34           419      353      453
# 21   2020-04-21   memb   mxb   170     -60           703      533      763
# 22   2020-04-22     No    mb    No     -82           394       No      476
# 23   2020-04-23     mb  mxmb   138     -90           642      504      732
# 24   2020-04-24    mdb    mb    32     -77           484      452      561
# 25   2020-04-25    lmb   mlb    70    -123           442      372      565
# 26   2020-04-26     mb  memb    52    -171           585      533      756
# 27   2020-04-27     No    mb    No     -14           580       No      594
# 28   2020-04-28     mb   mlb    22     -14           636      614      650
# 29   2020-04-29   memb    lb    23      -7           690      667      697
# ..           ...   ...   ...   ...     ...           ...      ...      ...
# 343  2020-07-04    mdb    mb  3049    -589         14746    11697    15335
# 344  2020-07-05    mlb  memb   513   -4942         15829    15316    20771
# 345  2020-07-06     No   lmb    No    -498         15315       No    15813
# 346  2020-07-07    mlb  memb   791   -4116         16836    16045    20952
# 347  2020-07-08     lb  memb  1000   -1925         19508    18508    21433
# 348  2020-07-09    lmb   mlb    99   -2052         19408    19309    21460
# 349  2020-07-10   memb   mxb   676   -2315         20289    19613    22604
# 350  2020-07-11    mdb  mxmb  1473    -202         19981    18508    20183
# 351  2020-07-12    lmb    mb   307    -810         18198    17891    19008
# 352  2020-07-13    lmb   mlb   829    -935         17683    16854    18618
# 353  2020-07-14   memb   mdb   208    -233         20977    20769    21210
# 354  2020-07-15     mb  memb   510   -1088         20646    20136    21734
# 355  2020-07-16   memb  mxmb  1656    -381         22867    21211    23248
# 356  2020-07-17    mdb    mb   293   -3163         17476    17183    20639
# 357  2020-07-18   mxmb   mdb   225   -1302         23583    23358    24885
# 358  2020-07-19     mb  memb  1734   -1777         22730    20996    24507
# 359  2020-07-20    mlb  memb   510    -383         24303    23793    24686
# 360  2020-07-21     lb  mxmb  1604   -1826         27589    25985    29415
# 361  2020-07-22    mdb   mxb    51   -5355         31875    31824    37230
# 362  2020-07-23   mxmb  memb   472   -1030         33326    32854    34356
# 363  2020-07-24     mb    lb  4891   -2329         32514    27623    34843
# 364  2020-07-25   memb  mxmb   494    -644         37125    36631    37769
# 365  2020-07-26     No    mb    No    -491         31512       No    32003
# 366  2020-07-27    mlb   mdb  1169    -489         34354    33185    34843
# 367  2020-07-28    lmb   mlb   128    -597         35683    35555    36280
# 368  2020-07-29     No   lmb    No   -2190         32886       No    35076
# 369  2020-07-30     mb  memb  3209     -30         37425    34216    37455
# 370  2020-07-31     mb   mdb  1291    -898         36554    35263    37452
# 371  2020-08-01    mxb    No  8500      No         51232    42732       No
# 372  2020-08-02     No   mdb    No  -30308             0       No    30308
#
# [373 rows x 8 columns]

# %%
err_df.to_excel("edrrr_df.xlsx")
