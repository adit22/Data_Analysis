# %%
import pandas as pd
import numpy as np 
import copy
from matplotlib import pyplot as plt
import seaborn as sns
from collections import *
import datetime

# %%
data=pd.read_csv(r"C:\Users\Mark 1\Desktop\Lockdown\data\Covid-19\28\case_time_series.csv")
data.head()
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0   30 January                 1                1                0
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
data_daily=data[53:]
data_daily.reset_index(drop=True,inplace=True)
data_daily.head()
# Out:
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0  23 March                94              497                2
# 1  24 March                74              571               15
# 2  25 March                86              657                3
# 3  26 March                73              730                7
# 4  27 March               153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0               25               2               9
# 1               40               1              10
# 2               43               1              11
# 3               50               5              16
# 4               75               3              19

# %%
data_daily.tail()
# Out:
#          Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 125  26 July             48932          1436020            31512
# 126  27 July             46484          1482504            34354
# 127  28 July             49631          1532135            35683
# 128  29 July             52479          1584614            32886
# 129  30 July             54750          1639364            37425
#
#      Total Recovered  Daily Deceased  Total Deceased
# 125           918636             704           32827
# 126           952990             642           33469
# 127           988673             774           34243
# 128          1021559             775           35018
# 129          1058984             783           35801

# %%
colls=list(data_daily.columns)
colls
# Out:
# ['Date',
#  'Daily Confirmed',
#  'Total Confirmed',
#  'Daily Recovered',
#  'Total Recovered',
#  'Daily Deceased',
#  'Total Deceased']

# %%
data_daily.dtypes
# Out:
# Date               object
# Daily Confirmed     int64
# Total Confirmed     int64
# Daily Recovered     int64
# Total Recovered     int64
# Daily Deceased      int64
# Total Deceased      int64
# dtype: object

# %%
data_daily[data_daily.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Daily Confirmed, Total Confirmed, Daily Recovered, Total Recovered, Daily Deceased, Total Deceased]
# Index: []

# %%
data_daily['Date'] = data_daily['Date'].astype('str')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,9):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" March")
for i in range(0,9):
    data_daily["Date"][i]="2020-03-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(9,39):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" April")
for i in range(9,39):
    data_daily["Date"][i]="2020-04-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(39,70):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" May")
for i in range(39,70):
    data_daily["Date"][i]="2020-05-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(70,100):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" June")
for i in range(70,100):
    data_daily["Date"][i]="2020-06-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for i in range(100,130):
    data_daily["Date"][i]=data_daily["Date"][i].strip(" July")
for i in range(100,130):
    data_daily["Date"][i]="2020-07-"+data_daily["Date"][i]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
data_daily["Date"]=data_daily["Date"].astype('datetime64[ns]')
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_daily.dtypes
# Out:
# Date               datetime64[ns]
# Daily Confirmed             int64
# Total Confirmed             int64
# Daily Recovered             int64
# Total Recovered             int64
# Daily Deceased              int64
# Total Deceased              int64
# dtype: object

# %%
data_daily_ratio_with_two_precision=data_daily.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_daily_ratio_with_two_precision.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_daily_ratio_with_two_precision[i]=list(range(len(data_daily_ratio_with_two_precision)))
    data_daily_ratio_with_two_precision[i][0]=1
    tmp=[]
    tmp.append(data_daily_ratio_with_two_precision[i][0])
    for k in range(0,len(data_daily_ratio_with_two_precision)-1):
        tmp.append(round(data_daily_ratio_with_two_precision[j][k+1]/data_daily_ratio_with_two_precision[j][k],2))
    data_daily_ratio_with_two_precision[i]=tmp
data_daily_ratio_with_two_precision.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9                   1.00
# 1               40               1              10                   0.79
# 2               43               1              11                   1.16
# 3               50               5              16                   0.85
# 4               75               3              19                   2.10
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0                   1.00                   1.00                   1.00
# 1                   1.15                   7.50                   1.60
# 2                   1.15                   0.20                   1.08
# 3                   1.11                   2.33                   1.16
# 4                   1.21                   3.57                   1.50
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0                  1.00
# 1                   0.5                  1.11
# 2                   1.0                  1.10
# 3                   5.0                  1.45
# 4                   0.6                  1.19

# %%
data_daily_ratio=data_daily.copy()

# %%
new_cols=["Daily_Confirmed_Ratio","Total_Confirmed_Ratio","Daily_Recovered_Ratio","Total_Recovered_Ratio","Daily_Deceased_Ratio","Total_Deceased_Ratio"]
existing_cols=list(data_daily_ratio.columns)
existing_cols.pop(0)
existing_cols
for i,j in zip(new_cols,existing_cols):
    data_daily_ratio[i]=list(range(len(data_daily_ratio)))
    data_daily_ratio[i][0]=1
    tmp=[]
    tmp.append(data_daily_ratio[i][0])
    for k in range(0,len(data_daily_ratio)-1):
        tmp.append(data_daily_ratio[j][k+1]/data_daily_ratio[j][k])
    data_daily_ratio[i]=tmp
data_daily_ratio.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#         Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0 2020-03-23               94              497                2
# 1 2020-03-24               74              571               15
# 2 2020-03-25               86              657                3
# 3 2020-03-26               73              730                7
# 4 2020-03-27              153              883               25
#
#    Total Recovered  Daily Deceased  Total Deceased  Daily_Confirmed_Ratio  \
# 0               25               2               9               1.000000
# 1               40               1              10               0.787234
# 2               43               1              11               1.162162
# 3               50               5              16               0.848837
# 4               75               3              19               2.095890
#
#    Total_Confirmed_Ratio  Daily_Recovered_Ratio  Total_Recovered_Ratio  \
# 0               1.000000               1.000000               1.000000
# 1               1.148893               7.500000               1.600000
# 2               1.150613               0.200000               1.075000
# 3               1.111111               2.333333               1.162791
# 4               1.209589               3.571429               1.500000
#
#    Daily_Deceased_Ratio  Total_Deceased_Ratio
# 0                   1.0              1.000000
# 1                   0.5              1.111111
# 2                   1.0              1.100000
# 3                   5.0              1.454545
# 4                   0.6              1.187500

# %%
strt_cnt=1
end_cnt=8
strt_lst=[]
end_lst=[]
strt_lst.append(strt_cnt)
end_lst.append(end_cnt)
while(end_cnt<=len(data_daily_ratio)):
        strt_cnt+=1
        strt_lst.append(strt_cnt)
        end_cnt+=1
        end_lst.append(end_cnt)
if(end_lst[len(end_lst)-1]>=len(data_daily_ratio)):
    end_lst.pop(len(end_lst)-1)
strt_lst.pop(len(strt_lst)-1)
#print(strt_lst)
#print(end_lst)
#print(len(strt_lst)==len(end_lst))

for st,en in zip(strt_lst,end_lst):

    dcr=data_daily_ratio.iloc[st:en,9:10]
    dcr.reset_index(inplace = True, drop = True)
    dc=data_daily_ratio.iloc[st:en,3:4]
    dc.reset_index(inplace = True, drop = True)



    next_day_recovered_case_count_mean_based=dcr.mean()[0]*dc.mean()[0]

    next_day_recovered_case_count_max_based=max(dcr["Daily_Recovered_Ratio"])*max(dc["Daily Recovered"])


    next_day_recovered_case_count_mean_max_based=dcr.mean()[0]*max(dc["Daily Recovered"])


    next_day_recovered_case_count_max_mean_based=max(dcr["Daily_Recovered_Ratio"])*dc.mean()[0]


    next_day_recovered_case_count_mean_last_based=dcr.mean()[0]*dc["Daily Recovered"][len(dc)-1]


    next_day_recovered_case_count_last_mean_based=dcr["Daily_Recovered_Ratio"][len(dcr)-1]*dc.mean()[0]


    next_day_recovered_case_count_last_based=dcr["Daily_Recovered_Ratio"][len(dcr)-1]*dc["Daily Recovered"][len(dc)-1]


    next_day_recovered_case_count_middle_based=dcr["Daily_Recovered_Ratio"][3]*dc["Daily Recovered"][3]


    pred_val=[]
    pred_val.append(np.round(next_day_recovered_case_count_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_max_based))
    pred_val.append(np.round(next_day_recovered_case_count_max_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_mean_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_mean_based))
    pred_val.append(np.round(next_day_recovered_case_count_last_based))
    pred_val.append(np.round(next_day_recovered_case_count_middle_based))

    if(en!=len(data_daily_ratio)):
        pred_dict={"date":data_daily_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":data_daily_ratio["Daily Recovered"][en-1],"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
    else:
        pred_dict={"date":data_daily_ratio["Date"][en-1]+datetime.timedelta(hours=24),"original_val":0,"mean_based":pred_val[0],"max_based":pred_val[1],"mean_max_based":pred_val[2],"max_mean_based":pred_val[3],"mean_last_based":pred_val[4],"last_mean_based":pred_val[5],"last_based":pred_val[6],"middle_based":pred_val[7]}
        
    
    pred_df=pd.DataFrame(pred_dict, index=[0])
    
    
    d=pd.read_excel(r"C:\Users\Mark 1\ramprd_df_strd.xlsx")
    d=pd.concat([d,pred_df])
    d.reset_index(drop=True,inplace=True)
    d.to_excel("ramprd_df_strd.xlsx")

# %%
dc=pd.read_excel(r"C:\Users\Mark 1\ramprd_df_strd.xlsx")
dc
# Out:
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31            35          41        262              89
# 1   2020-04-01            13          24        125              53
# 2   2020-04-02            19          31        125              59
# 3   2020-04-03            22          31        125              54
# 4   2020-04-04            39          28         80              50
# 5   2020-04-05            56          41        115              80
# 6   2020-04-06            43          42        115              72
# 7   2020-04-07            65          44        115              79
# 8   2020-04-08            75          60        133              99
# 9   2020-04-09            96          73        170             125
# 10  2020-04-10            70          78        170             119
# 11  2020-04-11           151         103        326             195
# 12  2020-04-12           186         124        401             235
# 13  2020-04-13           114         134        401             231
# 14  2020-04-14           112         134        401             216
# 15  2020-04-15           167         155        401             225
# 16  2020-04-16           144         155        401             214
# 17  2020-04-17           258         211        557             336
# 18  2020-04-18           273         206        489             313
# 19  2020-04-19           426         255        763             509
# 20  2020-04-20           388         312        763             527
# 21  2020-04-21           419         371        763             533
# 22  2020-04-22           703         476       1260             898
# 23  2020-04-23           394         504       1260             868
# 24  2020-04-24           642         561       1179             851
# 25  2020-04-25           484         576       1179             821
# 26  2020-04-26           442         533       1179             756
# 27  2020-04-27           585         594       1179             797
# 28  2020-04-28           580         614       1179             788
# 29  2020-04-29           636         558       1046             667
# 121           38724            33179            31256       30308
# 122           39392            38252            39262       42590
#
#      middle_based
# 0              89
# 1               4
# 2              29
# 3              72
# 4               5
# 5              28
# 6              25
# 7              69
# 8              80
# 9              33
# 10             98
# 11             87
# 12            123
# 13             51
# 14            326
# 15            229
# 16             70
# 17            110
# 18            249
# 19            124
# 20            462
# 21            289
# 22            665
# 23            353
# 24            452
# 25           1179
# 26            221
# 27           1046
# 28            365
# 29            404
# ..            ...
# 93           9507
# 94          15662
# 95          11697
# 96          11583
# 97          33153
# 98          10393
# 99          15083
# 100         16992
# 101         14818
# 102         18508
# 103         22604
# 104         19309
# 105         21210
# 106         19678
# 107         16574
# 108         17183
# 109         24885
# 110         20320
# 111         25327
# 112         13356
# 113         31824
# 114         21908
# 115         25985
# 116         31319
# 117         36827
# 118         34843
# 119         31722
# 120         42390
# 121         26748
# 122         37452
#
# [123 rows x 10 columns]

# %%
dce=dc.copy()

# %%
colls=list(dc.columns)
colls.pop(0)
colls.pop(0)
collss=["mb","mxb","memb","mxmb","mlb","lmb","lb","mdb"]
for i in collss:
    dce[i]=pd.Series(range(1,len(dce)+1))
colls
# Out:
# ['mean_based',
#  'max_based',
#  'mean_max_based',
#  'max_mean_based',
#  'mean_last_based',
#  'last_mean_based',
#  'last_based',
#  'middle_based']

# %%
for i,j in zip(colls,collss):
    for k in range(len(dce)):
        dce[j][k]=dce["original_val"][k]-dce[i][k]
dce
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           date  original_val  mean_based  max_based  mean_max_based  \
# 0   2020-03-31            35          41        262              89
# 1   2020-04-01            13          24        125              53
# 2   2020-04-02            19          31        125              59
# 3   2020-04-03            22          31        125              54
# 4   2020-04-04            39          28         80              50
# 5   2020-04-05            56          41        115              80
# 6   2020-04-06            43          42        115              72
# 7   2020-04-07            65          44        115              79
# 8   2020-04-08            75          60        133              99
# 9   2020-04-09            96          73        170             125
# 10  2020-04-10            70          78        170             119
# 11  2020-04-11           151         103        326             195
# 12  2020-04-12           186         124        401             235
# 13  2020-04-13           114         134        401             231
# 14  2020-04-14           112         134        401             216
# 15  2020-04-15           167         155        401             225
# 16  2020-04-16           144         155        401             214
# 17  2020-04-17           258         211        557             336
# 18  2020-04-18           273         206        489             313
# 19  2020-04-19           426         255        763             509
# 20  2020-04-20           388         312        763             527
# 21  2020-04-21           419         371        763             533
# 22  2020-04-22           703         476       1260             898
# 23  2020-04-23           394         504       1260             868
# 24  2020-04-24           642         561       1179             851
# 25  2020-04-25           484         576       1179             821
# 26  2020-04-26           442         533       1179             756
# 27  2020-04-27           585         594       1179             797
# 28  2020-04-28           580         614       1179             788
# 29  2020-04-29           636         558       1046             667
# ..         ...           ...         ...        ...             ...
# 93  2020-07-02         12064       12708      19760           14348
# 94  2020-07-03         19999       14708      33153           21851
# 95  2020-07-04         14417       15335      33153           21817
# 96  2020-07-05         14746       14677      33153           20771
# 97  2020-07-06         15829       15839      33153           21503
# 98  2020-07-07         15315       15705      33153           20952
# 99  2020-07-08         16836       16719      33153           21433
# 100 2020-07-09         19508       18332      33153           22000
# 101 2020-07-10         19408       16669      22604           19613
# 102 2020-07-11         20289       18320      23509           21338
# 103 2020-07-12         19981       19008      23509           21228
# 104 2020-07-13         18198       18932      23509           20757
# 105 2020-07-14         17683       19289      23509           20769
# 106 2020-07-15         20977       20136      24885           21734
# 107 2020-07-16         20646       19816      24885           21211
# 108 2020-07-17         22867       20639      27127           23490
# 109 2020-07-18         17476       19435      27127           22572
# 110 2020-07-19         23583       20996      31824           24507
# 111 2020-07-20         22730       21827      31824           24686
# 112 2020-07-21         24303       23120      32796           25778
# 113 2020-07-22         27589       23956      37230           29062
# 114 2020-07-23         31875       26241      43014           34356
# 115 2020-07-24         33326       27623      44972           35625
# 116 2020-07-25         32514       30764      44972           36631
# 117 2020-07-26         37125       32003      42892           39706
# 118 2020-07-27         31512       32833      42892           39096
# 119 2020-07-28         34354       34442      42892           39207
# 120 2020-07-29         35683       35198      42892           38695
# 121 2020-07-30         32886       34216      42390           37455
# 122 2020-07-31             0       35263      42732           38252
#
#      max_mean_based  mean_last_based  last_mean_based  last_based  \
# 0               120               89               33          72
# 1                56               20                6           5
# 2                64               32               26          28
# 3                72               34               23          25
# 4                46               50               39          69
# 5                59               80               41          80
# 6                67               55               25          33
# 7                65               79               55          98
# 8                81               99               53          87
# 9               100              125               72         123
# 10              112               87               46          51
# 11              171              195              171         326
# 12              211              235              121         229
# 13              233              141               66          70
# 14              248              130              113         110
# 15              276              202              191         249
# 16              291              166              116         124
# 17              349              336              290         462
# 18              321              313              190         289
# 19              382              509              333         665
# 20              453              480              230         353
# 21              531              524              320         452
# 22              668              898              626        1179
# 23              732              486              229         221
# 24              778              777              755        1046
# 25              828              565              372         365
# 26              832              475              453         404
# 27              879              663              694         774
# 28              918              650              542         575
# 29              876              660              589         697
# ..              ...              ...              ...         ...
# 93            17501            12165            12100       11583
# 94            22316            21851            22316       33153
# 95            23304            15727            10134       10393
# 96            23426            15316            14454       15083
# 97            24420            17019            15813       16992
# 98            24851            16045            14504       14818
# 99            25862            18043            17150       18508
# 100           27625            21460            19309       22604
# 101           19211            19512            16495       19309
# 102           20183            21338            18209       21210
# 103           21050            20906            17891       19678
# 104           21442            18618            16854       16574
# 105           21834            18101            18310       17183
# 106           23055            21734            23055       24885
# 107           23248            20876            19288       20320
# 108           23834            23490            22253       25327
# 109           23358            17250            15048       13356
# 110           27265            24507            27265       31824
# 111           28138            23793            20098       21908
# 112           29415            25778            23306       25985
# 113           30689            29062            25817       31319
# 114           32854            34356            28128       36827
# 115           34870            35625            27017       34843
# 116           37769            35738            27307       31722
# 117           34572            39706            34167       42390
# 118           36021            33185            26464       26748
# 119           37680            36280            35555       37452
# 120           39016            37192            35076       37063
# 121           38724            33179            31256       30308
# 122           39392            38252            39262       42590
#
#      middle_based     mb    mxb   memb   mxmb    mlb    lmb     lb    mdb
# 0              89     -6   -227    -54    -85    -54      2    -37    -54
# 1               4    -11   -112    -40    -43     -7      7      8      9
# 2              29    -12   -106    -40    -45    -13     -7     -9    -10
# 105  -1606  -5826  -3086  -4151   -418   -627    500  -3527
# 106    841  -3908   -757  -2078   -757  -2078  -3908   1299
# 107    830  -4239   -565  -2602   -230   1358    326   4072
# 108   2228  -4260   -623   -967   -623    614  -2460   5684
# 109  -1959  -9651  -5096  -5882    226   2428   4120  -7409
# 110   2587  -8241   -924  -3682   -924  -3682  -8241   3263
# 111    903  -9094  -1956  -5408  -1063   2632    822  -2597
# 112   1183  -8493  -1475  -5112  -1475    997  -1682  10947
# 113   3633  -9641  -1473  -3100  -1473   1772  -3730  -4235
# 114   5634 -11139  -2481   -979  -2481   3747  -4952   9967
# 115   5703 -11646  -2299  -1544  -2299   6309  -1517   7341
# 116   1750 -12458  -4117  -5255  -3224   5207    792   1195
# 117   5122  -5767  -2581   2553  -2581   2958  -5265    298
# 118  -1321 -11380  -7584  -4509  -1673   5048   4764  -3331
# 119    -88  -8538  -4853  -3326  -1926  -1201  -3098   2632
# 120    485  -7209  -3012  -3333  -1509    607  -1380  -6707
# 121  -1330  -9504  -4569  -5838   -293   1630   2578   6138
# 122 -35263 -42732 -38252 -39392 -38252 -39262 -42590 -37452
#
# [123 rows x 8 columns]

# %%
for j,k in zip(range(len(edf)),range(len(dce)-1)):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        ps=min(pos)
        psi=a.index(ps)
        psc=list(edf.columns)[psi]
    if(len(neg)):
        ng=max(neg)
        ngi=a.index(ng)
        ngc=list(edf.columns)[ngi]
    
    
    print("for date: "+str(dce["date"][k]).strip("00:00:00")+" the lowest positve error was by the method: "+psc+" and the highest negative error by the method: "+ngc)
# Out:
# for date: 2020-03-31  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-04-01  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-04-02  the lowest positve error was by the method: lmb and the highest negative error by the method: lmb
# for date: 2020-04-03  the lowest positve error was by the method: lmb and the highest negative error by the method: lmb
# for date: 2020-04-04  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-04-05  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-06  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-04-07  the lowest positve error was by the method: mxmb and the highest negative error by the method: mdb
# for date: 2020-04-08  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-04-09  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-10  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-11  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-12  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-04-13  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-14  the lowest positve error was by the method: lb and the highest negative error by the method: lmb
# for date: 2020-04-15  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-16  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-17  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-18  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-04-19  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-20  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-04-21  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-04-22  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-04-23  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-04-24  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-04-25  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-04-26  the lowest positve error was by the method: lb and the highest negative error by the method: lmb
# for date: 2020-04-27  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-28  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-04-29  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-04-30  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-01  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-02  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-05-03  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-04  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-05-05  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-05-06  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-07  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-08  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-09  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-05-10  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-05-11  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-05-12  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-05-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-14  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-15  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-05-16  the lowest positve error was by the method: mb and the highest negative error by the method: mdb
# for date: 2020-05-17  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-05-18  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-05-19  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-05-20  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-05-21  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-05-22  the lowest positve error was by the method: lmb and the highest negative error by the method: lb
# for date: 2020-05-23  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-05-24  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-05-25  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-05-26  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-05-27  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-05-28  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-05-29  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-05-30  the lowest positve error was by the method: mb and the highest negative error by the method: mxmb
# for date: 2020-05-31  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-06-01  the lowest positve error was by the method: mdb and the highest negative error by the method: lmb
# for date: 2020-06-02  the lowest positve error was by the method: lb and the highest negative error by the method: lmb
# for date: 2020-06-03  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-06-04  the lowest positve error was by the method: lb and the highest negative error by the method: lmb
# for date: 2020-06-05  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-06-06  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-07  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-08  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-06-09  the lowest positve error was by the method: lb and the highest negative error by the method: mdb
# for date: 2020-06-10  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-06-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-12  the lowest positve error was by the method: lb and the highest negative error by the method: mxmb
# for date: 2020-06-13  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-14  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-15  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-06-16  the lowest positve error was by the method: mxmb and the highest negative error by the method: memb
# for date: 2020-06-17  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-06-18  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-06-19  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-06-20  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-06-21  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-22  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-06-23  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-06-24  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-06-25  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-06-26  the lowest positve error was by the method: mdb and the highest negative error by the method: lb
# for date: 2020-06-27  the lowest positve error was by the method: mdb and the highest negative error by the method: mlb
# for date: 2020-06-28  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-06-29  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-06-30  the lowest positve error was by the method: mb and the highest negative error by the method: mlb
# for date: 2020-07-01  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-07-02  the lowest positve error was by the method: lb and the highest negative error by the method: lmb
# for date: 2020-07-03  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-04  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-07-05  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-06  the lowest positve error was by the method: lmb and the highest negative error by the method: mb
# for date: 2020-07-07  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-07-08  the lowest positve error was by the method: mb and the highest negative error by the method: lmb
# for date: 2020-07-09  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-07-10  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-07-11  the lowest positve error was by the method: mxmb and the highest negative error by the method: lb
# for date: 2020-07-12  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-07-13  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb
# for date: 2020-07-14  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-07-15  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-07-16  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-07-17  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-07-18  the lowest positve error was by the method: mlb and the highest negative error by the method: mb
# for date: 2020-07-19  the lowest positve error was by the method: mb and the highest negative error by the method: memb
# for date: 2020-07-20  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-07-21  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-07-22  the lowest positve error was by the method: lmb and the highest negative error by the method: memb
# for date: 2020-07-23  the lowest positve error was by the method: lmb and the highest negative error by the method: mxmb
# for date: 2020-07-24  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-25  the lowest positve error was by the method: lb and the highest negative error by the method: mlb
# for date: 2020-07-26  the lowest positve error was by the method: mdb and the highest negative error by the method: memb
# for date: 2020-07-27  the lowest positve error was by the method: lb and the highest negative error by the method: mb
# for date: 2020-07-28  the lowest positve error was by the method: mdb and the highest negative error by the method: mb
# for date: 2020-07-29  the lowest positve error was by the method: mb and the highest negative error by the method: lb
# for date: 2020-07-30  the lowest positve error was by the method: lmb and the highest negative error by the method: mlb

# %%
err_dict={"date":[],"mipe":[],"mxne":[],"mipv":[],"mxnv":[],"original_val":[],"pprd_val":[],"nprd_val":[]}
psc=[]
ngc=[]
date=[]
ps=[]
ng=[]
org_val=[]
pprd_val=[]
nprd_val=[]
for j,k in zip(range(len(edf)),range(len(dce))):
    
    a=list(edf.loc[j])
    pos=[]
    neg=[]
    for i in a:
        if(i>=0):
            pos.append(i)
        else:
            neg.append(i)
    if(len(pos)):
        aa=min(pos)
    
        psi=a.index(aa)
    
        ps.append(aa)
    
        psc.append(list(edf.columns)[psi])
    
    
        pprd_val.append(dce["original_val"][k]-aa)
    else:
        ps.append("No")
    
        psc.append("No")
    
    
        pprd_val.append("No")
        
    
    if(len(neg)):
        bb=max(neg)
        ngi=a.index(bb)
        ng.append(bb)
        ngc.append(list(edf.columns)[ngi])
        nprd_val.append(dce["original_val"][k]-bb)
    else:
        ng.append("No")
    
        ngc.append("No")
    
    
        nprd_val.append("No")
    
    date.append(str(dce["date"][k]).strip("00:00:00"))
    org_val.append(dce["original_val"][k])
err_dict.update({"date":date})
err_dict.update({"mipe":psc})
err_dict.update({"mxne":ngc})
err_dict.update({"mipv":ps})
err_dict.update({"mxnv":ng})
err_dict.update({"original_val":org_val})
err_dict.update({"pprd_val":pprd_val})
err_dict.update({"nprd_val":nprd_val})

# %%
err_dict
# Out:
# {'date': ['2020-03-31 ',
#   '2020-04-01 ',
#   '2020-04-02 ',
#   '2020-04-03 ',
#   '2020-04-04 ',
#   '2020-04-05 ',
#   '2020-04-06 ',
#   '2020-04-07 ',
#   '2020-04-08 ',
#   '2020-04-09 ',
#   '2020-04-10 ',
#   '2020-04-11 ',
#   '2020-04-12 ',
#   '2020-04-13 ',
#   '2020-04-14 ',
#   '2020-04-15 ',
#   '2020-04-16 ',
#   '2020-04-17 ',
#   '2020-04-18 ',
#   '2020-04-19 ',
#   '2020-04-20 ',
#   '2020-04-21 ',
#   '2020-04-22 ',
#   '2020-04-23 ',
#   '2020-04-24 ',
#   '2020-04-25 ',
#   '2020-04-26 ',
#   '2020-04-27 ',
#   '2020-04-28 ',
#   '2020-04-29 ',
#   '2020-04-30 ',
#   '2020-05-01 ',
#   '2020-05-02 ',
#   '2020-05-03 ',
#   '2020-05-04 ',
#   '2020-05-05 ',
#   '2020-05-06 ',
#   '2020-05-07 ',
#   '2020-05-08 ',
#   '2020-05-09 ',
#   '2020-05-10 ',
#   '2020-05-11 ',
#   '2020-05-12 ',
#   '2020-05-13 ',
#   '2020-05-14 ',
#   '2020-05-15 ',
#   '2020-05-16 ',
#   '2020-05-17 ',
#   '2020-05-18 ',
#   '2020-05-19 ',
#   '2020-05-20 ',
#   '2020-05-21 ',
#   '2020-05-22 ',
#   '2020-05-23 ',
#   '2020-05-24 ',
#   '2020-05-25 ',
#   '2020-05-26 ',
#   '2020-05-27 ',
#   '2020-05-28 ',
#   '2020-05-29 ',
#   '2020-05-30 ',
#   '2020-05-31 ',
#   '2020-06-01 ',
#   '2020-06-02 ',
#   '2020-06-03 ',
#   '2020-06-04 ',
#   '2020-06-05 ',
#   '2020-06-06 ',
#   '2020-06-07 ',
#   '2020-06-08 ',
#   '2020-06-09 ',
#   '2020-06-10 ',
#   '2020-06-11 ',
#   '2020-06-12 ',
#   '2020-06-13 ',
#   '2020-06-14 ',
#   '2020-06-15 ',
#   '2020-06-16 ',
#   '2020-06-17 ',
#   '2020-06-18 ',
#   '2020-06-19 ',
#   '2020-06-20 ',
#   '2020-06-21 ',
#   '2020-06-22 ',
#   '2020-06-23 ',
#   '2020-06-24 ',
#   '2020-06-25 ',
#   '2020-06-26 ',
#   '2020-06-27 ',
#   '2020-06-28 ',
#   '2020-06-29 ',
#   '2020-06-30 ',
#   '2020-07-01 ',
#   '2020-07-02 ',
#   '2020-07-03 ',
#   '2020-07-04 ',
#   '2020-07-05 ',
#   '2020-07-06 ',
#   '2020-07-07 ',
#   '2020-07-08 ',
#   '2020-07-09 ',
#   '2020-07-10 ',
#   '2020-07-11 ',
#   '2020-07-12 ',
#   '2020-07-13 ',
#   '2020-07-14 ',
#   '2020-07-15 ',
#   '2020-07-16 ',
#   '2020-07-17 ',
#   '2020-07-18 ',
#   '2020-07-19 ',
#   '2020-07-20 ',
#   '2020-07-21 ',
#   '2020-07-22 ',
#   '2020-07-23 ',
#   '2020-07-24 ',
#   '2020-07-25 ',
#   '2020-07-26 ',
#   '2020-07-27 ',
#   '2020-07-28 ',
#   '2020-07-29 ',
#   '2020-07-30 ',
#   '2020-07-31 '],
#  'mipe': ['lmb',
#   'lmb',
#   'No',
#   'No',
#   'lmb',
#   'mb',
#   'mb',
#   'mxmb',
#   'mb',
#   'mb',
#   'lb',
#   'mb',
#   'mb',
#   'lb',
#   'lb',
#   'mb',
#   'lb',
#   'mb',
#   'mdb',
#   'mxmb',
#   'lb',
#   'mb',
#   'mxmb',
#   'mdb',
#   'mb',
#   'lmb',
#   'lb',
#   'No',
#   'lb',
#   'lmb',
#   'mb',
#   'mb',
#   'mb',
#   'mb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mxmb',
#   'mb',
#   'mdb',
#   'mb',
#   'mxmb',
#   'mb',
#   'lb',
#   'mb',
#   'mb',
#   'lmb',
#   'lmb',
#   'mlb',
#   'mdb',
#   'lmb',
#   'mb',
#   'lb',
#   'lmb',
#   'mb',
#   'mdb',
#   'mdb',
#   'lb',
#   'mdb',
#   'lb',
#   'mdb',
#   'lmb',
#   'mxmb',
#   'mdb',
#   'lb',
#   'lmb',
#   'mxmb',
#   'lb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'lmb',
#   'mdb',
#   'mb',
#   'lb',
#   'mb',
#   'lmb',
#   'mb',
#   'lb',
#   'mb',
#   'mdb',
#   'mdb',
#   'mb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'mdb',
#   'mdb',
#   'mb',
#   'lmb',
#   'lb',
#   'mb',
#   'lmb',
#   'lb',
#   'mxmb',
#   'lb',
#   'lmb',
#   'lb',
#   'mb',
#   'lb',
#   'lmb',
#   'mlb',
#   'mb',
#   'lb',
#   'lmb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lb',
#   'mdb',
#   'lb',
#   'mdb',
#   'mb',
#   'lmb',
#   'No'],
#  'mxne': ['mb',
#   'mlb',
#   'lmb',
#   'lmb',
#   'mxmb',
#   'mxmb',
#   'mlb',
#   'mdb',
#   'mdb',
#   'mxmb',
#   'mb',
#   'mxmb',
#   'mxmb',
#   'mb',
#   'lmb',
#   'lmb',
#   'mb',
#   'lmb',
#   'lb',
#   'memb',
#   'mxmb',
#   'lb',
#   'memb',
#   'mlb',
#   'lmb',
#   'mlb',
#   'lmb',
#   'mb',
#   'mb',
#   'mlb',
#   'lb',
#   'mlb',
#   'mxmb',
#   'mlb',
#   'mlb',
#   'memb',
#   'mxmb',
#   'mlb',
#   'mxmb',
#   'mlb',
#   'mxmb',
#   'mxmb',
#   'mlb',
#   'memb',
#   'mdb',
#   'mlb',
#   'mdb',
#   'memb',
#   'mlb',
#   'mb',
#   'lmb',
#   'lb',
#   'lb',
#   'mb',
#   'mb',
#   'memb',
#   'mlb',
#   'memb',
#   'mlb',
#   'mlb',
#   'mxmb',
#   'mlb',
#   'lmb',
#   'lmb',
#   'lb',
#   'lmb',
#   'lb',
#   'mxmb',
#   'memb',
#   'mlb',
#   'mdb',
#   'mxmb',
#   'memb',
#   'mxmb',
#   'memb',
#   'memb',
#   'mlb',
#   'memb',
#   'mlb',
#   'mlb',
#   'memb',
#   'mb',
#   'lmb',
#   'mlb',
#   'mlb',
#   'mb',
#   'lmb',
#   'lb',
#   'mlb',
#   'memb',
#   'mlb',
#   'mlb',
#   'mlb',
#   'lmb',
#   'memb',
#   'mb',
#   'lb',
#   'mb',
#   'mb',
#   'lmb',
#   'mlb',
#   'mlb',
#   'lb',
#   'mlb',
#   'mlb',
#   'mlb',
#   'memb',
#   'mlb',
#   'memb',
#   'mb',
#   'memb',
#   'mlb',
#   'memb',
#   'memb',
#   'mxmb',
#   'lb',
#   'mlb',
#   'memb',
#   'mb',
#   'mb',
#   'lb',
#   'mlb',
#   'mb'],
#  'mipv': [2,
#   7,
#   'No',
#   'No',
#   0,
#   15,
#   1,
#   0,
#   15,
#   23,
#   19,
#   48,
#   62,
#   44,
#   2,
#   12,
#   20,
#   47,
#   24,
#   44,
#   35,
#   48,
#   35,
#   41,
#   81,
#   112,
#   38,
#   'No',
#   5,
#   47,
#   44,
#   46,
#   237,
#   49,
#   90,
#   108,
#   201,
#   84,
#   74,
#   265,
#   91,
#   117,
#   85,
#   30,
#   225,
#   100,
#   254,
#   175,
#   11,
#   55,
#   164,
#   61,
#   179,
#   49,
#   111,
#   136,
#   205,
#   334,
#   145,
#   224,
#   5607,
#   1014,
#   2000,
#   824,
#   2953,
#   620,
#   1332,
#   21,
#   143,
#   105,
#   20,
#   283,
#   173,
#   222,
#   223,
#   595,
#   447,
#   42,
#   2093,
#   199,
#   1401,
#   1439,
#   3309,
#   2806,
#   599,
#   401,
#   464,
#   941,
#   185,
#   2101,
#   1761,
#   372,
#   697,
#   481,
#   4337,
#   2720,
#   69,
#   16,
#   497,
#   117,
#   199,
#   99,
#   106,
#   303,
#   1344,
#   500,
#   841,
#   326,
#   614,
#   226,
#   2587,
#   822,
#   997,
#   1772,
#   3747,
#   5703,
#   792,
#   298,
#   4764,
#   2632,
#   485,
#   1630,
#   'No'],
#  'mxnv': [-6,
#   -7,
#   -7,
#   -1,
#   -7,
#   -3,
#   -12,
#   -4,
#   -5,
#   -4,
#   -8,
#   -20,
#   -25,
#   -20,
#   -1,
#   -24,
#   -11,
#   -32,
#   -16,
#   -83,
#   -65,
#   -33,
#   -195,
#   -92,
#   -113,
#   -81,
#   -11,
#   -9,
#   -34,
#   -24,
#   -59,
#   -7,
#   -25,
#   -95,
#   -75,
#   -119,
#   -101,
#   -113,
#   -208,
#   -42,
#   -122,
#   -5,
#   -116,
#   -143,
#   -7,
#   -46,
#   3289,
#   2928,
#   3058,
#   1578,
#   3169,
#   3058,
#   4749,
#   5290,
#   5086,
#   5151,
#   5351,
#   6102,
#   5822,
#   7040,
#   7497,
#   6911,
#   10597,
#   5133,
#   6691,
#   9340,
#   7590,
#   10665,
#   6269,
#   10280,
#   10061,
#   12625,
#   13042,
#   10061,
#   12128,
#   9870,
#   13125,
#   11868,
#   11583,
#   15662,
#   11697,
#   14677,
#   15813,
#   14818,
#   16719,
#   19309,
#   19309,
#   20183,
#   19678,
#   16854,
#   17183,
#   20136,
#   20320,
#   22253,
#   17250,
#   20996,
#   21908,
#   23306,
#   25817,
#   28128,
#   27623,
#   31722,
#   36827,
#   26748,
#   31722,
#   35198,
#   31256,
#   'No'],
#  'nprd_val': [41,
#   20,
#   26,
#   23,
#   46,
#   59,
#   55,
#   69,
#   80,
#   100,
#   78,
#   171,
#   211,
#   134,
#   113,
#   191,
#   155,
#   290,
#   289,
#   509,
#   453,
#   452,
#   898,
#   486,
#   755,
#   565,
#   453,
#   594,
#   614,
#   660,
#   749,
#   637,
#   987,
#   926,
#   986,
#   1201,
#   1396,
#   1274,
#   1683,
#   1153,
#   1536,
#   1674,
#   1695,
#   2048,
#   1970,
#   1640,
#   2298,
#   4799,
#   2837,
#   2682,
#   3116,
#   3196,
#   3149,
#   3396,
#   2754,
#   3445,
#   3132,
#   3712,
#   3522,
#   3215,
#   16282,
#   5736,
#   5590,
#   3943,
#   5289,
#   4341,
#   5086,
#   5101,
#   5682,
#   5288,
#   5183,
#   5690,
#   6758,
#   6267,
#   7739,
#   8594,
#   7766,
#   11912,
#   7667,
#   7153,
#   12065,
#   9182,
#   14561,
#   9950,
#   11544,
#   11180,
#   13807,
#   14938,
#   10846,
#   14739,
#   12327,
#   14230,
#   13193,
#   12100,
#   21851,
#   15335,
#   15083,
#   15839,
#   15705,
#   17150,
#   21460,
#   19512,
#   21210,
#   20906,
#   18618,
#   18101,
#   21734,
#   20876,
#   23490,
#   19435,
#   24507,
#   23793,
#   25778,
#   29062,
#   32854,
#   34843,
#   35738,
#   39706,
#   32833,
#   34442,
#   37063,
#   33179,
#   35263]}

# %%
pd.DataFrame(err_dict)
# Out:
#             date  mipe  mxne  mipv   mxnv  original_val pprd_val  nprd_val
# 0    2020-03-31    lmb    mb     2     -6            35       33        41
# 1    2020-04-01    lmb   mlb     7     -7            13        6        20
# 2    2020-04-02     No   lmb    No     -7            19       No        26
# 3    2020-04-03     No   lmb    No     -1            22       No        23
# 4    2020-04-04    lmb  mxmb     0     -7            39       39        46
# 5    2020-04-05     mb  mxmb    15     -3            56       41        59
# 6    2020-04-06     mb   mlb     1    -12            43       42        55
# 7    2020-04-07   mxmb   mdb     0     -4            65       65        69
# 8    2020-04-08     mb   mdb    15     -5            75       60        80
# 9    2020-04-09     mb  mxmb    23     -4            96       73       100
# 10   2020-04-10     lb    mb    19     -8            70       51        78
# 11   2020-04-11     mb  mxmb    48    -20           151      103       171
# 12   2020-04-12     mb  mxmb    62    -25           186      124       211
